# %%
import imageio
import matplotlib.pyplot as plt

# Load the .btf image
image_path = r"R:\FIVE\EXP\FIV925\Additional Datasets\Human Colon Cancer\Visium_HD_Human_Colon_Cancer_tissue_image.btf"
image = imageio.imread(image_path)

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide the axis
plt.show()
# Out:
# C:\Users\FIVE\AppData\Local\Temp\ipykernel_29952\3111000836.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(image_path)
# ---------------------------------------------------------------------------
# DecompressionBombError                    Traceback (most recent call last)
# Cell In[1], line 6
#       4 # Load the .btf image
#       5 image_path = r"R:\FIVE\EXP\FIV925\Additional Datasets\Human Colon Cancer\Visium_HD_Human_Colon_Cancer_tissue_image.btf"
# ----> 6 image = imageio.imread(image_path)
#       8 # Display the image
#       9 plt.imshow(image)
#
# File c:\Users\FIVE\anaconda3\envs\btf\Lib\site-packages\imageio\__init__.py:97, in imread(uri, format, **kwargs)
#      68 """imread(uri, format=None, **kwargs)
#      69
# ...

# %%
from PIL import Image
import imageio
import matplotlib.pyplot as plt

# Increase the image size limit
Image.MAX_IMAGE_PIXELS = None

# Load the .btf image
image_path = r"R:\FIVE\EXP\FIV925\Additional Datasets\Human Colon Cancer\Visium_HD_Human_Colon_Cancer_tissue_image.btf"
image = imageio.imread(image_path)

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide the axis
plt.show()
# Out:
# C:\Users\FIVE\AppData\Local\Temp\ipykernel_29952\2900638958.py:10: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(image_path)
