# %%
from example_package_khoifish2 import example

# %%
example.add_one(15)
# Out:
# 16

# %%
from SiDoLa import SiDoLa_NS

# %%
SiDoLa_NS.infer(r"S:\Phys\FIV925 XSection\Datasets\SpinalAtlas\Dodd and Fiederling\Cropped",micro_model_path=r"R:\dB\Papers\Spatial Scales Nervous System\Models\Micro Brain\map75=0669758 yolov9c .pt idx=4 ep=8 btch=8 rnd=4229985\weights\best.pt", macro_model_path=r"R:\dB\Papers\Spatial Scales Nervous System\Models\Macro Spinal Cord\map75=0804727 YOLOv8n-seg .yaml idx=17 ep=57 btch=32 rnd=8367787\weights\best.pt")
# Out:
# micro map75=0669758 yolov9c .pt idx=4 ep=8 btch=8 rnd=4229985 Found dimensions from model: 448. Set default max_area to 30000.
# macro map75=0804727 YOLOv8n-seg .yaml idx=17 ep=57 btch=32 rnd=8367787 Found dimensions from model: 512. Set default max_area to 30000000.
# 1 ------------------------------------------------------------------
#   Running Macro Model map75=0804727 YOLOv8n-seg .yaml idx=17 ep=57 btch=32 rnd=8367787  on resized image
#
# 0: 512x512 2 0s, 5 2s, 3 3s, 2 4s, 2 5s, 2 7s, 2 8s, 2 9s, 2 10s, 2 11s, 2 12s, 2 13s, 7 14s, 3 15s, 2 16s, 3 17s, 1 18, 1 19, 3 20s, 2 21s, 4 22s, 1 23, 2 24s, 3 25s, 109.7ms
# Speed: 35.5ms preprocess, 109.7ms inference, 372.6ms postprocess per image at shape (1, 3, 512, 512)
# Making SV ensemble . .
#  Loaded data from image 3136 x 3136  m RGB  min 11  max 255
# loading  1-C1-Slide1-6_Region0007_Channel555 nm,475 nm,395 nm_Seq0051.tif
# loading  1-C2-Slide1-6_Region0007_Channel555 nm,475 nm,395 nm_Seq0051.tif
# ...
