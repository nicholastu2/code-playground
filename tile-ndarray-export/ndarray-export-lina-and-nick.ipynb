# %%
# get voronoi boundaries

# get numpy array of image
#   - get centers of nuclei in numpy array
#   - prediction.boxes.xywh.numpy()
#       - export to csv
#           - how do you export to csv?

# %%
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
import torch
from ultralytics import YOLO
from PIL import Image, ImageDraw
import numpy as np
import pandas as pd
from IPython.display import clear_output
import socket
import time
from datetime import datetime
import shutil
from random import randint
import re
import imagecodecs
import tifffile
import tensorflow as tf
from scipy.spatial import Voronoi, cKDTree
from matplotlib.path import Path
from rtree import index
from ctypes.wintypes import INT
import time
import matplotlib.pyplot as plt
from shapely.geometry import Polygon, Point
import torch, torchvision
import colorsys

print("torchvision: ", torchvision.__version__)
print('CUDA available:', torch.cuda.is_available())
# Out:
# torchvision:  0.17.2
# CUDA available: True

# %%
# is this a segmentation model
yolo_model_path = r"S:\Phys\FIV925 XSection\Datasets\Axons vs SCs\01i5\YO 384 0530 MAXI\map75=0855192 YOLOv8n-seg map75=081193 idx=4 ep=24 btch=32 rnd=2840511\weights\best.pt"
# yolo_model_path = r"S:\Phys\FIV925 XSection\Datasets\Brain\01a\YO 384 0326 MAXI\map75=0650739 yolov9c  idx=12 ep=11 btch=8 rnd=6376250\weights\best.pt"
model = YOLO(yolo_model_path)

# %%
def get_color_by_id(point_region_id, total_ids):
    hue = point_region_id / total_ids # Scale the hue by the number of unique IDs, wrapping around the hue circle
    saturation = 0.9; value = 0.9  # Keep saturation and value high for bright colors
    rgb = colorsys.hsv_to_rgb(hue, saturation, value)
    r, g, b = (int(c * 255) for c in rgb)  # Convert to 0-255 scale for RGB colors
    return (r << 16) | (g << 8) | b  # Combine into a single integer

# %%
pred_height, pred_width = 384, 384
test_rows = 2
test_cols = 2
iteration = 0
scale_factor = 1
globalID = 0
maxArea = 10000
dataset = "Human Lung Cancer"
base_path = r"R:\FIVE\EXP\FIV925\Additional Datasets"
ome_tiff_path = f"{base_path}\\{dataset}\\morphology_mip.ome.tif"
use_entire_image = True

def int24_to_rgb(objID):
    r = (objID >> 16) & 0xFF  # Extract the highest 8 bits
    g = (objID >> 8) & 0xFF   # Extract the middle 8 bits
    b = objID & 0xFF          # Extract the lowest 8 bits
    return r, g, b

def ellipse_points(cx, cy, rx, ry, n=8):
    """Generate n points along the ellipse centered at (cx, cy) with radii rx and ry."""
    angles = np.linspace(0, 2 * np.pi, n, endpoint=False)
    points = [(cx + rx * np.cos(angle), cy + ry * np.sin(angle)) for angle in angles]
    return points

def draw_polygons(draw, polygons):
    global globalID
    for polygon in polygons:
        if len(polygon) < 2:
            continue
        # color = get_color_by_id(i, len(polygons))
        # draw.polygon(polygon, fill=i, outline='white')
        globalID+=1
        # there still aren't unique identifiers for each instance of a polygon
        #   I wonder if this is because the conversion from 24 bit to 8 bit integers doesn't guarantee a unique set of 8 bit integers for each 24 bit integer 
        (r,g,b) = int24_to_rgb(globalID)
        if (globalID == 300): print(globalID,r,g,b)
        draw.polygon(polygon, fill=(r,g,b))

with tifffile.TiffFile(ome_tiff_path) as tif:
    image = tif.asarray()
    # image_dapi = image[2,:, :] # DAPI channel
    image_data = image[::2, ::2] # downsample by half

    # normalize to 8 bit
    max_val_16bit = np.max(image_data)
    image_scaled = (image_data / max_val_16bit) * 255
    image_8bit = image_scaled.astype(np.uint8)

    # create image and resize
    og_image = Image.fromarray(image_8bit, 'L')
    new_width = int(og_image.width * scale_factor); new_height = int(og_image.height * scale_factor)
    image_resized = og_image.resize((new_width, new_height), Image.LANCZOS)
    image = np.array(image_resized)
    
    start_y = pred_height * 10
    start_x = pred_width * 10
    image_height_use = pred_height * test_rows
    image_width_use = pred_width * test_cols
    
    if use_entire_image:
        start_y = 0
        start_x = 0
        image_height_use = image_resized.height + pred_height*2
        image_width_use = image_resized.width + pred_width*2
        

    big_array = np.zeros((image_width_use, image_height_use)).astype(np.int32)
    list_xywh = []
    maxValue = 0

    # as we're making predictions, we want a big array that's meant to 'contain' the whole image
    #   then insert the predictions into that big array
    # so here is where we go through the image as tiles and make the predictions
    tile_id = 0
    for i in range(start_x, image_width_use + start_x, pred_width): # section_minx, section_maxx
        for j in range(start_y, image_height_use + start_y, pred_height): # section_miny, section_maxy
            iteration += 1
            tile = image[i:i+pred_width, j:j+pred_height]
            
            tile_id += 1
            
            if tile.shape[0] == 0 or tile.shape[1] == 0:
                continue  # Skip tiles that have no width or height
            tile_as_img = Image.fromarray(tile, 'L')
            predictions = model.predict(tile_as_img, show=False, max_det=3000) # can we pass an np array?
            
            result = predictions[0]
            # draw masks onto blank image
            if result.masks is not None:
                polygons = result.masks.xy
            else:
                if result.boxes is not None:
                    ## Ellipse Version
                    polygons = []
                    for (cx, cy, w, h) in result.boxes.xywh:
                        rx = w / 2
                        ry = h / 2
                        ellipse = ellipse_points(cx, cy, rx, ry, 8)
                        if (w*h)>maxArea: continue
                        polygons.append(ellipse)
                    
                    ## Bounding Box Version
                    # xyxy = result.boxes.xyxy
                    # for (x1, y1, x2, y2) in xyxy:
                    #     polygon = [(x1, y1), (x2, y1), (x2, y2), (x1, y2)]
                    #     polygons.append(polygon)
                else:
                    print("No Polygons or Boxes"); continue
            
            blank_tile = np.zeros((pred_width, pred_height,3))
            blank_tile_as_img = Image.fromarray(blank_tile,"RGB")
            draw_tile = ImageDraw.Draw(blank_tile_as_img) 
            draw_polygons(draw_tile, polygons)
            rgb_array = np.array(blank_tile_as_img).astype(np.int32)
            #rgb_array = rgb_array.astype(np.uint32)
            int_array = np.zeros((pred_width, pred_height), dtype=np.int32)
            int_array = ((rgb_array[:,:,0] << 16) | (rgb_array[:,:,1] << 8) | rgb_array[:,:,2])
            currentMax = np.max(int_array)
            print(currentMax)
            if (currentMax > maxValue): maxValue = currentMax
            
            # need a new version of image_array where we decode the 3 channels into 1 channel
            # ok I see the issue, we can only draw the polygons on the PIL image, and I don't know a way to draw them with different values
            
            # big_array[i:i - start_y, j:j - start_x] = image_array
            try:
                if int_array[0] > i-start_y:i-start_y+tile.shape[0] or int_array[1] > tile.shape[1]
                big_array[i-start_y:i-start_y+tile.shape[0] , j-start_x:j - start_x+tile.shape[1]] = int_array
            except:
                print("ERRRORORORORORORORO")
                pass
            # big_array[i-start_y:i-start_y+tile.shape[0] , j-start_x:j - start_x+tile.shape[1]] = int_array
            
            print("iteration: ", iteration)

# cropped_array = big_array[0:image_width_use, 0:image_height_use]
# cropped_array = big_array[0:image_resized.width, 0:image_resized.height]

# Swap i/j --
# Crop the large bit_array image down to match the sizes (keep the buffer in the beginning) --
# Limit Row and Column FIRST, do that when you arent in a view that has a scatterplot
# Send e-mail to JuanRu, copy us

#   Doing the predictions on your data has been going well, but exporting the data in the format that you requested confused us for a bit
#       we think we just got it working, so here's the file, but we haven't looked at it too carefully.
            
# Save the array with a header and formatted floating-point numbers
# np.savetxt(r"R:\FIVE\EXP\FIV925\Additional Datasets\Human Lung Cancer\array.csv", big_array, delimiter=",", fmt='%.2f')
# Out:
# c:\Users\FIVE\anaconda3\envs\torch01\lib\site-packages\torch\nn\modules\module.py:1150: UserWarning: expandable_segments not supported on this platform (Triggered internally at C:\cb\pytorch_1000000000000\work\c10/cuda/CUDAAllocatorConfig.h:30.)
#   return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# 0: 384x384 (no detections), 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 21.6ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  1
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  2
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  3
#
# 0: 384x384 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  4
#
# 0: 384x384 (no detections), 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  5
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  6
#
# 0: 384x384 4 axons, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 302.4ms postprocess per image at shape (1, 3, 384, 384)
# 4
# ERRRORORORORORORORO
# iteration:  7
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  8
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  9
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  10
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  11
#
# 0: 384x384 1 axon, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 5
# ERRRORORORORORORORO
# iteration:  12
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  13
#
# 0: 384x384 1 nuclei, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 6
# ERRRORORORORORORORO
# iteration:  14
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  15
#
# 0: 384x384 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  16
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  17
#
# 0: 384x384 (no detections), 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  18
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  19
#
# 0: 384x384 (no detections), 9.8ms
# Speed: 0.8ms preprocess, 9.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  20
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  21
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  22
#
# 0: 384x384 (no detections), 11.1ms
# Speed: 0.5ms preprocess, 11.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  23
#
# 0: 384x384 (no detections), 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  24
#
# 0: 384x384 (no detections), 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  25
#
# 0: 384x384 (no detections), 11.3ms
# Speed: 0.5ms preprocess, 11.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  26
#
# 0: 384x384 (no detections), 10.6ms
# Speed: 0.5ms preprocess, 10.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  27
#
# 0: 384x256 (no detections), 147.7ms
# Speed: 0.0ms preprocess, 147.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  28
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  35
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  36
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  37
#
# 0: 384x384 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  38
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  39
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  40
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  41
#
# 0: 384x384 53 axons, 6 nucleis, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 65
# ERRRORORORORORORORO
# iteration:  42
#
# 0: 384x384 164 axons, 8 nucleis, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 237
# ERRRORORORORORORORO
# iteration:  43
#
# 0: 384x384 431 axons, 31 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 384)
# 300 0 1 44
# 696
# ERRRORORORORORORORO
# iteration:  44
#
# 0: 384x384 333 axons, 23 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 1052
# ERRRORORORORORORORO
# iteration:  45
#
# 0: 384x384 202 axons, 14 nucleis, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 1267
# ERRRORORORORORORORO
# iteration:  46
#
# 0: 384x384 98 axons, 12 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 1375
# ERRRORORORORORORORO
# iteration:  47
#
# 0: 384x384 29 axons, 1 nuclei, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 1405
# ERRRORORORORORORORO
# iteration:  48
#
# 0: 384x384 1 axon, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 1406
# ERRRORORORORORORORO
# iteration:  49
#
# 0: 384x384 (no detections), 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  50
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  51
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  52
#
# 0: 384x384 (no detections), 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  53
#
# 0: 384x384 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  54
#
# 0: 384x384 (no detections), 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  55
#
# 0: 384x384 (no detections), 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  56
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  57
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  58
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  59
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  60
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  61
#
# 0: 384x256 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  62
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  69
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  70
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  71
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  72
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  73
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  74
#
# 0: 384x384 110 axons, 11 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 1527
# ERRRORORORORORORORO
# iteration:  75
#
# 0: 384x384 789 axons, 46 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 384)
# 2357
# ERRRORORORORORORORO
# iteration:  76
#
# 0: 384x384 884 axons, 46 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 384)
# 3277
# ERRRORORORORORORORO
# iteration:  77
#
# 0: 384x384 889 axons, 44 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 384)
# 4205
# ERRRORORORORORORORO
# iteration:  78
#
# 0: 384x384 850 axons, 38 nucleis, 11.4ms
# Speed: 0.0ms preprocess, 11.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 384)
# 5087
# ERRRORORORORORORORO
# iteration:  79
#
# 0: 384x384 927 axons, 55 nucleis, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 384)
# 6061
# ERRRORORORORORORORO
# iteration:  80
#
# 0: 384x384 854 axons, 36 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 6946
# ERRRORORORORORORORO
# iteration:  81
#
# 0: 384x384 751 axons, 54 nucleis, 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 7745
# ERRRORORORORORORORO
# iteration:  82
#
# 0: 384x384 467 axons, 47 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 8259
# ERRRORORORORORORORO
# iteration:  83
#
# 0: 384x384 42 axons, 5 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 8305
# ERRRORORORORORORORO
# iteration:  84
#
# 0: 384x384 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  85
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  86
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  87
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  88
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  89
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  90
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  91
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  92
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  93
#
# 0: 384x384 (no detections), 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  94
#
# 0: 384x384 (no detections), 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  95
#
# 0: 384x256 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  96
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  103
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  104
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  105
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  106
#
# 0: 384x384 11 axons, 1 nuclei, 10.6ms
# Speed: 0.5ms preprocess, 10.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 384)
# 8317
# ERRRORORORORORORORO
# iteration:  107
#
# 0: 384x384 327 axons, 20 nucleis, 10.7ms
# Speed: 0.5ms preprocess, 10.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 384)
# 8664
# ERRRORORORORORORORO
# iteration:  108
#
# 0: 384x384 648 axons, 46 nucleis, 9.7ms
# Speed: 1.0ms preprocess, 9.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 384)
# 9353
# ERRRORORORORORORORO
# iteration:  109
#
# 0: 384x384 614 axons, 36 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 9999
# ERRRORORORORORORORO
# iteration:  110
#
# 0: 384x384 914 axons, 33 nucleis, 10.1ms
# Speed: 0.4ms preprocess, 10.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 10938
# ERRRORORORORORORORO
# iteration:  111
#
# 0: 384x384 929 axons, 41 nucleis, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 11905
# ERRRORORORORORORORO
# iteration:  112
#
# 0: 384x384 933 axons, 40 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 12874
# ERRRORORORORORORORO
# iteration:  113
#
# 0: 384x384 921 axons, 35 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 13824
# ERRRORORORORORORORO
# iteration:  114
#
# 0: 384x384 947 axons, 41 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 18.8ms postprocess per image at shape (1, 3, 384, 384)
# 14805
# ERRRORORORORORORORO
# iteration:  115
#
# 0: 384x384 895 axons, 48 nucleis, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 15742
# ERRRORORORORORORORO
# iteration:  116
#
# 0: 384x384 805 axons, 70 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 16611
# ERRRORORORORORORORO
# iteration:  117
#
# 0: 384x384 545 axons, 40 nucleis, 10.2ms
# Speed: 0.5ms preprocess, 10.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 384)
# 17190
# ERRRORORORORORORORO
# iteration:  118
#
# 0: 384x384 74 axons, 5 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 17269
# ERRRORORORORORORORO
# iteration:  119
#
# 0: 384x384 (no detections), 11.3ms
# Speed: 1.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  120
#
# 0: 384x384 (no detections), 11.2ms
# Speed: 0.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  121
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  122
#
# 0: 384x384 1 axon, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 17270
# ERRRORORORORORORORO
# iteration:  123
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  124
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  125
#
# 0: 384x384 1 axon, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 17271
# ERRRORORORORORORORO
# iteration:  126
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  127
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  128
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  129
#
# 0: 384x256 10 axons, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 256)
# 17281
# ERRRORORORORORORORO
# iteration:  130
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  137
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  138
#
# 0: 384x384 44 axons, 15 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 17340
# ERRRORORORORORORORO
# iteration:  139
#
# 0: 384x384 114 axons, 23 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 17474
# ERRRORORORORORORORO
# iteration:  140
#
# 0: 384x384 694 axons, 34 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 24.0ms postprocess per image at shape (1, 3, 384, 384)
# 18195
# ERRRORORORORORORORO
# iteration:  141
#
# 0: 384x384 707 axons, 55 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 18951
# ERRRORORORORORORORO
# iteration:  142
#
# 0: 384x384 809 axons, 42 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 19799
# ERRRORORORORORORORO
# iteration:  143
#
# 0: 384x384 807 axons, 54 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 20655
# ERRRORORORORORORORO
# iteration:  144
#
# 0: 384x384 935 axons, 27 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 21613
# ERRRORORORORORORORO
# iteration:  145
#
# 0: 384x384 707 axons, 50 nucleis, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 22369
# ERRRORORORORORORORO
# iteration:  146
#
# 0: 384x384 922 axons, 37 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 23324
# ERRRORORORORORORORO
# iteration:  147
#
# 0: 384x384 877 axons, 48 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 24245
# ERRRORORORORORORORO
# iteration:  148
#
# 0: 384x384 922 axons, 61 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 25226
# ERRRORORORORORORORO
# iteration:  149
#
# 0: 384x384 874 axons, 49 nucleis, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 384)
# 26145
# ERRRORORORORORORORO
# iteration:  150
#
# 0: 384x384 944 axons, 48 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 47.5ms postprocess per image at shape (1, 3, 384, 384)
# 27131
# ERRRORORORORORORORO
# iteration:  151
#
# 0: 384x384 836 axons, 53 nucleis, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 28017
# ERRRORORORORORORORO
# iteration:  152
#
# 0: 384x384 378 axons, 39 nucleis, 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 28426
# ERRRORORORORORORORO
# iteration:  153
#
# 0: 384x384 408 axons, 23 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 28856
# ERRRORORORORORORORO
# iteration:  154
#
# 0: 384x384 130 axons, 12 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 28996
# ERRRORORORORORORORO
# iteration:  155
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  156
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  157
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  158
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  159
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  160
#
# 0: 384x384 (no detections), 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  161
#
# 0: 384x384 (no detections), 10.3ms
# Speed: 0.5ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  162
#
# 0: 384x384 4 axons, 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 29000
# ERRRORORORORORORORO
# iteration:  163
#
# 0: 384x256 25 axons, 11.5ms
# Speed: 0.5ms preprocess, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 256)
# 29025
# ERRRORORORORORORORO
# iteration:  164
#
# 0: 384x384 (no detections), 15.5ms
# Speed: 0.6ms preprocess, 15.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  171
#
# 0: 384x384 130 axons, 16 nucleis, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 29169
# ERRRORORORORORORORO
# iteration:  172
#
# 0: 384x384 704 axons, 62 nucleis, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 29933
# ERRRORORORORORORORO
# iteration:  173
#
# 0: 384x384 156 axons, 43 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 30129
# ERRRORORORORORORORO
# iteration:  174
#
# 0: 384x384 724 axons, 49 nucleis, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 30896
# ERRRORORORORORORORO
# iteration:  175
#
# 0: 384x384 782 axons, 43 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 31715
# ERRRORORORORORORORO
# iteration:  176
#
# 0: 384x384 851 axons, 29 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 384)
# 32589
# ERRRORORORORORORORO
# iteration:  177
#
# 0: 384x384 805 axons, 38 nucleis, 9.2ms
# Speed: 1.0ms preprocess, 9.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 33421
# ERRRORORORORORORORO
# iteration:  178
#
# 0: 384x384 904 axons, 37 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 34357
# ERRRORORORORORORORO
# iteration:  179
#
# 0: 384x384 889 axons, 56 nucleis, 10.0ms
# Speed: 0.5ms preprocess, 10.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 384)
# 35297
# ERRRORORORORORORORO
# iteration:  180
#
# 0: 384x384 895 axons, 47 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 36235
# ERRRORORORORORORORO
# iteration:  181
#
# 0: 384x384 871 axons, 36 nucleis, 10.1ms
# Speed: 0.5ms preprocess, 10.1ms inference, 31.1ms postprocess per image at shape (1, 3, 384, 384)
# 37133
# ERRRORORORORORORORO
# iteration:  182
#
# 0: 384x384 862 axons, 45 nucleis, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 38035
# ERRRORORORORORORORO
# iteration:  183
#
# 0: 384x384 891 axons, 55 nucleis, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 38978
# ERRRORORORORORORORO
# iteration:  184
#
# 0: 384x384 888 axons, 47 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 39910
# ERRRORORORORORORORO
# iteration:  185
#
# 0: 384x384 917 axons, 41 nucleis, 11.3ms
# Speed: 0.0ms preprocess, 11.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 40858
# ERRRORORORORORORORO
# iteration:  186
#
# 0: 384x384 769 axons, 70 nucleis, 11.0ms
# Speed: 0.5ms preprocess, 11.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 384)
# 41689
# ERRRORORORORORORORO
# iteration:  187
#
# 0: 384x384 818 axons, 40 nucleis, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 42539
# ERRRORORORORORORORO
# iteration:  188
#
# 0: 384x384 678 axons, 59 nucleis, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 384)
# 43267
# ERRRORORORORORORORO
# iteration:  189
#
# 0: 384x384 184 axons, 22 nucleis, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 43471
# ERRRORORORORORORORO
# iteration:  190
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  191
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  192
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  193
#
# 0: 384x384 (no detections), 11.1ms
# Speed: 0.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  194
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  195
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  196
#
# 0: 384x384 (no detections), 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  197
#
# 0: 384x256 1 axon, 10.6ms
# Speed: 1.1ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 43472
# ERRRORORORORORORORO
# iteration:  198
#
# 0: 384x384 (no detections), 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  205
#
# 0: 384x384 222 axons, 30 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 384)
# 43722
# ERRRORORORORORORORO
# iteration:  206
#
# 0: 384x384 877 axons, 54 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 44650
# ERRRORORORORORORORO
# iteration:  207
#
# 0: 384x384 202 axons, 47 nucleis, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 44883
# ERRRORORORORORORORO
# iteration:  208
#
# 0: 384x384 495 axons, 38 nucleis, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 45411
# ERRRORORORORORORORO
# iteration:  209
#
# 0: 384x384 777 axons, 58 nucleis, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 46240
# ERRRORORORORORORORO
# iteration:  210
#
# 0: 384x384 871 axons, 31 nucleis, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 47136
# ERRRORORORORORORORO
# iteration:  211
#
# 0: 384x384 849 axons, 46 nucleis, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 48025
# ERRRORORORORORORORO
# iteration:  212
#
# 0: 384x384 843 axons, 38 nucleis, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 384)
# 48904
# ERRRORORORORORORORO
# iteration:  213
#
# 0: 384x384 869 axons, 43 nucleis, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 49811
# ERRRORORORORORORORO
# iteration:  214
#
# 0: 384x384 968 axons, 28 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 21.5ms postprocess per image at shape (1, 3, 384, 384)
# 50800
# ERRRORORORORORORORO
# iteration:  215
#
# 0: 384x384 873 axons, 41 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 51704
# ERRRORORORORORORORO
# iteration:  216
#
# 0: 384x384 995 axons, 51 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 384)
# 52745
# ERRRORORORORORORORO
# iteration:  217
#
# 0: 384x384 935 axons, 56 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 53731
# ERRRORORORORORORORO
# iteration:  218
#
# 0: 384x384 763 axons, 60 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 54549
# ERRRORORORORORORORO
# iteration:  219
#
# 0: 384x384 778 axons, 58 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 55378
# ERRRORORORORORORORO
# iteration:  220
#
# 0: 384x384 887 axons, 72 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 56327
# ERRRORORORORORORORO
# iteration:  221
#
# 0: 384x384 948 axons, 40 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 384)
# 57308
# ERRRORORORORORORORO
# iteration:  222
#
# 0: 384x384 885 axons, 57 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 58243
# ERRRORORORORORORORO
# iteration:  223
#
# 0: 384x384 757 axons, 48 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 59038
# ERRRORORORORORORORO
# iteration:  224
#
# 0: 384x384 293 axons, 26 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 59356
# ERRRORORORORORORORO
# iteration:  225
#
# 0: 384x384 8 axons, 1 nuclei, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 59364
# ERRRORORORORORORORO
# iteration:  226
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  227
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  228
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  229
#
# 0: 384x384 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  230
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  231
#
# 0: 384x256 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  232
#
# 0: 384x384 (no detections), 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  239
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  240
#
# 0: 384x384 532 axons, 73 nucleis, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 21.0ms postprocess per image at shape (1, 3, 384, 384)
# 59964
# ERRRORORORORORORORO
# iteration:  241
#
# 0: 384x384 562 axons, 62 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 60585
# ERRRORORORORORORORO
# iteration:  242
#
# 0: 384x384 888 axons, 44 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 61510
# ERRRORORORORORORORO
# iteration:  243
#
# 0: 384x384 820 axons, 51 nucleis, 11.0ms
# Speed: 0.5ms preprocess, 11.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 384)
# 62374
# ERRRORORORORORORORO
# iteration:  244
#
# 0: 384x384 817 axons, 35 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 63213
# ERRRORORORORORORORO
# iteration:  245
#
# 0: 384x384 790 axons, 35 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 384)
# 64034
# ERRRORORORORORORORO
# iteration:  246
#
# 0: 384x384 840 axons, 34 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 64904
# ERRRORORORORORORORO
# iteration:  247
#
# 0: 384x384 843 axons, 39 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 65781
# ERRRORORORORORORORO
# iteration:  248
#
# 0: 384x384 924 axons, 41 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 66740
# ERRRORORORORORORORO
# iteration:  249
#
# 0: 384x384 804 axons, 45 nucleis, 9.9ms
# Speed: 0.5ms preprocess, 9.9ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 384)
# 67587
# ERRRORORORORORORORO
# iteration:  250
#
# 0: 384x384 901 axons, 42 nucleis, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 32.2ms postprocess per image at shape (1, 3, 384, 384)
# 68527
# ERRRORORORORORORORO
# iteration:  251
#
# 0: 384x384 915 axons, 56 nucleis, 10.2ms
# Speed: 0.5ms preprocess, 10.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 384)
# 69493
# ERRRORORORORORORORO
# iteration:  252
#
# 0: 384x384 792 axons, 69 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 70345
# ERRRORORORORORORORO
# iteration:  253
#
# 0: 384x384 830 axons, 61 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 71227
# ERRRORORORORORORORO
# iteration:  254
#
# 0: 384x384 881 axons, 81 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 72185
# ERRRORORORORORORORO
# iteration:  255
#
# 0: 384x384 912 axons, 70 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 73162
# ERRRORORORORORORORO
# iteration:  256
#
# 0: 384x384 1025 axons, 63 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 21.0ms postprocess per image at shape (1, 3, 384, 384)
# 74239
# ERRRORORORORORORORO
# iteration:  257
#
# 0: 384x384 887 axons, 72 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 75193
# ERRRORORORORORORORO
# iteration:  258
#
# 0: 384x384 835 axons, 42 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 76059
# ERRRORORORORORORORO
# iteration:  259
#
# 0: 384x384 335 axons, 16 nucleis, 9.9ms
# Speed: 0.6ms preprocess, 9.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 384)
# 76406
# ERRRORORORORORORORO
# iteration:  260
#
# 0: 384x384 125 axons, 13 nucleis, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 76543
# ERRRORORORORORORORO
# iteration:  261
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  262
#
# 0: 384x384 3 axons, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 76546
# ERRRORORORORORORORO
# iteration:  263
#
# 0: 384x384 10 axons, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 76556
# ERRRORORORORORORORO
# iteration:  264
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  265
#
# 0: 384x256 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  266
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  273
#
# 0: 384x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  274
#
# 0: 384x384 332 axons, 29 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 76913
# ERRRORORORORORORORO
# iteration:  275
#
# 0: 384x384 931 axons, 39 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 77873
# ERRRORORORORORORORO
# iteration:  276
#
# 0: 384x384 937 axons, 43 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 78845
# ERRRORORORORORORORO
# iteration:  277
#
# 0: 384x384 902 axons, 36 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 79776
# ERRRORORORORORORORO
# iteration:  278
#
# 0: 384x384 837 axons, 53 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 30.1ms postprocess per image at shape (1, 3, 384, 384)
# 80661
# ERRRORORORORORORORO
# iteration:  279
#
# 0: 384x384 766 axons, 43 nucleis, 9.5ms
# Speed: 1.1ms preprocess, 9.5ms inference, 27.6ms postprocess per image at shape (1, 3, 384, 384)
# 81468
# ERRRORORORORORORORO
# iteration:  280
#
# 0: 384x384 827 axons, 47 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 29.0ms postprocess per image at shape (1, 3, 384, 384)
# 82339
# ERRRORORORORORORORO
# iteration:  281
#
# 0: 384x384 834 axons, 33 nucleis, 10.4ms
# Speed: 0.8ms preprocess, 10.4ms inference, 29.4ms postprocess per image at shape (1, 3, 384, 384)
# 83201
# ERRRORORORORORORORO
# iteration:  282
#
# 0: 384x384 814 axons, 60 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 29.0ms postprocess per image at shape (1, 3, 384, 384)
# 84065
# ERRRORORORORORORORO
# iteration:  283
#
# 0: 384x384 752 axons, 73 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 28.0ms postprocess per image at shape (1, 3, 384, 384)
# 84885
# ERRRORORORORORORORO
# iteration:  284
#
# 0: 384x384 919 axons, 57 nucleis, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 32.2ms postprocess per image at shape (1, 3, 384, 384)
# 85853
# ERRRORORORORORORORO
# iteration:  285
#
# 0: 384x384 860 axons, 48 nucleis, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 30.5ms postprocess per image at shape (1, 3, 384, 384)
# 86749
# ERRRORORORORORORORO
# iteration:  286
#
# 0: 384x384 845 axons, 59 nucleis, 10.2ms
# Speed: 0.6ms preprocess, 10.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 384)
# 87639
# ERRRORORORORORORORO
# iteration:  287
#
# 0: 384x384 830 axons, 49 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 88513
# ERRRORORORORORORORO
# iteration:  288
#
# 0: 384x384 929 axons, 73 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 89509
# ERRRORORORORORORORO
# iteration:  289
#
# 0: 384x384 937 axons, 49 nucleis, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 90482
# ERRRORORORORORORORO
# iteration:  290
#
# 0: 384x384 965 axons, 63 nucleis, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 91502
# ERRRORORORORORORORO
# iteration:  291
#
# 0: 384x384 1022 axons, 61 nucleis, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 92581
# ERRRORORORORORORORO
# iteration:  292
#
# 0: 384x384 888 axons, 51 nucleis, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 93514
# ERRRORORORORORORORO
# iteration:  293
#
# 0: 384x384 418 axons, 51 nucleis, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 384)
# 93979
# ERRRORORORORORORORO
# iteration:  294
#
# 0: 384x384 753 axons, 48 nucleis, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 94774
# ERRRORORORORORORORO
# iteration:  295
#
# 0: 384x384 399 axons, 26 nucleis, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 95197
# ERRRORORORORORORORO
# iteration:  296
#
# 0: 384x384 659 axons, 32 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 95884
# ERRRORORORORORORORO
# iteration:  297
#
# 0: 384x384 729 axons, 31 nucleis, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 384)
# 96643
# ERRRORORORORORORORO
# iteration:  298
#
# 0: 384x384 112 axons, 9 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 96763
# ERRRORORORORORORORO
# iteration:  299
#
# 0: 384x256 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  300
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  307
#
# 0: 384x384 17 axons, 5 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 96785
# ERRRORORORORORORORO
# iteration:  308
#
# 0: 384x384 693 axons, 33 nucleis, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 97503
# ERRRORORORORORORORO
# iteration:  309
#
# 0: 384x384 703 axons, 56 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 98260
# ERRRORORORORORORORO
# iteration:  310
#
# 0: 384x384 786 axons, 56 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 99095
# ERRRORORORORORORORO
# iteration:  311
#
# 0: 384x384 909 axons, 50 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 31.5ms postprocess per image at shape (1, 3, 384, 384)
# 100045
# ERRRORORORORORORORO
# iteration:  312
#
# 0: 384x384 853 axons, 42 nucleis, 10.0ms
# Speed: 1.1ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 100936
# ERRRORORORORORORORO
# iteration:  313
#
# 0: 384x384 855 axons, 40 nucleis, 9.8ms
# Speed: 0.5ms preprocess, 9.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 384)
# 101827
# ERRRORORORORORORORO
# iteration:  314
#
# 0: 384x384 912 axons, 39 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 384)
# 102771
# ERRRORORORORORORORO
# iteration:  315
#
# 0: 384x384 754 axons, 45 nucleis, 9.9ms
# Speed: 0.5ms preprocess, 9.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 384)
# 103562
# ERRRORORORORORORORO
# iteration:  316
#
# 0: 384x384 931 axons, 45 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 104531
# ERRRORORORORORORORO
# iteration:  317
#
# 0: 384x384 976 axons, 54 nucleis, 9.5ms
# Speed: 1.3ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 105554
# ERRRORORORORORORORO
# iteration:  318
#
# 0: 384x384 964 axons, 54 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 106560
# ERRRORORORORORORORO
# iteration:  319
#
# 0: 384x384 871 axons, 47 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 107473
# ERRRORORORORORORORO
# iteration:  320
#
# 0: 384x384 847 axons, 49 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 108363
# ERRRORORORORORORORO
# iteration:  321
#
# 0: 384x384 907 axons, 43 nucleis, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 109306
# ERRRORORORORORORORO
# iteration:  322
#
# 0: 384x384 885 axons, 70 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 110257
# ERRRORORORORORORORO
# iteration:  323
#
# 0: 384x384 522 axons, 55 nucleis, 10.0ms
# Speed: 0.5ms preprocess, 10.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 384)
# 110831
# ERRRORORORORORORORO
# iteration:  324
#
# 0: 384x384 916 axons, 56 nucleis, 9.9ms
# Speed: 0.6ms preprocess, 9.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 111801
# ERRRORORORORORORORO
# iteration:  325
#
# ...
# iteration:  908
#
# 0: 384x384 825 axons, 27 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 541809
# ERRRORORORORORORORO
# iteration:  909
#
# 0: 384x384 883 axons, 32 nucleis, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 542720
# ERRRORORORORORORORO
# iteration:  910
#
# 0: 384x384 947 axons, 41 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 543703
# ERRRORORORORORORORO
# iteration:  911
#
# 0: 384x256 550 axons, 41 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 256)
# 544290
# ERRRORORORORORORORO
# iteration:  912
#
# 0: 384x384 155 axons, 45 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 544488
# ERRRORORORORORORORO
# iteration:  919
#
# 0: 384x384 675 axons, 53 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 545211
# ERRRORORORORORORORO
# iteration:  920
#
# 0: 384x384 836 axons, 54 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 546098
# ERRRORORORORORORORO
# iteration:  921
#
# 0: 384x384 214 axons, 53 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 546362
# ERRRORORORORORORORO
# iteration:  922
#
# 0: 384x384 693 axons, 62 nucleis, 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 26.5ms postprocess per image at shape (1, 3, 384, 384)
# 547114
# ERRRORORORORORORORO
# iteration:  923
#
# 0: 384x384 842 axons, 49 nucleis, 9.3ms
# Speed: 0.5ms preprocess, 9.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 548002
# ERRRORORORORORORORO
# iteration:  924
#
# 0: 384x384 876 axons, 79 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 548945
# ERRRORORORORORORORO
# iteration:  925
#
# 0: 384x384 918 axons, 74 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 33.5ms postprocess per image at shape (1, 3, 384, 384)
# 549927
# ERRRORORORORORORORO
# iteration:  926
#
# 0: 384x384 851 axons, 59 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 550832
# ERRRORORORORORORORO
# iteration:  927
#
# 0: 384x384 765 axons, 60 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 551651
# ERRRORORORORORORORO
# iteration:  928
#
# 0: 384x384 476 axons, 57 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 552180
# ERRRORORORORORORORO
# iteration:  929
#
# 0: 384x384 565 axons, 43 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 552781
# ERRRORORORORORORORO
# iteration:  930
#
# 0: 384x384 993 axons, 60 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 553829
# ERRRORORORORORORORO
# iteration:  931
#
# 0: 384x384 955 axons, 42 nucleis, 10.9ms
# Speed: 1.1ms preprocess, 10.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 384)
# 554823
# ERRRORORORORORORORO
# iteration:  932
#
# 0: 384x384 765 axons, 52 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 555636
# ERRRORORORORORORORO
# iteration:  933
#
# 0: 384x384 871 axons, 52 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 556554
# ERRRORORORORORORORO
# iteration:  934
#
# 0: 384x384 955 axons, 58 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 384)
# 557562
# ERRRORORORORORORORO
# iteration:  935
#
# 0: 384x384 805 axons, 58 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 558419
# ERRRORORORORORORORO
# iteration:  936
#
# 0: 384x384 836 axons, 63 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 559314
# ERRRORORORORORORORO
# iteration:  937
#
# 0: 384x384 726 axons, 58 nucleis, 9.2ms
# Speed: 0.5ms preprocess, 9.2ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 384)
# 560094
# ERRRORORORORORORORO
# iteration:  938
#
# 0: 384x384 833 axons, 46 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 560967
# ERRRORORORORORORORO
# iteration:  939
#
# 0: 384x384 794 axons, 39 nucleis, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 27.8ms postprocess per image at shape (1, 3, 384, 384)
# 561795
# ERRRORORORORORORORO
# iteration:  940
#
# 0: 384x384 756 axons, 37 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 26.7ms postprocess per image at shape (1, 3, 384, 384)
# 562582
# ERRRORORORORORORORO
# iteration:  941
#
# 0: 384x384 426 axons, 23 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 384)
# 563029
# ERRRORORORORORORORO
# iteration:  942
#
# 0: 384x384 933 axons, 37 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 563992
# ERRRORORORORORORORO
# iteration:  943
#
# 0: 384x384 761 axons, 59 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 27.5ms postprocess per image at shape (1, 3, 384, 384)
# 564806
# ERRRORORORORORORORO
# iteration:  944
#
# 0: 384x384 816 axons, 56 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 565670
# ERRRORORORORORORORO
# iteration:  945
#
# 0: 384x256 610 axons, 41 nucleis, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 256)
# 566320
# ERRRORORORORORORORO
# iteration:  946
#
# 0: 384x384 658 axons, 70 nucleis, 10.0ms
# Speed: 0.8ms preprocess, 10.0ms inference, 25.1ms postprocess per image at shape (1, 3, 384, 384)
# 567043
# ERRRORORORORORORORO
# iteration:  953
#
# 0: 384x384 924 axons, 52 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 568017
# ERRRORORORORORORORO
# iteration:  954
#
# 0: 384x384 601 axons, 77 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 23.0ms postprocess per image at shape (1, 3, 384, 384)
# 568689
# ERRRORORORORORORORO
# iteration:  955
#
# 0: 384x384 392 axons, 65 nucleis, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 569143
# ERRRORORORORORORORO
# iteration:  956
#
# 0: 384x384 727 axons, 62 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 56.6ms postprocess per image at shape (1, 3, 384, 384)
# 569927
# ERRRORORORORORORORO
# iteration:  957
#
# 0: 384x384 625 axons, 56 nucleis, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 23.0ms postprocess per image at shape (1, 3, 384, 384)
# 570603
# ERRRORORORORORORORO
# iteration:  958
#
# 0: 384x384 800 axons, 70 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 29.6ms postprocess per image at shape (1, 3, 384, 384)
# 571470
# ERRRORORORORORORORO
# iteration:  959
#
# 0: 384x384 879 axons, 63 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 31.6ms postprocess per image at shape (1, 3, 384, 384)
# 572407
# ERRRORORORORORORORO
# iteration:  960
#
# 0: 384x384 800 axons, 70 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 29.5ms postprocess per image at shape (1, 3, 384, 384)
# 573271
# ERRRORORORORORORORO
# iteration:  961
#
# 0: 384x384 445 axons, 67 nucleis, 9.9ms
# Speed: 1.0ms preprocess, 9.9ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 384)
# 573776
# ERRRORORORORORORORO
# iteration:  962
#
# 0: 384x384 533 axons, 38 nucleis, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 19.6ms postprocess per image at shape (1, 3, 384, 384)
# 574344
# ERRRORORORORORORORO
# iteration:  963
#
# 0: 384x384 748 axons, 51 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 26.5ms postprocess per image at shape (1, 3, 384, 384)
# 575136
# ERRRORORORORORORORO
# iteration:  964
#
# 0: 384x384 937 axons, 38 nucleis, 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 31.7ms postprocess per image at shape (1, 3, 384, 384)
# 576109
# ERRRORORORORORORORO
# iteration:  965
#
# 0: 384x384 882 axons, 50 nucleis, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 30.5ms postprocess per image at shape (1, 3, 384, 384)
# 577040
# ERRRORORORORORORORO
# iteration:  966
#
# 0: 384x384 812 axons, 51 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 29.1ms postprocess per image at shape (1, 3, 384, 384)
# 577895
# ERRRORORORORORORORO
# iteration:  967
#
# 0: 384x384 759 axons, 45 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 27.8ms postprocess per image at shape (1, 3, 384, 384)
# 578691
# ERRRORORORORORORORO
# iteration:  968
#
# 0: 384x384 751 axons, 47 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 25.6ms postprocess per image at shape (1, 3, 384, 384)
# 579485
# ERRRORORORORORORORO
# iteration:  969
#
# 0: 384x384 766 axons, 60 nucleis, 9.9ms
# Speed: 1.0ms preprocess, 9.9ms inference, 59.5ms postprocess per image at shape (1, 3, 384, 384)
# 580307
# ERRRORORORORORORORO
# iteration:  970
#
# 0: 384x384 988 axons, 48 nucleis, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 384)
# 581337
# ERRRORORORORORORORO
# iteration:  971
#
# 0: 384x384 814 axons, 43 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 582192
# ERRRORORORORORORORO
# iteration:  972
#
# 0: 384x384 659 axons, 41 nucleis, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 582885
# ERRRORORORORORORORO
# iteration:  973
#
# 0: 384x384 247 axons, 29 nucleis, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 583155
# ERRRORORORORORORORO
# iteration:  974
#
# 0: 384x384 19 axons, 2 nucleis, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 583176
# ERRRORORORORORORORO
# iteration:  975
#
# 0: 384x384 260 axons, 18 nucleis, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 384)
# 583453
# ERRRORORORORORORORO
# iteration:  976
#
# 0: 384x384 722 axons, 38 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 584210
# ERRRORORORORORORORO
# iteration:  977
#
# 0: 384x384 866 axons, 34 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 585104
# ERRRORORORORORORORO
# iteration:  978
#
# 0: 384x384 974 axons, 43 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 384)
# 586116
# ERRRORORORORORORORO
# iteration:  979
#
# 0: 384x256 616 axons, 30 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 256)
# 586757
# ERRRORORORORORORORO
# iteration:  980
#
# 0: 384x384 463 axons, 42 nucleis, 10.6ms
# Speed: 0.5ms preprocess, 10.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 384)
# 587253
# ERRRORORORORORORORO
# iteration:  987
#
# 0: 384x384 891 axons, 54 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 588194
# ERRRORORORORORORORO
# iteration:  988
#
# 0: 384x384 253 axons, 67 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 588509
# ERRRORORORORORORORO
# iteration:  989
#
# 0: 384x384 854 axons, 40 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 589400
# ERRRORORORORORORORO
# iteration:  990
#
# 0: 384x384 809 axons, 66 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 590272
# ERRRORORORORORORORO
# iteration:  991
#
# 0: 384x384 420 axons, 71 nucleis, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 590761
# ERRRORORORORORORORO
# iteration:  992
#
# 0: 384x384 753 axons, 70 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 591578
# ERRRORORORORORORORO
# iteration:  993
#
# 0: 384x384 770 axons, 53 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 592395
# ERRRORORORORORORORO
# iteration:  994
#
# 0: 384x384 931 axons, 50 nucleis, 9.5ms
# Speed: 1.1ms preprocess, 9.5ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 593373
# ERRRORORORORORORORO
# iteration:  995
#
# 0: 384x384 412 axons, 48 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 593828
# ERRRORORORORORORORO
# iteration:  996
#
# 0: 384x384 566 axons, 49 nucleis, 10.0ms
# Speed: 0.5ms preprocess, 10.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 384)
# 594439
# ERRRORORORORORORORO
# iteration:  997
#
# 0: 384x384 667 axons, 47 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 595149
# ERRRORORORORORORORO
# iteration:  998
#
# 0: 384x384 682 axons, 54 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 595880
# ERRRORORORORORORORO
# iteration:  999
#
# 0: 384x384 810 axons, 51 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 596734
# ERRRORORORORORORORO
# iteration:  1000
#
# 0: 384x384 800 axons, 53 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 384)
# 597582
# ERRRORORORORORORORO
# iteration:  1001
#
# 0: 384x384 737 axons, 40 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 598357
# ERRRORORORORORORORO
# iteration:  1002
#
# 0: 384x384 603 axons, 54 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 599003
# ERRRORORORORORORORO
# iteration:  1003
#
# 0: 384x384 862 axons, 49 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 384)
# 599910
# ERRRORORORORORORORO
# iteration:  1004
#
# 0: 384x384 971 axons, 31 nucleis, 9.0ms
# Speed: 1.1ms preprocess, 9.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 384)
# 600903
# ERRRORORORORORORORO
# iteration:  1005
#
# 0: 384x384 752 axons, 37 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 601688
# ERRRORORORORORORORO
# iteration:  1006
#
# 0: 384x384 415 axons, 26 nucleis, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 602126
# ERRRORORORORORORORO
# iteration:  1007
#
# 0: 384x384 147 axons, 11 nucleis, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 602281
# ERRRORORORORORORORO
# iteration:  1008
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  1009
#
# 0: 384x384 145 axons, 16 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 602441
# ERRRORORORORORORORO
# iteration:  1010
#
# 0: 384x384 217 axons, 8 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 384)
# 602663
# ERRRORORORORORORORO
# iteration:  1011
#
# 0: 384x384 267 axons, 11 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 384)
# 602941
# ERRRORORORORORORORO
# iteration:  1012
#
# 0: 384x384 259 axons, 19 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 603216
# ERRRORORORORORORORO
# iteration:  1013
#
# 0: 384x256 122 axons, 14 nucleis, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 603349
# ERRRORORORORORORORO
# iteration:  1014

# %%
print(np.max(big_array))
# Out:
# 0

# %%
big_array[i-start_y:i-start_y+tile.shape[0] , j-start_x:j - start_x+tile.shape[1]].shape

# %%
cropped_array = big_array[0:image_resized.height - 384, 0:image_resized.width - 384]
Image.fromarray(cropped_array).show()

# %%
cropped_array.shape

# %%
np.savetxt(r"R:\FIVE\EXP\FIV925\Additional Datasets\Human Lung Cancer\array_2x2b.csv", cropped_array, delimiter=",")#, fmt='%.2f')
