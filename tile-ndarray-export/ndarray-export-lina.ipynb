# %%
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
import torch
from ultralytics import YOLO
from PIL import Image, ImageDraw
import numpy as np
import pandas as pd
from IPython.display import clear_output
import socket
import time
from datetime import datetime
import shutil
from random import randint
import re
import imagecodecs
import tifffile
from scipy.spatial import Voronoi, cKDTree
from matplotlib.path import Path
from rtree import index
from ctypes.wintypes import INT
import time
import matplotlib.pyplot as plt
from shapely.geometry import Polygon, Point

# %%
# Functions
idx = index.Index()

def sanitize_for_filesystem(input_string, len = 6):
    safe_string = re.sub(r'[^a-zA-Z0-9]', '', input_string)
    return safe_string[:len]

def save_tile_results(res2, save_path, max_tile_cols = 6, divider_width = 4, show=False):
    divider_color = (255, 0, 0)  # Divider color in RGB (red in this example)

    def calculate_canvas_size(images, max_cols, img_width, img_height, divider_width):
        #rows = (len(images) + max_cols - 1) // max_cols
        canvas_width = (img_width + divider_width) * min(len(images), max_cols) - divider_width
        canvas_height = (img_height * 2 + divider_width) #* rows - divider_width
        return canvas_width, canvas_height

    image_pairs = []

    for result in res2:
        img_orig = result.orig_img
        img_labeled = result.plot(labels=False, conf=False)
        img_orig_pil = Image.fromarray(img_orig)
        img_labeled_pil = Image.fromarray(img_labeled)
        image_pairs.append((img_orig_pil, img_labeled_pil))

    if not image_pairs:
        print("No images to display.")
    else:
        img_width, img_height = image_pairs[0][0].size
        canvas_width, canvas_height = calculate_canvas_size(image_pairs, max_tile_cols, img_width, img_height, divider_width)
        canvas = Image.new('RGB', (canvas_width, canvas_height), "white")
        draw = ImageDraw.Draw(canvas)

        for i, (img_orig, img_labeled) in enumerate(image_pairs[:max_tile_cols]):
            col = i % max_tile_cols; row = i // max_tile_cols
            top_left_x = col * (img_width + divider_width); top_left_y = row * (img_height * 2 + divider_width)
            canvas.paste(img_orig, (top_left_x, top_left_y))
            canvas.paste(img_labeled, (top_left_x, top_left_y + img_height + divider_width))

            # if col > 0:
            #     draw.line([(1+ top_left_x - divider_width, top_left_y), (1+top_left_x - divider_width, top_left_y + img_height * 2)], fill=divider_color, width=divider_width)
            #     draw.line([(0, top_left_y - divider_width), (canvas_width, top_left_y - divider_width)], fill=divider_color, width=divider_width)
        if (show): display(canvas)
        if (save_path!=""): canvas.save(save_path)

def results_toDF(res2, addIDCol = False):
    data = []
    for result in res2:
        boxes = result.boxes
        inst = 0
        for box in boxes:
            x, y, w, h = box.xywh[0].tolist()
            inst += 1
            data.append({
                'path': result.path,
                'Filename' : os.path.basename(result.path),
                'Instance' : inst,
                'Class': box.cls[0].item(),
                'Conf': box.conf[0].item(),
                'x': x, 'y': y,
                'w': w, 'h': h,
                'xc' : x + w/2,
                'yc' : y + h/2,
                'Circ Area' : (0.858 * w * h)
            })
    df = pd.DataFrame(data)
    if (addIDCol): 
        df['ID'] = df.groupby('path').cumcount()
    return df

def results_toCSV(res2, save_path):
    df = results_toDF(res2)
    df.to_csv(save_path, index=False)


def create_polygon_from_vertices(vertices):
            return Polygon(vertices)

# Function to find Voronoi region for a point
def find_voronoi_region(point, idx):
    point_geom = Point(point)
    for point_region_id in idx.intersection(point_geom.bounds):
        # Verify if point is actually in the Voronoi region
        if region_paths[point_region_id].contains_point(point):
            return point_region_id
    return -1

def is_point_in_ellipse(x, y, center_x, center_y, semi_major, semi_minor): ## calcualte the position of the point (trx) relative to ellipse center
    normalized_x = (x - center_x) / semi_major
    normalized_y = (y - center_y) / semi_minor
    return (normalized_x ** 2 + normalized_y ** 2) <= 1 ## if nx^2 + ny^2 <1, then point is within elliipse (is_within == True)

def save_tile_results(res2, save_path, max_tile_cols = 6, divider_width = 4, show=False):
    divider_color = (255, 0, 0)  # Divider color in RGB (red in this example)

    def calculate_canvas_size(images, max_cols, img_width, img_height, divider_width):
        #rows = (len(images) + max_cols - 1) // max_cols
        canvas_width = (img_width + divider_width) * min(len(images), max_cols) - divider_width
        canvas_height = (img_height * 2 + divider_width) #* rows - divider_width
        return canvas_width, canvas_height

    image_pairs = []

    for result in res2:
        img_orig = result.orig_img
        img_labeled = result.plot(labels=False, conf=False)
        img_orig_pil = Image.fromarray(img_orig)
        img_labeled_pil = Image.fromarray(img_labeled)
        image_pairs.append((img_orig_pil, img_labeled_pil))

    if not image_pairs:
        print("No images to display.")
    else:
        img_width, img_height = image_pairs[0][0].size
        canvas_width, canvas_height = calculate_canvas_size(image_pairs, max_tile_cols, img_width, img_height, divider_width)
        canvas = Image.new('RGB', (canvas_width, canvas_height), "white")
        draw = ImageDraw.Draw(canvas)

        for i, (img_orig, img_labeled) in enumerate(image_pairs[:max_tile_cols]):
            col = i % max_tile_cols; row = i // max_tile_cols
            top_left_x = col * (img_width + divider_width); top_left_y = row * (img_height * 2 + divider_width)
            canvas.paste(img_orig, (top_left_x, top_left_y))
            canvas.paste(img_labeled, (top_left_x, top_left_y + img_height + divider_width))

            # if col > 0:
            #     draw.line([(1+ top_left_x - divider_width, top_left_y), (1+top_left_x - divider_width, top_left_y + img_height * 2)], fill=divider_color, width=divider_width)
            #     draw.line([(0, top_left_y - divider_width), (canvas_width, top_left_y - divider_width)], fill=divider_color, width=divider_width)
        if (show): display(canvas)
        if (save_path!=""): canvas.save(save_path)

# %%
# Define datatset and base path
dataset = "Human Lung Cancer"
base_path = r"R:\FIVE\EXP\FIV925\Additional Datasets"
tile_base_path = r"S:\Phys\FIV925 XSection\Datasets\Additional Datasets"

# path for image
ome_tiff_path = f"{base_path}\\{dataset}\\morphology_mip.ome.tif"
preview_path = f"{base_path}\\{dataset}\\downsample.png"

# path for YOLO model
yolo_model_path = r"S:\Phys\FIV925 XSection\Datasets\Axons vs SCs\01i5\YO 384 0530 MAXI\map75=0855192 YOLOv8n-seg map75=081193 idx=4 ep=24 btch=32 rnd=2840511\weights\best.pt"
# r"S:\Phys\FIV925 XSection\Datasets\Axons vs SCs\01i3\M 384 MAXI 0213\0966245 idx=6 ep=98 mType=0 rnd=7669543\weights\best.pt"
# r"S:\Phys\FIV925 XSection\Datasets\Brain\01a\YO 384 0326 MAXI\map75=0650739 yolov9c  idx=12 ep=11 btch=8 rnd=6376250\weights\best.pt"
# r"S:\Phys\FIV925 XSection\Datasets\Axons vs SCs\01i5\YO 384 0530 MAXI\map75=0855192 YOLOv8n-seg map75=081193 idx=4 ep=24 btch=32 rnd=2840511\weights\best.pt"

# path for transcripts
transcripts = f"{base_path}\\{dataset}\\transcripts.csv"

# save path 
pred_save_path = f"{base_path}\\{dataset}\\results.csv"
tile_save_path = f"{tile_base_path}\\{dataset}"

# save tiles?
save_tiles = True

# conversion from um to pixel
um_to_pixel_div = 0.425 # divisor for um -> pixel conversion. 1 pixel = 0.425 um

# image level 
lvl = 1

# Optional:  define boundaries for cross section of interest (in pixel coord)
section_minx = 5427; section_maxx = 7027
section_miny = int(3000/um_to_pixel_div); section_maxy = int(8800/um_to_pixel_div)

# %%
# For Human Lung Cancer
save_level = f"{base_path}\\{dataset}\\downsample.bmp"
with tifffile.TiffFile(ome_tiff_path) as tif:
    #full_size_image = tif.asarray() #If you want the full sized image
    # image = tif.asarray(series=0, level=1) # 27K x 21K
    image = tif.asarray() # 14K x 10K
    image_dapi = image[2,...]
    downsampled_image = image[::2, ::2] #1770 ish, very manageable
    # metadata = tif.ome_metadata

# what does sca mean?
sca = downsampled_image / np.quantile(downsampled_image,0.99) # rescale the intensity, if we use max it is way to far outside
sca[sca > 1] = 1
plt.imshow(sca, cmap='gray')
plt.axis('off')  # to hide axis labels and ticks
# Out:
# (-0.5, 10616.5, 12048.5, -0.5)

# %%
# infer
def results_toDF(res2, offset_x, offset_y, addIDCol = False):
    data = []
    for result in res2:
        boxes = result.boxes
        inst = 0
        for box in boxes:
            x, y, w, h = box.xywh[0].tolist()
            inst += 1
            data.append({
                'path': result.path,
                'Filename' : os.path.basename(result.path),
                'Instance' : inst,
                'Class': box.cls[0].item(),
                'Conf': box.conf[0].item(),
                'x': x, 'y': y,
                'w': w, 'h': h,
                'x_global': x + offset_x,
                'y_global': y + offset_y,
                'xc' : x + w/2,
                'yc' : y + h/2,
                'Circ Area' : (0.858 * w * h)
            })
    df = pd.DataFrame(data)
    if (addIDCol): 
        df['ID'] = df.groupby('path').cumcount()
    return df

iteration = 0
tile_size = 384
scale_factor = 1
tile_save_path = r"S:\Phys\FIV925 XSection\Datasets\Human Lung\Infer\Prediction Tiles"
save_tiles = False

df = pd.DataFrame()
model = YOLO(yolo_model_path)

tif = tifffile.TiffFile(ome_tiff_path)

# so this is an ndarray
#   (3000, 3200, 3)
#       wait, no, this was for the Colon Cancer data, but it wasn't working
# what do the numbers in the array represent?
#   i'm assuming each list of 3 is the RGB info
image = tif.asarray()

# image_dapi = image[2,:, :] # DAPI channel
#   I'm not sure if this is actually the DAPI channel

# what does this mean?
#   take every second row and column
# ok, so what's the image made of in the first place?
image_data = image[::2, ::2] # downsample by half

# normalize to 8 bit
max_val_16bit = np.max(image_data)
image_scaled = (image_data / max_val_16bit) * 255
image_8bit = image_scaled.astype(np.uint8)
#   wait, but the max value in image_data is 255, so isn't image_data already 8 bit?
#       it's 8 bits per channel, so 24 bit
#   bruh image_8bit and image_data are equal because image_data is already 8 bit

# create image and resize
og_image = Image.fromarray(image_8bit, 'L')
new_width = int(og_image.width * scale_factor); new_height = int(og_image.height * scale_factor)
image_resized = og_image.resize((new_width, new_height), Image.LANCZOS)
image = np.array(image_resized)

image_height, image_width = image_resized.size

for i in range(0, image_height, 384): # section_miny, section_maxy
    for j in range(0, image_width, 384): # section_minx, section_maxx
        tile = image[i:i+tile_size, j:j+tile_size]
        
        if tile.shape[0] == 0 or tile.shape[1] == 0:
            continue  # Skip tiles that have no width or height
        tile_as_img = Image.fromarray(tile, 'L')
        prediction = model.predict(tile_as_img, show=False, max_det=3000)
        iteration += 1
        print(iteration)

        # save out tile prediction
        if save_tiles:
            tile_path = os.path.join(tile_save_path, f"{i}_{j}.png")
            save_tile_results(prediction, tile_path, show=False)

        try: 
            temp_df = results_toDF(prediction, j, i, addIDCol=True)
            df = pd.concat([df, temp_df], ignore_index=True)
        except KeyError as e:
            print(f"Skipping iteration due to missing key: {e}")
            continue
# Out:
# 0: 384x384 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 1
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 2
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 3
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 4
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 5
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 6
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 4 axons, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 7
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 8
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 9
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 5.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 10
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 11
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 1 axon, 10.0ms
# Speed: 5.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 12
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 13
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 1 nuclei, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 14
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 15
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 16
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 17
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 5.5ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 18
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 19
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 4.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 20
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 21
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 22
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 23
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 24
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 25
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 26
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 27
# Skipping iteration due to missing key: 'path'
#
# 0: 384x256 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 256)
# 28
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.4ms
# Speed: 1.0ms preprocess, 10.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
# 29
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.3ms
# Speed: 1.0ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 30
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.4ms
# Speed: 1.0ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 31
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.9ms
# Speed: 1.5ms preprocess, 9.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 32
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.9ms
# Speed: 1.0ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 33
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 5.7ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 34
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.7ms
# Speed: 1.2ms preprocess, 10.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 35
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 53 axons, 6 nucleis, 11.0ms
# Speed: 5.2ms preprocess, 11.0ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 384)
# 36
#
# 0: 384x384 164 axons, 8 nucleis, 10.9ms
# Speed: 1.0ms preprocess, 10.9ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 384)
# 37
#
# 0: 384x384 431 axons, 31 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 33.5ms postprocess per image at shape (1, 3, 384, 384)
# 38
#
# 0: 384x384 333 axons, 23 nucleis, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 26.0ms postprocess per image at shape (1, 3, 384, 384)
# 39
#
# 0: 384x384 202 axons, 14 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 384)
# 40
#
# 0: 384x384 98 axons, 12 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 384)
# 41
#
# 0: 384x384 29 axons, 1 nuclei, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 42
#
# 0: 384x384 1 axon, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 43
#
# 0: 384x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 44
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 45
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 46
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 47
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 48
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 49
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 50
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 51
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 52
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 53
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 54
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 55
# Skipping iteration due to missing key: 'path'
#
# 0: 384x256 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 256)
# 56
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 57
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 58
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 59
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 60
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 61
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 62
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 110 axons, 11 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 384)
# 63
#
# 0: 384x384 789 axons, 46 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 62.1ms postprocess per image at shape (1, 3, 384, 384)
# 64
#
# 0: 384x384 884 axons, 46 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 33.5ms postprocess per image at shape (1, 3, 384, 384)
# 65
#
# 0: 384x384 889 axons, 44 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 66
#
# 0: 384x384 850 axons, 38 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 67
#
# 0: 384x384 927 axons, 55 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 34.5ms postprocess per image at shape (1, 3, 384, 384)
# 68
#
# 0: 384x384 854 axons, 36 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 66.5ms postprocess per image at shape (1, 3, 384, 384)
# 69
#
# 0: 384x384 751 axons, 54 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 59.5ms postprocess per image at shape (1, 3, 384, 384)
# 70
#
# 0: 384x384 467 axons, 47 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 384)
# 71
#
# 0: 384x384 42 axons, 5 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 72
#
# 0: 384x384 (no detections), 13.3ms
# Speed: 1.0ms preprocess, 13.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 73
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.5ms preprocess, 10.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 74
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.5ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 75
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.4ms
# Speed: 0.5ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 76
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 1.1ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 77
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.6ms
# Speed: 0.5ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 78
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 79
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.6ms
# Speed: 0.5ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 80
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.6ms
# Speed: 0.5ms preprocess, 10.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 81
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 82
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.9ms
# Speed: 0.5ms preprocess, 9.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 83
# Skipping iteration due to missing key: 'path'
#
# 0: 384x256 (no detections), 10.9ms
# Speed: 0.5ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 256)
# 84
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 16.1ms
# Speed: 0.5ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 85
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 86
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 87
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 88
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 11 axons, 1 nuclei, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 89
#
# 0: 384x384 327 axons, 20 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 384)
# 90
#
# 0: 384x384 648 axons, 46 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 24.0ms postprocess per image at shape (1, 3, 384, 384)
# 91
#
# 0: 384x384 614 axons, 36 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 22.0ms postprocess per image at shape (1, 3, 384, 384)
# 92
#
# 0: 384x384 914 axons, 33 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 93
#
# 0: 384x384 929 axons, 41 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 73.0ms postprocess per image at shape (1, 3, 384, 384)
# 94
#
# 0: 384x384 933 axons, 40 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 34.5ms postprocess per image at shape (1, 3, 384, 384)
# 95
#
# 0: 384x384 921 axons, 35 nucleis, 10.8ms
# Speed: 0.5ms preprocess, 10.8ms inference, 33.8ms postprocess per image at shape (1, 3, 384, 384)
# 96
#
# 0: 384x384 947 axons, 41 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 34.2ms postprocess per image at shape (1, 3, 384, 384)
# 97
#
# 0: 384x384 895 axons, 48 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 98
#
# 0: 384x384 805 axons, 70 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 65.5ms postprocess per image at shape (1, 3, 384, 384)
# 99
#
# 0: 384x384 545 axons, 40 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 384)
# 100
#
# 0: 384x384 74 axons, 5 nucleis, 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 101
#
# 0: 384x384 (no detections), 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 102
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 103
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 104
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 1 axon, 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 105
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 106
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 11.7ms
# Speed: 1.1ms preprocess, 11.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 107
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 1 axon, 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 108
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 109
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.4ms
# Speed: 1.1ms preprocess, 10.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 110
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.3ms
# Speed: 0.5ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 111
# Skipping iteration due to missing key: 'path'
#
# 0: 384x256 10 axons, 11.4ms
# Speed: 0.5ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 256)
# 112
#
# 0: 384x384 (no detections), 10.9ms
# Speed: 1.0ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 113
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.9ms
# Speed: 0.5ms preprocess, 10.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 114
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 44 axons, 15 nucleis, 10.1ms
# Speed: 0.6ms preprocess, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 115
#
# 0: 384x384 114 axons, 23 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 116
#
# 0: 384x384 694 axons, 34 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 25.0ms postprocess per image at shape (1, 3, 384, 384)
# 117
#
# 0: 384x384 707 axons, 55 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 27.0ms postprocess per image at shape (1, 3, 384, 384)
# 118
#
# 0: 384x384 809 axons, 42 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 29.5ms postprocess per image at shape (1, 3, 384, 384)
# 119
#
# 0: 384x384 807 axons, 54 nucleis, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 64.6ms postprocess per image at shape (1, 3, 384, 384)
# 120
#
# 0: 384x384 935 axons, 27 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 33.5ms postprocess per image at shape (1, 3, 384, 384)
# 121
#
# 0: 384x384 707 axons, 50 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 56.6ms postprocess per image at shape (1, 3, 384, 384)
# 122
#
# 0: 384x384 922 axons, 37 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 123
#
# 0: 384x384 877 axons, 48 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 69.5ms postprocess per image at shape (1, 3, 384, 384)
# 124
#
# 0: 384x384 922 axons, 61 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 33.5ms postprocess per image at shape (1, 3, 384, 384)
# 125
#
# 0: 384x384 874 axons, 49 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 126
#
# 0: 384x384 944 axons, 48 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 34.0ms postprocess per image at shape (1, 3, 384, 384)
# 127
#
# 0: 384x384 836 axons, 53 nucleis, 9.4ms
# Speed: 0.5ms preprocess, 9.4ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 128
#
# 0: 384x384 378 axons, 39 nucleis, 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 31.3ms postprocess per image at shape (1, 3, 384, 384)
# 129
#
# 0: 384x384 408 axons, 23 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 130
#
# 0: 384x384 130 axons, 12 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 384)
# 131
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 132
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 133
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 134
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 135
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 136
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 137
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 138
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 4 axons, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 139
#
# 0: 384x256 25 axons, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 140
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 141
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 130 axons, 16 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 384)
# 142
#
# 0: 384x384 704 axons, 62 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 57.5ms postprocess per image at shape (1, 3, 384, 384)
# 143
#
# 0: 384x384 156 axons, 43 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 384)
# 144
#
# 0: 384x384 724 axons, 49 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 26.0ms postprocess per image at shape (1, 3, 384, 384)
# 145
#
# 0: 384x384 782 axons, 43 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 28.5ms postprocess per image at shape (1, 3, 384, 384)
# 146
#
# 0: 384x384 851 axons, 29 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 147
#
# 0: 384x384 805 axons, 38 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 29.5ms postprocess per image at shape (1, 3, 384, 384)
# 148
#
# 0: 384x384 904 axons, 37 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 70.5ms postprocess per image at shape (1, 3, 384, 384)
# 149
#
# 0: 384x384 889 axons, 56 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 150
#
# 0: 384x384 895 axons, 47 nucleis, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 151
#
# 0: 384x384 871 axons, 36 nucleis, 10.8ms
# Speed: 1.0ms preprocess, 10.8ms inference, 31.4ms postprocess per image at shape (1, 3, 384, 384)
# 152
#
# 0: 384x384 862 axons, 45 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 31.5ms postprocess per image at shape (1, 3, 384, 384)
# 153
#
# 0: 384x384 891 axons, 55 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 70.5ms postprocess per image at shape (1, 3, 384, 384)
# 154
#
# 0: 384x384 888 axons, 47 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 155
#
# 0: 384x384 917 axons, 41 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 156
#
# 0: 384x384 769 axons, 70 nucleis, 11.0ms
# Speed: 0.5ms preprocess, 11.0ms inference, 29.1ms postprocess per image at shape (1, 3, 384, 384)
# 157
#
# 0: 384x384 818 axons, 40 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 29.5ms postprocess per image at shape (1, 3, 384, 384)
# 158
#
# 0: 384x384 678 axons, 59 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 54.5ms postprocess per image at shape (1, 3, 384, 384)
# 159
#
# 0: 384x384 184 axons, 22 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 384)
# 160
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 161
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 162
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 163
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 164
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 165
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 166
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 167
# Skipping iteration due to missing key: 'path'
#
# 0: 384x256 1 axon, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 168
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 169
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 222 axons, 30 nucleis, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 384)
# 170
#
# 0: 384x384 877 axons, 54 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 70.0ms postprocess per image at shape (1, 3, 384, 384)
# 171
#
# 0: 384x384 202 axons, 47 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 384)
# 172
#
# 0: 384x384 495 axons, 38 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 18.6ms postprocess per image at shape (1, 3, 384, 384)
# 173
#
# 0: 384x384 777 axons, 58 nucleis, 9.9ms
# Speed: 0.5ms preprocess, 9.9ms inference, 29.3ms postprocess per image at shape (1, 3, 384, 384)
# 174
#
# 0: 384x384 871 axons, 31 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 30.5ms postprocess per image at shape (1, 3, 384, 384)
# 175
#
# 0: 384x384 849 axons, 46 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 31.5ms postprocess per image at shape (1, 3, 384, 384)
# 176
#
# 0: 384x384 843 axons, 38 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 66.1ms postprocess per image at shape (1, 3, 384, 384)
# 177
#
# 0: 384x384 869 axons, 43 nucleis, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 32.5ms postprocess per image at shape (1, 3, 384, 384)
# 178
#
# 0: 384x384 968 axons, 28 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 35.1ms postprocess per image at shape (1, 3, 384, 384)
# 179
#
# 0: 384x384 873 axons, 41 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 180
#
# 0: 384x384 995 axons, 51 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 36.0ms postprocess per image at shape (1, 3, 384, 384)
# 181
#
# 0: 384x384 935 axons, 56 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 75.0ms postprocess per image at shape (1, 3, 384, 384)
# 182
#
# 0: 384x384 763 axons, 60 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 61.5ms postprocess per image at shape (1, 3, 384, 384)
# 183
#
# 0: 384x384 778 axons, 58 nucleis, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 28.5ms postprocess per image at shape (1, 3, 384, 384)
# 184
#
# 0: 384x384 887 axons, 72 nucleis, 9.4ms
# Speed: 0.5ms preprocess, 9.4ms inference, 33.8ms postprocess per image at shape (1, 3, 384, 384)
# 185
#
# 0: 384x384 948 axons, 40 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 34.5ms postprocess per image at shape (1, 3, 384, 384)
# 186
#
# 0: 384x384 885 axons, 57 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 187
#
# 0: 384x384 757 axons, 48 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 60.0ms postprocess per image at shape (1, 3, 384, 384)
# 188
#
# 0: 384x384 293 axons, 26 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 384)
# 189
#
# 0: 384x384 8 axons, 1 nuclei, 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 190
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 191
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 192
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 193
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 194
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 195
# Skipping iteration due to missing key: 'path'
#
# 0: 384x256 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 256)
# 196
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
# 197
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 198
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 532 axons, 73 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 21.3ms postprocess per image at shape (1, 3, 384, 384)
# 199
#
# 0: 384x384 562 axons, 62 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 22.2ms postprocess per image at shape (1, 3, 384, 384)
# 200
#
# 0: 384x384 888 axons, 44 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 32.5ms postprocess per image at shape (1, 3, 384, 384)
# 201
#
# 0: 384x384 820 axons, 51 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 202
#
# 0: 384x384 817 axons, 35 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 64.0ms postprocess per image at shape (1, 3, 384, 384)
# 203
#
# 0: 384x384 790 axons, 35 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 62.0ms postprocess per image at shape (1, 3, 384, 384)
# 204
#
# 0: 384x384 840 axons, 34 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 31.1ms postprocess per image at shape (1, 3, 384, 384)
# 205
#
# 0: 384x384 843 axons, 39 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 206
#
# 0: 384x384 924 axons, 41 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 34.0ms postprocess per image at shape (1, 3, 384, 384)
# 207
#
# 0: 384x384 804 axons, 45 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 208
#
# 0: 384x384 901 axons, 42 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 209
#
# 0: 384x384 915 axons, 56 nucleis, 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 73.6ms postprocess per image at shape (1, 3, 384, 384)
# 210
#
# 0: 384x384 792 axons, 69 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 211
#
# 0: 384x384 830 axons, 61 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 212
#
# 0: 384x384 881 axons, 81 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 213
#
# 0: 384x384 912 axons, 70 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 34.5ms postprocess per image at shape (1, 3, 384, 384)
# 214
#
# 0: 384x384 1025 axons, 63 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 82.5ms postprocess per image at shape (1, 3, 384, 384)
# 215
#
# 0: 384x384 887 axons, 72 nucleis, 10.3ms
# Speed: 0.6ms preprocess, 10.3ms inference, 71.3ms postprocess per image at shape (1, 3, 384, 384)
# 216
#
# 0: 384x384 835 axons, 42 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 217
#
# 0: 384x384 335 axons, 16 nucleis, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 384)
# 218
#
# 0: 384x384 125 axons, 13 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 384)
# 219
#
# 0: 384x384 (no detections), 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 220
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 3 axons, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 384)
# 221
#
# 0: 384x384 10 axons, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 222
#
# 0: 384x384 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
# 223
# Skipping iteration due to missing key: 'path'
#
# 0: 384x256 (no detections), 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 256)
# 224
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 225
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 9.2ms
# Speed: 1.0ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 226
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 332 axons, 29 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 384)
# 227
#
# 0: 384x384 931 axons, 39 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 34.0ms postprocess per image at shape (1, 3, 384, 384)
# 228
#
# 0: 384x384 937 axons, 43 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 34.0ms postprocess per image at shape (1, 3, 384, 384)
# 229
#
# 0: 384x384 902 axons, 36 nucleis, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 71.6ms postprocess per image at shape (1, 3, 384, 384)
# 230
#
# 0: 384x384 837 axons, 53 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 66.5ms postprocess per image at shape (1, 3, 384, 384)
# 231
#
# 0: 384x384 766 axons, 43 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 27.5ms postprocess per image at shape (1, 3, 384, 384)
# 232
#
# 0: 384x384 827 axons, 47 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 233
#
# 0: 384x384 834 axons, 33 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 234
#
# 0: 384x384 814 axons, 60 nucleis, 10.6ms
# Speed: 0.5ms preprocess, 10.6ms inference, 30.1ms postprocess per image at shape (1, 3, 384, 384)
# 235
#
# 0: 384x384 752 axons, 73 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 28.0ms postprocess per image at shape (1, 3, 384, 384)
# 236
#
# 0: 384x384 919 axons, 57 nucleis, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 73.5ms postprocess per image at shape (1, 3, 384, 384)
# 237
#
# 0: 384x384 860 axons, 48 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 238
#
# 0: 384x384 845 axons, 59 nucleis, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 239
#
# 0: 384x384 830 axons, 49 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 30.2ms postprocess per image at shape (1, 3, 384, 384)
# 240
#
# 0: 384x384 929 axons, 73 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 35.0ms postprocess per image at shape (1, 3, 384, 384)
# 241
#
# 0: 384x384 937 axons, 49 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 74.5ms postprocess per image at shape (1, 3, 384, 384)
# 242
#
# 0: 384x384 965 axons, 63 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 36.0ms postprocess per image at shape (1, 3, 384, 384)
# 243
#
# 0: 384x384 1022 axons, 61 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 38.0ms postprocess per image at shape (1, 3, 384, 384)
# 244
#
# 0: 384x384 888 axons, 51 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 32.2ms postprocess per image at shape (1, 3, 384, 384)
# 245
#
# 0: 384x384 418 axons, 51 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 384)
# 246
#
# 0: 384x384 753 axons, 48 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 59.1ms postprocess per image at shape (1, 3, 384, 384)
# 247
#
# 0: 384x384 399 axons, 26 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 384)
# 248
#
# 0: 384x384 659 axons, 32 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 24.0ms postprocess per image at shape (1, 3, 384, 384)
# 249
#
# 0: 384x384 729 axons, 31 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 26.0ms postprocess per image at shape (1, 3, 384, 384)
# 250
#
# 0: 384x384 112 axons, 9 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 251
#
# 0: 384x256 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 256)
# 252
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 253
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 17 axons, 5 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 254
#
# 0: 384x384 693 axons, 33 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 25.5ms postprocess per image at shape (1, 3, 384, 384)
# 255
#
# 0: 384x384 703 axons, 56 nucleis, 9.9ms
# Speed: 0.5ms preprocess, 9.9ms inference, 26.4ms postprocess per image at shape (1, 3, 384, 384)
# 256
#
# 0: 384x384 786 axons, 56 nucleis, 8.9ms
# Speed: 1.6ms preprocess, 8.9ms inference, 63.5ms postprocess per image at shape (1, 3, 384, 384)
# 257
#
# 0: 384x384 909 axons, 50 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 258
#
# 0: 384x384 853 axons, 42 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 30.5ms postprocess per image at shape (1, 3, 384, 384)
# 259
#
# 0: 384x384 855 axons, 40 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 30.5ms postprocess per image at shape (1, 3, 384, 384)
# 260
#
# 0: 384x384 912 axons, 39 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 32.6ms postprocess per image at shape (1, 3, 384, 384)
# 261
#
# 0: 384x384 754 axons, 45 nucleis, 9.8ms
# Speed: 0.6ms preprocess, 9.8ms inference, 59.4ms postprocess per image at shape (1, 3, 384, 384)
# 262
#
# 0: 384x384 931 axons, 45 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 73.5ms postprocess per image at shape (1, 3, 384, 384)
# 263
#
# 0: 384x384 976 axons, 54 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 36.0ms postprocess per image at shape (1, 3, 384, 384)
# 264
#
# 0: 384x384 964 axons, 54 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 36.0ms postprocess per image at shape (1, 3, 384, 384)
# 265
#
# 0: 384x384 871 axons, 47 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 32.6ms postprocess per image at shape (1, 3, 384, 384)
# 266
#
# 0: 384x384 847 axons, 49 nucleis, 9.9ms
# Speed: 0.5ms preprocess, 9.9ms inference, 31.2ms postprocess per image at shape (1, 3, 384, 384)
# 267
#
# 0: 384x384 907 axons, 43 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 71.5ms postprocess per image at shape (1, 3, 384, 384)
# 268
#
# 0: 384x384 885 axons, 70 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 269
#
# 0: 384x384 522 axons, 55 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 384)
# 270
#
# 0: 384x384 916 axons, 56 nucleis, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 34.0ms postprocess per image at shape (1, 3, 384, 384)
# 271
#
# 0: 384x384 977 axons, 49 nucleis, 10.3ms
# Speed: 0.5ms preprocess, 10.3ms inference, 35.5ms postprocess per image at shape (1, 3, 384, 384)
# 272
#
# 0: 384x384 975 axons, 47 nucleis, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 77.0ms postprocess per image at shape (1, 3, 384, 384)
# 273
#
# 0: 384x384 955 axons, 61 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 76.5ms postprocess per image at shape (1, 3, 384, 384)
# 274
#
# 0: 384x384 1007 axons, 48 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 37.1ms postprocess per image at shape (1, 3, 384, 384)
# 275
#
# 0: 384x384 1019 axons, 40 nucleis, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 37.0ms postprocess per image at shape (1, 3, 384, 384)
# 276
#
# 0: 384x384 1057 axons, 29 nucleis, 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 38.5ms postprocess per image at shape (1, 3, 384, 384)
# 277
#
# 0: 384x384 1037 axons, 42 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 38.0ms postprocess per image at shape (1, 3, 384, 384)
# 278
#
# 0: 384x384 251 axons, 20 nucleis, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 384)
# 279
#
# 0: 384x256 (no detections), 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 256)
# 280
# Skipping iteration due to missing key: 'path'
#
# 0: 384x384 20 axons, 5 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 281
#
# 0: 384x384 524 axons, 39 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 40.5ms postprocess per image at shape (1, 3, 384, 384)
# 282
#
# 0: 384x384 759 axons, 58 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 60.5ms postprocess per image at shape (1, 3, 384, 384)
# 283
#
# 0: 384x384 956 axons, 46 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 35.0ms postprocess per image at shape (1, 3, 384, 384)
# 284
#
# 0: 384x384 864 axons, 53 nucleis, 9.8ms
# Speed: 0.5ms preprocess, 9.8ms inference, 31.9ms postprocess per image at shape (1, 3, 384, 384)
# 285
#
# 0: 384x384 936 axons, 43 nucleis, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 34.6ms postprocess per image at shape (1, 3, 384, 384)
# 286
#
# 0: 384x384 858 axons, 42 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 31.5ms postprocess per image at shape (1, 3, 384, 384)
# 287
#
# 0: 384x384 859 axons, 44 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 67.5ms postprocess per image at shape (1, 3, 384, 384)
# 288
#
# 0: 384x384 872 axons, 45 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 32.5ms postprocess per image at shape (1, 3, 384, 384)
# 289
#
# 0: 384x384 987 axons, 66 nucleis, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 36.9ms postprocess per image at shape (1, 3, 384, 384)
# 290
#
# 0: 384x384 950 axons, 43 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 34.0ms postprocess per image at shape (1, 3, 384, 384)
# 291
#
# 0: 384x384 1041 axons, 41 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 37.5ms postprocess per image at shape (1, 3, 384, 384)
# 292
#
# 0: 384x384 857 axons, 43 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 68.1ms postprocess per image at shape (1, 3, 384, 384)
# 293
#
# 0: 384x384 961 axons, 47 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 35.5ms postprocess per image at shape (1, 3, 384, 384)
# 294
#
# 0: 384x384 899 axons, 53 nucleis, 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 295
#
# 0: 384x384 863 axons, 53 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 296
#
# 0: 384x384 690 axons, 40 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 25.0ms postprocess per image at shape (1, 3, 384, 384)
# 297
#
# 0: 384x384 145 axons, 15 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 384)
# 298
#
# 0: 384x384 783 axons, 59 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 63.5ms postprocess per image at shape (1, 3, 384, 384)
# 299
#
# 0: 384x384 1044 axons, 57 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 38.5ms postprocess per image at shape (1, 3, 384, 384)
# 300
#
# 0: 384x384 981 axons, 37 nucleis, 10.3ms
# Speed: 0.5ms preprocess, 10.3ms inference, 35.1ms postprocess per image at shape (1, 3, 384, 384)
# 301
#
# 0: 384x384 1074 axons, 51 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 40.0ms postprocess per image at shape (1, 3, 384, 384)
# 302
#
# 0: 384x384 931 axons, 33 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 34.1ms postprocess per image at shape (1, 3, 384, 384)
# 303
#
# 0: 384x384 1025 axons, 39 nucleis, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 81.1ms postprocess per image at shape (1, 3, 384, 384)
# 304
#
# 0: 384x384 1115 axons, 37 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 40.0ms postprocess per image at shape (1, 3, 384, 384)
# 305
#
# 0: 384x384 1043 axons, 37 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 37.4ms postprocess per image at shape (1, 3, 384, 384)
# 306
#
# 0: 384x384 903 axons, 49 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 307
#
# 0: 384x256 314 axons, 12 nucleis, 11.0ms
# ...
# 673
#
# 0: 384x384 931 axons, 63 nucleis, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 34.0ms postprocess per image at shape (1, 3, 384, 384)
# 674
#
# 0: 384x384 882 axons, 70 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 33.5ms postprocess per image at shape (1, 3, 384, 384)
# 675
#
# 0: 384x384 869 axons, 55 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 676
#
# 0: 384x384 930 axons, 51 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 34.0ms postprocess per image at shape (1, 3, 384, 384)
# 677
#
# 0: 384x384 971 axons, 64 nucleis, 16.8ms
# Speed: 0.6ms preprocess, 16.8ms inference, 78.0ms postprocess per image at shape (1, 3, 384, 384)
# 678
#
# 0: 384x384 894 axons, 59 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 33.5ms postprocess per image at shape (1, 3, 384, 384)
# 679
#
# 0: 384x384 966 axons, 60 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 35.5ms postprocess per image at shape (1, 3, 384, 384)
# 680
#
# 0: 384x384 943 axons, 32 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 33.5ms postprocess per image at shape (1, 3, 384, 384)
# 681
#
# 0: 384x384 938 axons, 60 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 34.2ms postprocess per image at shape (1, 3, 384, 384)
# 682
#
# 0: 384x384 928 axons, 48 nucleis, 9.7ms
# Speed: 0.5ms preprocess, 9.7ms inference, 73.5ms postprocess per image at shape (1, 3, 384, 384)
# 683
#
# 0: 384x384 921 axons, 67 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 34.0ms postprocess per image at shape (1, 3, 384, 384)
# 684
#
# 0: 384x384 1028 axons, 54 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 82.5ms postprocess per image at shape (1, 3, 384, 384)
# 685
#
# 0: 384x384 980 axons, 70 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 37.0ms postprocess per image at shape (1, 3, 384, 384)
# 686
#
# 0: 384x384 890 axons, 53 nucleis, 10.4ms
# Speed: 0.5ms preprocess, 10.4ms inference, 32.9ms postprocess per image at shape (1, 3, 384, 384)
# 687
#
# 0: 384x384 667 axons, 62 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 26.0ms postprocess per image at shape (1, 3, 384, 384)
# 688
#
# 0: 384x384 910 axons, 52 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 689
#
# 0: 384x384 911 axons, 46 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 72.1ms postprocess per image at shape (1, 3, 384, 384)
# 690
#
# 0: 384x384 870 axons, 55 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 691
#
# 0: 384x384 995 axons, 48 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 37.0ms postprocess per image at shape (1, 3, 384, 384)
# 692
#
# 0: 384x384 891 axons, 34 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 31.9ms postprocess per image at shape (1, 3, 384, 384)
# 693
#
# 0: 384x384 803 axons, 42 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 29.0ms postprocess per image at shape (1, 3, 384, 384)
# 694
#
# 0: 384x384 964 axons, 33 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 75.1ms postprocess per image at shape (1, 3, 384, 384)
# 695
#
# 0: 384x384 966 axons, 43 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 35.0ms postprocess per image at shape (1, 3, 384, 384)
# 696
#
# 0: 384x384 885 axons, 46 nucleis, 10.1ms
# Speed: 0.5ms preprocess, 10.1ms inference, 32.4ms postprocess per image at shape (1, 3, 384, 384)
# 697
#
# 0: 384x384 898 axons, 37 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 698
#
# 0: 384x384 821 axons, 52 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 699
#
# 0: 384x256 622 axons, 19 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 256)
# 700
#
# 0: 384x384 929 axons, 60 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 75.0ms postprocess per image at shape (1, 3, 384, 384)
# 701
#
# 0: 384x384 988 axons, 43 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 77.6ms postprocess per image at shape (1, 3, 384, 384)
# 702
#
# 0: 384x384 704 axons, 58 nucleis, 10.3ms
# Speed: 1.0ms preprocess, 10.3ms inference, 26.3ms postprocess per image at shape (1, 3, 384, 384)
# 703
#
# 0: 384x384 1012 axons, 49 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 37.7ms postprocess per image at shape (1, 3, 384, 384)
# 704
#
# 0: 384x384 657 axons, 80 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 26.0ms postprocess per image at shape (1, 3, 384, 384)
# 705
#
# 0: 384x384 916 axons, 70 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 34.5ms postprocess per image at shape (1, 3, 384, 384)
# 706
#
# 0: 384x384 861 axons, 58 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 69.0ms postprocess per image at shape (1, 3, 384, 384)
# 707
#
# 0: 384x384 959 axons, 63 nucleis, 9.9ms
# Speed: 0.5ms preprocess, 9.9ms inference, 35.6ms postprocess per image at shape (1, 3, 384, 384)
# 708
#
# 0: 384x384 928 axons, 47 nucleis, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 34.5ms postprocess per image at shape (1, 3, 384, 384)
# 709
#
# 0: 384x384 747 axons, 43 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 27.5ms postprocess per image at shape (1, 3, 384, 384)
# 710
#
# 0: 384x384 530 axons, 51 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 384)
# 711
#
# 0: 384x384 842 axons, 60 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 67.0ms postprocess per image at shape (1, 3, 384, 384)
# 712
#
# 0: 384x384 910 axons, 49 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 33.2ms postprocess per image at shape (1, 3, 384, 384)
# 713
#
# 0: 384x384 885 axons, 51 nucleis, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 714
#
# 0: 384x384 975 axons, 48 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 36.0ms postprocess per image at shape (1, 3, 384, 384)
# 715
#
# 0: 384x384 752 axons, 73 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 28.5ms postprocess per image at shape (1, 3, 384, 384)
# 716
#
# 0: 384x384 1019 axons, 42 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 80.8ms postprocess per image at shape (1, 3, 384, 384)
# 717
#
# 0: 384x384 907 axons, 64 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 34.0ms postprocess per image at shape (1, 3, 384, 384)
# 718
#
# 0: 384x384 927 axons, 47 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 34.0ms postprocess per image at shape (1, 3, 384, 384)
# 719
#
# 0: 384x384 944 axons, 50 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 34.2ms postprocess per image at shape (1, 3, 384, 384)
# 720
#
# 0: 384x384 837 axons, 49 nucleis, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 30.5ms postprocess per image at shape (1, 3, 384, 384)
# 721
#
# 0: 384x384 885 axons, 36 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 68.5ms postprocess per image at shape (1, 3, 384, 384)
# 722
#
# 0: 384x384 914 axons, 40 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 723
#
# 0: 384x384 949 axons, 39 nucleis, 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 34.6ms postprocess per image at shape (1, 3, 384, 384)
# 724
#
# 0: 384x384 951 axons, 42 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 35.0ms postprocess per image at shape (1, 3, 384, 384)
# 725
#
# 0: 384x384 828 axons, 41 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 726
#
# 0: 384x384 854 axons, 38 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 66.5ms postprocess per image at shape (1, 3, 384, 384)
# 727
#
# 0: 384x256 621 axons, 22 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 256)
# 728
#
# 0: 384x384 476 axons, 73 nucleis, 11.1ms
# Speed: 0.0ms preprocess, 11.1ms inference, 18.9ms postprocess per image at shape (1, 3, 384, 384)
# 729
#
# 0: 384x384 775 axons, 55 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 29.0ms postprocess per image at shape (1, 3, 384, 384)
# 730
#
# 0: 384x384 854 axons, 48 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 731
#
# 0: 384x384 849 axons, 63 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 732
#
# 0: 384x384 687 axons, 65 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 56.5ms postprocess per image at shape (1, 3, 384, 384)
# 733
#
# 0: 384x384 965 axons, 37 nucleis, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 76.1ms postprocess per image at shape (1, 3, 384, 384)
# 734
#
# 0: 384x384 818 axons, 94 nucleis, 9.9ms
# Speed: 1.1ms preprocess, 9.9ms inference, 31.8ms postprocess per image at shape (1, 3, 384, 384)
# 735
#
# 0: 384x384 946 axons, 68 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 35.5ms postprocess per image at shape (1, 3, 384, 384)
# 736
#
# 0: 384x384 847 axons, 68 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 737
#
# 0: 384x384 794 axons, 38 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 29.0ms postprocess per image at shape (1, 3, 384, 384)
# 738
#
# 0: 384x384 794 axons, 44 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 62.0ms postprocess per image at shape (1, 3, 384, 384)
# 739
#
# 0: 384x384 550 axons, 51 nucleis, 11.6ms
# Speed: 0.7ms preprocess, 11.6ms inference, 20.8ms postprocess per image at shape (1, 3, 384, 384)
# 740
#
# 0: 384x384 837 axons, 69 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 741
#
# 0: 384x384 969 axons, 52 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 35.5ms postprocess per image at shape (1, 3, 384, 384)
# 742
#
# 0: 384x384 847 axons, 58 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 743
#
# 0: 384x384 1022 axons, 45 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 81.5ms postprocess per image at shape (1, 3, 384, 384)
# 744
#
# 0: 384x384 1024 axons, 47 nucleis, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 37.8ms postprocess per image at shape (1, 3, 384, 384)
# 745
#
# 0: 384x384 850 axons, 45 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 746
#
# 0: 384x384 893 axons, 45 nucleis, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 747
#
# 0: 384x384 618 axons, 31 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 22.5ms postprocess per image at shape (1, 3, 384, 384)
# 748
#
# 0: 384x384 973 axons, 49 nucleis, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 77.5ms postprocess per image at shape (1, 3, 384, 384)
# 749
#
# 0: 384x384 903 axons, 41 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 33.2ms postprocess per image at shape (1, 3, 384, 384)
# 750
#
# 0: 384x384 893 axons, 38 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 751
#
# 0: 384x384 922 axons, 49 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 752
#
# 0: 384x384 825 axons, 27 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 29.0ms postprocess per image at shape (1, 3, 384, 384)
# 753
#
# 0: 384x384 883 axons, 32 nucleis, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 68.5ms postprocess per image at shape (1, 3, 384, 384)
# 754
#
# 0: 384x384 947 axons, 41 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 34.6ms postprocess per image at shape (1, 3, 384, 384)
# 755
#
# 0: 384x256 550 axons, 41 nucleis, 10.4ms
# Speed: 0.5ms preprocess, 10.4ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 256)
# 756
#
# 0: 384x384 155 axons, 45 nucleis, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 384)
# 757
#
# 0: 384x384 675 axons, 53 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 25.0ms postprocess per image at shape (1, 3, 384, 384)
# 758
#
# 0: 384x384 836 axons, 54 nucleis, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 759
#
# 0: 384x384 214 axons, 53 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 384)
# 760
#
# 0: 384x384 693 axons, 62 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 55.5ms postprocess per image at shape (1, 3, 384, 384)
# 761
#
# 0: 384x384 842 axons, 49 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 384)
# 762
#
# 0: 384x384 876 axons, 79 nucleis, 9.5ms
# Speed: 0.5ms preprocess, 9.5ms inference, 72.0ms postprocess per image at shape (1, 3, 384, 384)
# 763
#
# 0: 384x384 918 axons, 74 nucleis, 19.5ms
# Speed: 1.5ms preprocess, 19.5ms inference, 35.8ms postprocess per image at shape (1, 3, 384, 384)
# 764
#
# 0: 384x384 851 axons, 59 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 765
#
# 0: 384x384 765 axons, 60 nucleis, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 28.6ms postprocess per image at shape (1, 3, 384, 384)
# 766
#
# 0: 384x384 476 axons, 57 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 384)
# 767
#
# 0: 384x384 565 axons, 43 nucleis, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 45.0ms postprocess per image at shape (1, 3, 384, 384)
# 768
#
# 0: 384x384 993 axons, 60 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 79.7ms postprocess per image at shape (1, 3, 384, 384)
# 769
#
# 0: 384x384 955 axons, 42 nucleis, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 35.0ms postprocess per image at shape (1, 3, 384, 384)
# 770
#
# 0: 384x384 765 axons, 52 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 28.5ms postprocess per image at shape (1, 3, 384, 384)
# 771
#
# 0: 384x384 871 axons, 52 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
# 772
#
# 0: 384x384 955 axons, 58 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 34.6ms postprocess per image at shape (1, 3, 384, 384)
# 773
#
# 0: 384x384 805 axons, 58 nucleis, 10.3ms
# Speed: 0.5ms preprocess, 10.3ms inference, 65.0ms postprocess per image at shape (1, 3, 384, 384)
# 774
#
# 0: 384x384 836 axons, 63 nucleis, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 67.5ms postprocess per image at shape (1, 3, 384, 384)
# 775
#
# 0: 384x384 726 axons, 58 nucleis, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 58.0ms postprocess per image at shape (1, 3, 384, 384)
# 776
#
# 0: 384x384 833 axons, 46 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 777
#
# 0: 384x384 794 axons, 39 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 61.5ms postprocess per image at shape (1, 3, 384, 384)
# 778
#
# 0: 384x384 756 axons, 37 nucleis, 9.9ms
# Speed: 0.5ms preprocess, 9.9ms inference, 27.7ms postprocess per image at shape (1, 3, 384, 384)
# 779
#
# 0: 384x384 426 axons, 23 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 384)
# 780
#
# 0: 384x384 933 axons, 37 nucleis, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 33.0ms postprocess per image at shape (1, 3, 384, 384)
# 781
#
# 0: 384x384 761 axons, 59 nucleis, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 29.0ms postprocess per image at shape (1, 3, 384, 384)
# 782
#
# 0: 384x384 816 axons, 56 nucleis, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 30.0ms postprocess per image at shape (1, 3, 384, 384)
# 783
#
# 0: 384x256 610 axons, 41 nucleis, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 256)
# 784

# %%
# how I would export the data
df.to_csv(r"R:\FIVE\EXP\FIV925\Additional Datasets\Human Lung Cancer\results_3.csv")
