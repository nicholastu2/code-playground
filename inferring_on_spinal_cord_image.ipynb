# %%
import imageio
import tifffile
from ultralytics import YOLO
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

image_path = r"S:\Phys\FIV925 XSection\Datasets\SpinalAtlas\Dodd and Fiederling\Cropped\2_Inverted_Slides\I2\C3-Slide1-6_Region0007_Channel555 nm,475 nm,395 nm_Seq0051.tif"
tif = tifffile.TiffFile(image_path)
image = tif.asarray()
arr_as_img = Image.fromarray(image, 'L')

yolo_model_path = r"S:\Phys\FIV925 XSection\Datasets\AllenBA\02b\YO 512 0515 MAXI\map75=0804727 YOLOv8n-seg .yaml idx=17 ep=57 btch=32 rnd=8367787\weights\best.pt"
model = YOLO(yolo_model_path)
prediction = model.predict(arr_as_img)
im_array = prediction[0].plot(labels=False, )

plt.imshow(im_array)
plt.axis('off')
plt.show()
# Out:
# 0: 512x512 2 2s, 6 3s, 2 4s, 2 5s, 1 6, 4 7s, 3 8s, 3 9s, 4 10s, 2 11s, 5 12s, 3 13s, 5 14s, 3 15s, 2 16s, 2 17s, 3 18s, 5 19s, 2 20s, 2 21s, 3 22s, 4 23s, 3 24s, 4 25s, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 512)

# %% [markdown]
# # Validating Brain model results
