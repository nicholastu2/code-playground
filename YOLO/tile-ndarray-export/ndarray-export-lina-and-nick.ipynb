# %%
# get voronoi boundaries

# get numpy array of image
#   - get centers of nuclei in numpy array
#   - prediction.boxes.xywh.numpy()
#       - export to csv
#           - how do you export to csv?

# %%
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
import torch
from ultralytics import YOLO
from PIL import Image, ImageDraw
import numpy as np
import pandas as pd
from IPython.display import clear_output
import socket
import time
from datetime import datetime
import shutil
from random import randint
import re
import imagecodecs
import tifffile
import tensorflow as tf
from scipy.spatial import Voronoi, cKDTree
from matplotlib.path import Path
from rtree import index
from ctypes.wintypes import INT
import time
import matplotlib.pyplot as plt
from shapely.geometry import Polygon, Point
import torch, torchvision
import colorsys

print("torchvision: ", torchvision.__version__)
print('CUDA available:', torch.cuda.is_available())
# Out:
# torchvision:  0.17.2
# CUDA available: True

# %%
# is this a segmentation model
# yolo_model_path = r"S:\Phys\FIV925 XSection\Datasets\Axons vs SCs\01i5\YO 384 0530 MAXI\map75=0855192 YOLOv8n-seg map75=081193 idx=4 ep=24 btch=32 rnd=2840511\weights\best.pt"
yolo_model_path = r"S:\Phys\FIV925 XSection\Datasets\Brain\01a\YO 384 0326 MAXI\map75=0650739 yolov9c  idx=12 ep=11 btch=8 rnd=6376250\weights\best.pt"
model = YOLO(yolo_model_path)

# %%
def get_color_by_id(point_region_id, total_ids):
    hue = point_region_id / total_ids # Scale the hue by the number of unique IDs, wrapping around the hue circle
    saturation = 0.9; value = 0.9  # Keep saturation and value high for bright colors
    rgb = colorsys.hsv_to_rgb(hue, saturation, value)
    r, g, b = (int(c * 255) for c in rgb)  # Convert to 0-255 scale for RGB colors
    return (r << 16) | (g << 8) | b  # Combine into a single integer

# %%
pred_height, pred_width = 384, 384
test_rows = 2
test_cols = 2
iteration = 0
scale_factor = 1
globalID = 0
maxArea = 10000
dataset = "Human Lung Cancer"
base_path = r"R:\FIVE\EXP\FIV925\Additional Datasets"
ome_tiff_path = f"{base_path}\\{dataset}\\morphology_mip.ome.tif"
use_entire_image = True

def int24_to_rgb(objID):
    r = (objID >> 16) & 0xFF  # Extract the highest 8 bits
    g = (objID >> 8) & 0xFF   # Extract the middle 8 bits
    b = objID & 0xFF          # Extract the lowest 8 bits
    return r, g, b

def ellipse_points(cx, cy, rx, ry, n=8):
    """Generate n points along the ellipse centered at (cx, cy) with radii rx and ry."""
    angles = np.linspace(0, 2 * np.pi, n, endpoint=False)
    points = [(cx + rx * np.cos(angle), cy + ry * np.sin(angle)) for angle in angles]
    return points

def draw_polygons(draw, polygons):
    global globalID
    for polygon in polygons:
        if len(polygon) < 2:
            continue
        # color = get_color_by_id(i, len(polygons))
        # draw.polygon(polygon, fill=i, outline='white')
        globalID+=1
        # there still aren't unique identifiers for each instance of a polygon
        #   I wonder if this is because the conversion from 24 bit to 8 bit integers doesn't guarantee a unique set of 8 bit integers for each 24 bit integer 
        (r,g,b) = int24_to_rgb(globalID)
        if (globalID == 300): print(globalID,r,g,b)
        draw.polygon(polygon, fill=(r,g,b))

with tifffile.TiffFile(ome_tiff_path) as tif:
    image = tif.asarray()
    # image_dapi = image[2,:, :] # DAPI channel
    image_data = image[::2, ::2] # downsample by half

    # normalize to 8 bit
    max_val_16bit = np.max(image_data)
    image_scaled = (image_data / max_val_16bit) * 255
    image_8bit = image_scaled.astype(np.uint8)

    # create image and resize
    og_image = Image.fromarray(image_8bit, 'L')
    new_width = int(og_image.width * scale_factor); new_height = int(og_image.height * scale_factor)
    image_resized = og_image.resize((new_width, new_height), Image.LANCZOS)
    image = np.array(image_resized)
    
    start_y = pred_height * 10
    start_x = pred_width * 10
    image_height_use = pred_height * test_rows
    image_width_use = pred_width * test_cols
    
    if use_entire_image:
        start_y = 0
        start_x = 0
        image_height_use = image_resized.height + pred_height*2
        image_width_use = image_resized.width + pred_width*2
        

    big_array = np.zeros((image_width_use, image_height_use)).astype(np.int32)
    list_xywh = []
    maxValue = 0

    # as we're making predictions, we want a big array that's meant to 'contain' the whole image
    #   then insert the predictions into that big array
    # so here is where we go through the image as tiles and make the predictions
    tile_id = 0
    for i in range(start_x, image_width_use + start_x, pred_width): # section_minx, section_maxx
        for j in range(start_y, image_height_use + start_y, pred_height): # section_miny, section_maxy
            iteration += 1
            tile = image[i:i+pred_width, j:j+pred_height]
            
            tile_id += 1
            
            if tile.shape[0] == 0 or tile.shape[1] == 0:
                continue  # Skip tiles that have no width or height
            tile_as_img = Image.fromarray(tile, 'L')
            predictions = model.predict(tile_as_img, show=False, max_det=3000) # can we pass an np array?
            
            result = predictions[0]
            # draw masks onto blank image
            if result.masks is not None:
                polygons = result.masks.xy
            else:
                if result.boxes is not None:
                    ## Ellipse Version
                    polygons = []
                    for (cx, cy, w, h) in result.boxes.xywh:
                        rx = w / 2
                        ry = h / 2
                        ellipse = ellipse_points(cx, cy, rx, ry, 8)
                        if (w*h)>maxArea: continue
                        polygons.append(ellipse)
                    
                    ## Bounding Box Version
                    # xyxy = result.boxes.xyxy
                    # for (x1, y1, x2, y2) in xyxy:
                    #     polygon = [(x1, y1), (x2, y1), (x2, y2), (x1, y2)]
                    #     polygons.append(polygon)
                else:
                    print("No Polygons or Boxes"); continue
            
            blank_tile = np.zeros((pred_width, pred_height,3))
            blank_tile_as_img = Image.fromarray(blank_tile,"RGB")
            draw_tile = ImageDraw.Draw(blank_tile_as_img) 
            draw_polygons(draw_tile, polygons)
            rgb_array = np.array(blank_tile_as_img).astype(np.int32)
            #rgb_array = rgb_array.astype(np.uint32)
            int_array = np.zeros((pred_width, pred_height), dtype=np.int32)
            int_array = ((rgb_array[:,:,0] << 16) | (rgb_array[:,:,1] << 8) | rgb_array[:,:,2])
            currentMax = np.max(int_array)
            print(currentMax)
            if (currentMax > maxValue): maxValue = currentMax
            
            # need a new version of image_array where we decode the 3 channels into 1 channel
            # ok I see the issue, we can only draw the polygons on the PIL image, and I don't know a way to draw them with different values
            
            # big_array[i:i - start_y, j:j - start_x] = image_array
            try:
                if int_array[0] > i-start_y:i-start_y+tile.shape[0] or int_array[1] > tile.shape[1]
                big_array[i-start_y:i-start_y+tile.shape[0] , j-start_x:j - start_x+tile.shape[1]] = int_array
            except:
                print("ERRRORORORORORORORO")
                pass
            #big_array[i-start_y:i-start_y+tile.shape[0] , j-start_x:j - start_x+tile.shape[1]] = int_array
            
            print("iteration: ", iteration)

# cropped_array = big_array[0:image_width_use, 0:image_height_use]
# cropped_array = big_array[0:image_resized.width, 0:image_resized.height]

# Swap i/j --
# Crop the large bit_array image down to match the sizes (keep the buffer in the beginning) --
# Limit Row and Column FIRST, do that when you arent in a view that has a scatterplot
# Send e-mail to JuanRu, copy us

#   Doing the predictions on your data has been going well, but exporting the data in the format that you requested confused us for a bit
#       we think we just got it working, so here's the file, but we haven't looked at it too carefully.
            
# Save the array with a header and formatted floating-point numbers
# np.savetxt(r"R:\FIVE\EXP\FIV925\Additional Datasets\Human Lung Cancer\array.csv", big_array, delimiter=",", fmt='%.2f')
# Out:
# 0: 384x384 30 Nucs, 25.0ms
# Speed: 4.0ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  1
#
# 0: 384x384 27 Nucs, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  2
#
# 0: 384x384 28 Nucs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  3
#
# 0: 384x384 28 Nucs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  4
#
# 0: 384x384 31 Nucs, 23.2ms
# Speed: 1.0ms preprocess, 23.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  5
#
# 0: 384x384 28 Nucs, 23.0ms
# Speed: 4.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  6
#
# 0: 384x384 28 Nucs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  7
#
# 0: 384x384 30 Nucs, 23.1ms
# Speed: 1.0ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  8
#
# 0: 384x384 33 Nucs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  9
#
# 0: 384x384 32 Nucs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  10
#
# 0: 384x384 32 Nucs, 23.2ms
# Speed: 1.0ms preprocess, 23.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  11
#
# 0: 384x384 34 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 1
# iteration:  12
#
# 0: 384x384 31 Nucs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  13
#
# 0: 384x384 33 Nucs, 22.5ms
# Speed: 5.2ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 2
# iteration:  14
#
# 0: 384x384 28 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  15
#
# 0: 384x384 30 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  16
#
# 0: 384x384 29 Nucs, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  17
#
# 0: 384x384 29 Nucs, 21.0ms
# Speed: 4.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  18
#
# 0: 384x384 27 Nucs, 21.6ms
# Speed: 4.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  19
#
# 0: 384x384 28 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  20
#
# 0: 384x384 26 Nucs, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  21
#
# 0: 384x384 29 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  22
#
# 0: 384x384 29 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  23
#
# 0: 384x384 28 Nucs, 22.1ms
# Speed: 0.0ms preprocess, 22.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  24
#
# 0: 384x384 28 Nucs, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  25
#
# 0: 384x384 28 Nucs, 31.5ms
# Speed: 6.1ms preprocess, 31.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  26
#
# 0: 384x384 29 Nucs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  27
#
# 0: 384x256 18 Nucs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  28
#
# 0: 384x384 29 Nucs, 23.7ms
# Speed: 1.0ms preprocess, 23.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  35
#
# 0: 384x384 31 Nucs, 22.4ms
# Speed: 1.6ms preprocess, 22.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  36
#
# 0: 384x384 28 Nucs, 23.1ms
# Speed: 1.1ms preprocess, 23.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  37
#
# 0: 384x384 30 Nucs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  38
#
# 0: 384x384 29 Nucs, 27.6ms
# Speed: 1.0ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  39
#
# 0: 384x384 28 Nucs, 21.5ms
# Speed: 2.5ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  40
#
# 0: 384x384 32 Nucs, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  41
#
# 0: 384x384 25 Nucs, 66 Strias, 21.5ms
# Speed: 1.5ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 71
# iteration:  42
#
# 0: 384x384 23 Nucs, 206 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 295
# iteration:  43
#
# 0: 384x384 20 Nucs, 583 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 300 0 1 44
# 898
# iteration:  44
#
# 0: 384x384 34 Nucs, 402 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 1334
# iteration:  45
#
# 0: 384x384 23 Nucs, 260 Strias, 21.9ms
# Speed: 1.0ms preprocess, 21.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 1614
# iteration:  46
#
# 0: 384x384 18 Nucs, 127 Strias, 21.0ms
# Speed: 5.6ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 1747
# iteration:  47
#
# 0: 384x384 35 Nucs, 25 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 1779
# iteration:  48
#
# 0: 384x384 30 Nucs, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 1780
# iteration:  49
#
# 0: 384x384 32 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  50
#
# 0: 384x384 26 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  51
#
# 0: 384x384 29 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  52
#
# 0: 384x384 25 Nucs, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  53
#
# 0: 384x384 30 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  54
#
# 0: 384x384 28 Nucs, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  55
#
# 0: 384x384 31 Nucs, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  56
#
# 0: 384x384 30 Nucs, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  57
#
# 0: 384x384 28 Nucs, 21.7ms
# Speed: 1.0ms preprocess, 21.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  58
#
# 0: 384x384 31 Nucs, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  59
#
# 0: 384x384 28 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  60
#
# 0: 384x384 31 Nucs, 21.6ms
# Speed: 2.0ms preprocess, 21.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  61
#
# 0: 384x256 17 Nucs, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  62
#
# 0: 384x384 28 Nucs, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  69
#
# 0: 384x384 30 Nucs, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  70
#
# 0: 384x384 30 Nucs, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  71
#
# 0: 384x384 30 Nucs, 22.0ms
# Speed: 4.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  72
#
# 0: 384x384 28 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  73
#
# 0: 384x384 29 Nucs, 21.7ms
# Speed: 6.0ms preprocess, 21.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  74
#
# 0: 384x384 26 Nucs, 118 Strias, 21.0ms
# Speed: 5.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 1924
# iteration:  75
#
# 0: 384x384 3 Nucs, 1015 Strias, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 2942
# iteration:  76
#
# 0: 384x384 1137 Strias, 20.0ms
# Speed: 6.5ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 4079
# iteration:  77
#
# 0: 384x384 1094 Strias, 22.4ms
# Speed: 1.0ms preprocess, 22.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 5173
# iteration:  78
#
# 0: 384x384 1070 Strias, 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 6243
# iteration:  79
#
# 0: 384x384 1236 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 7479
# iteration:  80
#
# 0: 384x384 2 Nucs, 1104 Strias, 21.0ms
# Speed: 4.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 8585
# iteration:  81
#
# 0: 384x384 6 Nucs, 1033 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 9624
# iteration:  82
#
# 0: 384x384 22 Nucs, 662 Strias, 21.0ms
# Speed: 0.5ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 10308
# iteration:  83
#
# 0: 384x384 18 Nucs, 55 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 10370
# iteration:  84
#
# 0: 384x384 29 Nucs, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  85
#
# 0: 384x384 31 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  86
#
# 0: 384x384 31 Nucs, 22.0ms
# Speed: 1.5ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  87
#
# 0: 384x384 26 Nucs, 20.7ms
# Speed: 1.0ms preprocess, 20.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  88
#
# 0: 384x384 29 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  89
#
# 0: 384x384 25 Nucs, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  90
#
# 0: 384x384 27 Nucs, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  91
#
# 0: 384x384 27 Nucs, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  92
#
# 0: 384x384 29 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  93
#
# 0: 384x384 27 Nucs, 21.0ms
# Speed: 4.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  94
#
# 0: 384x384 27 Nucs, 22.0ms
# Speed: 5.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  95
#
# 0: 384x256 17 Nucs, 22.0ms
# Speed: 6.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  96
#
# 0: 384x384 30 Nucs, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  103
#
# 0: 384x384 29 Nucs, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  104
#
# 0: 384x384 31 Nucs, 21.2ms
# Speed: 1.5ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  105
#
# 0: 384x384 32 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  106
#
# 0: 384x384 26 Nucs, 12 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 10385
# iteration:  107
#
# 0: 384x384 11 Nucs, 430 Strias, 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 10826
# iteration:  108
#
# 0: 384x384 10 Nucs, 826 Strias, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 11662
# iteration:  109
#
# 0: 384x384 18 Nucs, 761 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 12441
# iteration:  110
#
# 0: 384x384 1088 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 13529
# iteration:  111
#
# 0: 384x384 1069 Strias, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 14598
# iteration:  112
#
# 0: 384x384 1182 Strias, 21.4ms
# Speed: 1.0ms preprocess, 21.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 15780
# iteration:  113
#
# 0: 384x384 1169 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 16949
# iteration:  114
#
# 0: 384x384 1171 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 18120
# iteration:  115
#
# 0: 384x384 6 Nucs, 1176 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 19302
# iteration:  116
#
# 0: 384x384 8 Nucs, 1135 Strias, 21.6ms
# Speed: 0.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 20445
# iteration:  117
#
# 0: 384x384 11 Nucs, 742 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 21198
# iteration:  118
#
# 0: 384x384 20 Nucs, 118 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 21319
# iteration:  119
#
# 0: 384x384 32 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  120
#
# 0: 384x384 34 Nucs, 22.0ms
# Speed: 5.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  121
#
# 0: 384x384 30 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  122
#
# 0: 384x384 28 Nucs, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  123
#
# 0: 384x384 30 Nucs, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  124
#
# 0: 384x384 31 Nucs, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  125
#
# 0: 384x384 26 Nucs, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 21320
# iteration:  126
#
# 0: 384x384 31 Nucs, 21.0ms
# Speed: 7.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  127
#
# 0: 384x384 29 Nucs, 21.1ms
# Speed: 2.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  128
#
# 0: 384x384 28 Nucs, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  129
#
# 0: 384x256 5 Nucs, 23.5ms
# Speed: 0.6ms preprocess, 23.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 256)
# 21324
# ERRRORORORORORORORO
# iteration:  130
#
# 0: 384x384 34 Nucs, 24.0ms
# Speed: 6.6ms preprocess, 24.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  137
#
# 0: 384x384 30 Nucs, 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  138
#
# 0: 384x384 28 Nucs, 56 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 21396
# iteration:  139
#
# 0: 384x384 31 Nucs, 133 Strias, 25.0ms
# Speed: 0.5ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 21560
# iteration:  140
#
# 0: 384x384 6 Nucs, 947 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 22513
# iteration:  141
#
# 0: 384x384 12 Nucs, 958 Strias, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 23483
# iteration:  142
#
# 0: 384x384 10 Nucs, 1049 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 24542
# iteration:  143
#
# 0: 384x384 1 Nuc, 1082 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 25625
# iteration:  144
#
# 0: 384x384 1 Nuc, 1170 Strias, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 26796
# iteration:  145
#
# 0: 384x384 7 Nucs, 949 Strias, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 27752
# iteration:  146
#
# 0: 384x384 1160 Strias, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 28912
# iteration:  147
#
# 0: 384x384 1 Nuc, 1154 Strias, 21.4ms
# Speed: 1.0ms preprocess, 21.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 30067
# iteration:  148
#
# 0: 384x384 1274 Strias, 22.1ms
# Speed: 1.6ms preprocess, 22.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 31341
# iteration:  149
#
# 0: 384x384 1220 Strias, 21.0ms
# Speed: 7.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 32561
# iteration:  150
#
# 0: 384x384 1223 Strias, 22.1ms
# Speed: 1.1ms preprocess, 22.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 384)
# 33784
# iteration:  151
#
# 0: 384x384 1170 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 34954
# iteration:  152
#
# 0: 384x384 20 Nucs, 551 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 35525
# iteration:  153
#
# 0: 384x384 15 Nucs, 509 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 36049
# iteration:  154
#
# 0: 384x384 19 Nucs, 177 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 36234
# iteration:  155
#
# 0: 384x384 28 Nucs, 21.7ms
# Speed: 1.0ms preprocess, 21.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  156
#
# 0: 384x384 29 Nucs, 22.6ms
# Speed: 1.0ms preprocess, 22.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  157
#
# 0: 384x384 30 Nucs, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  158
#
# 0: 384x384 32 Nucs, 21.7ms
# Speed: 1.0ms preprocess, 21.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  159
#
# 0: 384x384 30 Nucs, 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  160
#
# 0: 384x384 30 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  161
#
# 0: 384x384 27 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  162
#
# 0: 384x384 29 Nucs, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 36237
# iteration:  163
#
# 0: 384x256 3 Nucs, 6 Strias, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 36246
# ERRRORORORORORORORO
# iteration:  164
#
# 0: 384x384 32 Nucs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  171
#
# 0: 384x384 9 Nucs, 195 Strias, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 384)
# 36443
# iteration:  172
#
# 0: 384x384 7 Nucs, 1041 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 37491
# iteration:  173
#
# 0: 384x384 114 Nucs, 111 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 37716
# iteration:  174
#
# 0: 384x384 16 Nucs, 993 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 38725
# iteration:  175
#
# 0: 384x384 7 Nucs, 1012 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 39744
# iteration:  176
#
# 0: 384x384 1 Nuc, 1102 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 40847
# iteration:  177
#
# 0: 384x384 1 Nuc, 990 Strias, 22.6ms
# Speed: 1.0ms preprocess, 22.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 41838
# iteration:  178
#
# 0: 384x384 1160 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 42998
# iteration:  179
#
# 0: 384x384 1239 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 44237
# iteration:  180
#
# 0: 384x384 1 Nuc, 1153 Strias, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 45391
# iteration:  181
#
# 0: 384x384 1161 Strias, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 46552
# iteration:  182
#
# 0: 384x384 1181 Strias, 23.0ms
# Speed: 3.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 47733
# iteration:  183
#
# 0: 384x384 1190 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 384)
# 48923
# iteration:  184
#
# 0: 384x384 1247 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 384)
# 50170
# iteration:  185
#
# 0: 384x384 2 Nucs, 1321 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 51493
# iteration:  186
#
# 0: 384x384 7 Nucs, 1050 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 52550
# iteration:  187
#
# 0: 384x384 5 Nucs, 1035 Strias, 21.4ms
# Speed: 1.0ms preprocess, 21.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 53590
# iteration:  188
#
# 0: 384x384 16 Nucs, 874 Strias, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 54480
# iteration:  189
#
# 0: 384x384 30 Nucs, 237 Strias, 23.1ms
# Speed: 1.0ms preprocess, 23.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 384)
# 54747
# iteration:  190
#
# 0: 384x384 30 Nucs, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  191
#
# 0: 384x384 33 Nucs, 21.1ms
# Speed: 0.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  192
#
# 0: 384x384 29 Nucs, 21.7ms
# Speed: 7.0ms preprocess, 21.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  193
#
# 0: 384x384 26 Nucs, 22.3ms
# Speed: 4.0ms preprocess, 22.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  194
#
# 0: 384x384 28 Nucs, 21.5ms
# Speed: 7.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  195
#
# 0: 384x384 30 Nucs, 21.0ms
# Speed: 5.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  196
#
# 0: 384x384 30 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  197
#
# 0: 384x256 17 Nucs, 24.0ms
# Speed: 4.0ms preprocess, 24.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 256)
# 54748
# ERRRORORORORORORORO
# iteration:  198
#
# 0: 384x384 31 Nucs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  205
#
# 0: 384x384 6 Nucs, 333 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 55087
# iteration:  206
#
# 0: 384x384 1157 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 56244
# iteration:  207
#
# 0: 384x384 95 Nucs, 174 Strias, 20.8ms
# Speed: 3.0ms preprocess, 20.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 56513
# iteration:  208
#
# 0: 384x384 35 Nucs, 629 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 57177
# iteration:  209
#
# 0: 384x384 10 Nucs, 1025 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 58212
# iteration:  210
#
# 0: 384x384 1068 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 384)
# 59280
# iteration:  211
#
# 0: 384x384 1 Nuc, 1058 Strias, 21.6ms
# Speed: 0.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 60339
# iteration:  212
#
# 0: 384x384 6 Nucs, 1030 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 61375
# iteration:  213
#
# 0: 384x384 1 Nuc, 1135 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 62511
# iteration:  214
#
# 0: 384x384 1230 Strias, 21.0ms
# Speed: 4.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 63741
# iteration:  215
#
# 0: 384x384 2 Nucs, 1185 Strias, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 64928
# iteration:  216
#
# 0: 384x384 1332 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 66260
# iteration:  217
#
# 0: 384x384 1311 Strias, 21.5ms
# Speed: 4.6ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 67571
# iteration:  218
#
# 0: 384x384 6 Nucs, 1049 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 68626
# iteration:  219
#
# 0: 384x384 4 Nucs, 1007 Strias, 25.0ms
# Speed: 0.0ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 69637
# iteration:  220
#
# 0: 384x384 2 Nucs, 1251 Strias, 22.0ms
# Speed: 4.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 70890
# iteration:  221
#
# 0: 384x384 1221 Strias, 22.4ms
# Speed: 0.5ms preprocess, 22.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 72111
# iteration:  222
#
# 0: 384x384 2 Nucs, 1154 Strias, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 73267
# iteration:  223
#
# 0: 384x384 9 Nucs, 999 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 74275
# iteration:  224
#
# 0: 384x384 6 Nucs, 441 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 74722
# iteration:  225
#
# 0: 384x384 31 Nucs, 6 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 74731
# iteration:  226
#
# 0: 384x384 31 Nucs, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  227
#
# 0: 384x384 29 Nucs, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  228
#
# 0: 384x384 28 Nucs, 22.0ms
# Speed: 4.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  229
#
# 0: 384x384 32 Nucs, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  230
#
# 0: 384x384 27 Nucs, 22.0ms
# Speed: 4.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  231
#
# 0: 384x256 19 Nucs, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  232
#
# 0: 384x384 30 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  239
#
# 0: 384x384 31 Nucs, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  240
#
# 0: 384x384 4 Nucs, 740 Strias, 22.2ms
# Speed: 1.0ms preprocess, 22.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 75475
# iteration:  241
#
# 0: 384x384 33 Nucs, 760 Strias, 21.0ms
# Speed: 6.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 76268
# iteration:  242
#
# 0: 384x384 3 Nucs, 1122 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 77393
# iteration:  243
#
# 0: 384x384 2 Nucs, 1073 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 78468
# iteration:  244
#
# 0: 384x384 1003 Strias, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 79471
# iteration:  245
#
# 0: 384x384 3 Nucs, 945 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 80419
# iteration:  246
#
# 0: 384x384 3 Nucs, 1048 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 81470
# iteration:  247
#
# 0: 384x384 1050 Strias, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 82520
# iteration:  248
#
# 0: 384x384 1160 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 83680
# iteration:  249
#
# 0: 384x384 1 Nuc, 1062 Strias, 21.4ms
# Speed: 4.6ms preprocess, 21.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 84743
# iteration:  250
#
# 0: 384x384 1204 Strias, 20.1ms
# Speed: 6.0ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 85947
# iteration:  251
#
# 0: 384x384 1307 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 87254
# iteration:  252
#
# 0: 384x384 1119 Strias, 21.7ms
# Speed: 2.6ms preprocess, 21.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 88373
# iteration:  253
#
# 0: 384x384 1143 Strias, 22.1ms
# Speed: 1.0ms preprocess, 22.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 89516
# iteration:  254
#
# 0: 384x384 1 Nuc, 1179 Strias, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 90696
# iteration:  255
#
# 0: 384x384 1230 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 91926
# iteration:  256
#
# 0: 384x384 1370 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 93296
# iteration:  257
#
# 0: 384x384 1227 Strias, 21.5ms
# Speed: 4.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 94523
# iteration:  258
#
# 0: 384x384 1 Nuc, 1163 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 95687
# iteration:  259
#
# 0: 384x384 14 Nucs, 399 Strias, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 96100
# iteration:  260
#
# 0: 384x384 18 Nucs, 162 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 96273
# iteration:  261
#
# 0: 384x384 28 Nucs, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  262
#
# 0: 384x384 29 Nucs, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 96277
# iteration:  263
#
# 0: 384x384 31 Nucs, 7 Strias, 22.8ms
# Speed: 4.0ms preprocess, 22.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 96288
# iteration:  264
#
# 0: 384x384 31 Nucs, 21.0ms
# Speed: 5.6ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  265
#
# 0: 384x256 20 Nucs, 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  266
#
# 0: 384x384 32 Nucs, 23.5ms
# Speed: 0.5ms preprocess, 23.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  273
#
# 0: 384x384 30 Nucs, 24.1ms
# Speed: 0.6ms preprocess, 24.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  274
#
# 0: 384x384 23 Nucs, 429 Strias, 22.4ms
# Speed: 1.0ms preprocess, 22.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 96740
# iteration:  275
#
# 0: 384x384 1224 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 97964
# iteration:  276
#
# 0: 384x384 1226 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 99190
# iteration:  277
#
# 0: 384x384 1179 Strias, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 100369
# iteration:  278
#
# 0: 384x384 4 Nucs, 1061 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 101434
# iteration:  279
#
# 0: 384x384 1 Nuc, 976 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 102411
# iteration:  280
#
# 0: 384x384 1038 Strias, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 103449
# iteration:  281
#
# 0: 384x384 7 Nucs, 1036 Strias, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 104492
# iteration:  282
#
# 0: 384x384 3 Nucs, 1011 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 105506
# iteration:  283
#
# 0: 384x384 3 Nucs, 988 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 106497
# iteration:  284
#
# 0: 384x384 1222 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 107719
# iteration:  285
#
# 0: 384x384 4 Nucs, 1140 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 108863
# iteration:  286
#
# 0: 384x384 3 Nucs, 1137 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 110003
# iteration:  287
#
# 0: 384x384 2 Nucs, 1075 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 111080
# iteration:  288
#
# 0: 384x384 1 Nuc, 1314 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 112395
# iteration:  289
#
# 0: 384x384 1 Nuc, 1304 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 113700
# iteration:  290
#
# 0: 384x384 1 Nuc, 1306 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 115007
# iteration:  291
#
# 0: 384x384 1475 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 116482
# iteration:  292
#
# 0: 384x384 4 Nucs, 1173 Strias, 21.0ms
# Speed: 6.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 117659
# iteration:  293
#
# 0: 384x384 25 Nucs, 546 Strias, 20.9ms
# Speed: 1.5ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 118230
# iteration:  294
#
# 0: 384x384 4 Nucs, 997 Strias, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 119231
# iteration:  295
#
# 0: 384x384 12 Nucs, 506 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 119749
# iteration:  296
#
# 0: 384x384 21 Nucs, 816 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 120586
# iteration:  297
#
# 0: 384x384 7 Nucs, 991 Strias, 22.2ms
# Speed: 2.6ms preprocess, 22.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 121584
# iteration:  298
#
# 0: 384x384 19 Nucs, 148 Strias, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 121736
# iteration:  299
#
# 0: 384x256 20 Nucs, 23.0ms
# Speed: 0.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  300
#
# 0: 384x384 29 Nucs, 22.5ms
# Speed: 0.0ms preprocess, 22.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# iteration:  307
#
# 0: 384x384 26 Nucs, 35 Strias, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 121775
# iteration:  308
#
# 0: 384x384 6 Nucs, 948 Strias, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 122729
# iteration:  309
#
# 0: 384x384 14 Nucs, 940 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 123683
# iteration:  310
#
# 0: 384x384 10 Nucs, 1060 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 124753
# iteration:  311
#
# 0: 384x384 2 Nucs, 1133 Strias, 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 125888
# iteration:  312
#
# 0: 384x384 1 Nuc, 1080 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 126969
# iteration:  313
#
# 0: 384x384 1054 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 128023
# iteration:  314
#
# 0: 384x384 1172 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 129195
# iteration:  315
#
# 0: 384x384 10 Nucs, 958 Strias, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 130163
# iteration:  316
#
# 0: 384x384 1192 Strias, 22.5ms
# Speed: 0.0ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 131355
# iteration:  317
#
# 0: 384x384 1297 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 132652
# iteration:  318
#
# 0: 384x384 1329 Strias, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 133981
# iteration:  319
#
# 0: 384x384 1212 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 135193
# iteration:  320
#
# 0: 384x384 1120 Strias, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 136313
# iteration:  321
#
# 0: 384x384 4 Nucs, 1243 Strias, 21.0ms
# Speed: 5.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 137560
# iteration:  322
#
# 0: 384x384 4 Nucs, 1272 Strias, 22.0ms
# Speed: 5.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 138836
# iteration:  323
#
# 0: 384x384 17 Nucs, 748 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 139601
# iteration:  324
#
# 0: 384x384 6 Nucs, 1236 Strias, 21.0ms
# Speed: 7.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 140843
# iteration:  325
#
# 0: 384x384 1314 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 142157
# iteration:  326
#
# 0: 384x384 1252 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 143409
# iteration:  327
#
# 0: 384x384 1238 Strias, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 144647
# iteration:  328
#
# 0: 384x384 1278 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 145925
# iteration:  329
#
# 0: 384x384 1305 Strias, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 147230
# iteration:  330
#
# 0: 384x384 1 Nuc, 1385 Strias, 22.0ms
# Speed: 3.6ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 148616
# iteration:  331
#
# 0: 384x384 1 Nuc, 1334 Strias, 22.3ms
# Speed: 1.0ms preprocess, 22.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 149951
# iteration:  332
#
# 0: 384x384 11 Nucs, 342 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 150302
# iteration:  333
#
# 0: 384x256 20 Nucs, 21.7ms
# Speed: 1.0ms preprocess, 21.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 0
# ERRRORORORORORORORO
# iteration:  334
#
# 0: 384x384 28 Nucs, 22 Strias, 23.5ms
# Speed: 0.0ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 150330
# iteration:  341
#
# 0: 384x384 4 Nucs, 688 Strias, 21.4ms
# Speed: 1.0ms preprocess, 21.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 151022
# iteration:  342
#
# 0: 384x384 5 Nucs, 988 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 152015
# iteration:  343
#
# 0: 384x384 1188 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 153203
# iteration:  344
#
# 0: 384x384 1 Nuc, 1116 Strias, 20.6ms
# Speed: 3.0ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 154320
# iteration:  345
#
# 0: 384x384 1139 Strias, 21.6ms
# Speed: 5.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 155459
# iteration:  346
#
# 0: 384x384 1 Nuc, 1080 Strias, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 156540
# iteration:  347
#
# 0: 384x384 1067 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 157607
# iteration:  348
#
# 0: 384x384 3 Nucs, 1121 Strias, 22.1ms
# Speed: 1.0ms preprocess, 22.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 158731
# iteration:  349
#
# 0: 384x384 1273 Strias, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 160004
# iteration:  350
#
# 0: 384x384 3 Nucs, 1266 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 161273
# iteration:  351
#
# 0: 384x384 1340 Strias, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 162613
# iteration:  352
#
# 0: 384x384 1103 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 163716
# iteration:  353
#
# 0: 384x384 1266 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 164982
# iteration:  354
#
# 0: 384x384 1 Nuc, 1215 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 166198
# iteration:  355
#
# 0: 384x384 2 Nucs, 1138 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 167338
# iteration:  356
#
# 0: 384x384 7 Nucs, 942 Strias, 21.0ms
# Speed: 0.6ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 168287
# iteration:  357
#
# 0: 384x384 25 Nucs, 170 Strias, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 168482
# iteration:  358
#
# 0: 384x384 13 Nucs, 1061 Strias, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 169556
# iteration:  359
#
# 0: 384x384 1420 Strias, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 170976
# iteration:  360
#
# 0: 384x384 1337 Strias, 21.6ms
# Speed: 1.1ms preprocess, 21.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 172313
# iteration:  361
#
# 0: 384x384 1394 Strias, 21.0ms
# Speed: 5.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 173707
# iteration:  362
#
# 0: 384x384 1173 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 174880
# iteration:  363
#
# 0: 384x384 1 Nuc, 1336 Strias, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 176217
# iteration:  364
#
# 0: 384x384 1436 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 177653
# iteration:  365
#
# 0: 384x384 6 Nucs, 1309 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 178968
# iteration:  366
#
# 0: 384x384 7 Nucs, 1177 Strias, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 180152
# iteration:  367
#
# 0: 384x256 11 Nucs, 409 Strias, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 256)
# 180572
# ERRRORORORORORORORO
# iteration:  368
#
# 0: 384x384 12 Nucs, 237 Strias, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 180821
# iteration:  375
#
# 0: 384x384 8 Nucs, 713 Strias, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 181542
# iteration:  376
#
# 0: 384x384 2 Nucs, 1032 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 182576
# iteration:  377
#
# 0: 384x384 2 Nucs, 1172 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 183750
# iteration:  378
#
# 0: 384x384 8 Nucs, 1100 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 184858
# iteration:  379
#
# 0: 384x384 17 Nucs, 969 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 185844
# iteration:  380
#
# 0: 384x384 1125 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 186969
# iteration:  381
#
# 0: 384x384 1154 Strias, 21.5ms
# Speed: 6.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 188123
# iteration:  382
#
# ...
# Speed: 4.0ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 669848
# iteration:  900
#
# 0: 384x384 1300 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 671148
# iteration:  901
#
# 0: 384x384 8 Nucs, 1052 Strias, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 672208
# iteration:  902
#
# 0: 384x384 3 Nucs, 1178 Strias, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 673389
# iteration:  903
#
# 0: 384x384 19 Nucs, 840 Strias, 21.0ms
# Speed: 5.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 674248
# iteration:  904
#
# 0: 384x384 1 Nuc, 1362 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
# 675611
# iteration:  905
#
# 0: 384x384 4 Nucs, 1267 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 676882
# iteration:  906
#
# 0: 384x384 1217 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 678099
# iteration:  907
#
# 0: 384x384 2 Nucs, 1228 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 679329
# iteration:  908
#
# 0: 384x384 1125 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 680454
# iteration:  909
#
# 0: 384x384 3 Nucs, 1122 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 681579
# iteration:  910
#
# 0: 384x384 1207 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 682786
# iteration:  911
#
# 0: 384x256 1 Nuc, 714 Strias, 22.5ms
# Speed: 5.0ms preprocess, 22.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 683501
# ERRRORORORORORORORO
# iteration:  912
#
# 0: 384x384 117 Nucs, 108 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 683726
# iteration:  919
#
# 0: 384x384 13 Nucs, 902 Strias, 22.1ms
# Speed: 0.5ms preprocess, 22.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 684641
# iteration:  920
#
# 0: 384x384 4 Nucs, 1101 Strias, 22.1ms
# Speed: 1.0ms preprocess, 22.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 685746
# iteration:  921
#
# 0: 384x384 55 Nucs, 267 Strias, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 686068
# iteration:  922
#
# 0: 384x384 31 Nucs, 891 Strias, 26.0ms
# Speed: 0.0ms preprocess, 26.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 686990
# iteration:  923
#
# 0: 384x384 6 Nucs, 1125 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 688121
# iteration:  924
#
# 0: 384x384 1 Nuc, 1178 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 689300
# iteration:  925
#
# 0: 384x384 4 Nucs, 1237 Strias, 21.4ms
# Speed: 1.0ms preprocess, 21.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 690541
# iteration:  926
#
# 0: 384x384 1106 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 691647
# iteration:  927
#
# 0: 384x384 5 Nucs, 977 Strias, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 692629
# iteration:  928
#
# 0: 384x384 43 Nucs, 573 Strias, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 693245
# iteration:  929
#
# 0: 384x384 40 Nucs, 665 Strias, 22.6ms
# Speed: 0.0ms preprocess, 22.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 693950
# iteration:  930
#
# 0: 384x384 1 Nuc, 1239 Strias, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 695190
# iteration:  931
#
# 0: 384x384 2 Nucs, 1195 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 696387
# iteration:  932
#
# 0: 384x384 17 Nucs, 960 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 697364
# iteration:  933
#
# 0: 384x384 21 Nucs, 1111 Strias, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 698496
# iteration:  934
#
# 0: 384x384 1212 Strias, 21.0ms
# Speed: 1.1ms preprocess, 21.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
# 699708
# iteration:  935
#
# 0: 384x384 5 Nucs, 1012 Strias, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 700725
# iteration:  936
#
# 0: 384x384 3 Nucs, 1145 Strias, 20.3ms
# Speed: 0.0ms preprocess, 20.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 701873
# iteration:  937
#
# 0: 384x384 12 Nucs, 1018 Strias, 21.0ms
# Speed: 4.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 702903
# iteration:  938
#
# 0: 384x384 4 Nucs, 1111 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 704018
# iteration:  939
#
# 0: 384x384 17 Nucs, 1041 Strias, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 705076
# iteration:  940
#
# 0: 384x384 4 Nucs, 964 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 706044
# iteration:  941
#
# 0: 384x384 8 Nucs, 585 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 706637
# iteration:  942
#
# 0: 384x384 5 Nucs, 1178 Strias, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 707820
# iteration:  943
#
# 0: 384x384 6 Nucs, 1000 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 708826
# iteration:  944
#
# 0: 384x384 7 Nucs, 1042 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 709875
# iteration:  945
#
# 0: 384x256 1 Nuc, 789 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 710665
# ERRRORORORORORORORO
# iteration:  946
#
# 0: 384x384 26 Nucs, 904 Strias, 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 711595
# iteration:  953
#
# 0: 384x384 12 Nucs, 1262 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 712869
# iteration:  954
#
# 0: 384x384 22 Nucs, 819 Strias, 22.0ms
# Speed: 4.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 713710
# iteration:  955
#
# 0: 384x384 40 Nucs, 475 Strias, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 714225
# iteration:  956
#
# 0: 384x384 22 Nucs, 990 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 715237
# iteration:  957
#
# 0: 384x384 28 Nucs, 829 Strias, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 716094
# iteration:  958
#
# 0: 384x384 2 Nucs, 1005 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 717101
# iteration:  959
#
# 0: 384x384 1144 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 718245
# iteration:  960
#
# 0: 384x384 6 Nucs, 1086 Strias, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 719337
# iteration:  961
#
# 0: 384x384 28 Nucs, 572 Strias, 21.8ms
# Speed: 0.5ms preprocess, 21.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 719937
# iteration:  962
#
# 0: 384x384 32 Nucs, 599 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 720568
# iteration:  963
#
# 0: 384x384 13 Nucs, 927 Strias, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 721508
# iteration:  964
#
# 0: 384x384 2 Nucs, 1151 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 722661
# iteration:  965
#
# 0: 384x384 1120 Strias, 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 723781
# iteration:  966
#
# 0: 384x384 9 Nucs, 1061 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 724851
# iteration:  967
#
# 0: 384x384 6 Nucs, 980 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 725837
# iteration:  968
#
# 0: 384x384 10 Nucs, 1019 Strias, 21.1ms
# Speed: 0.0ms preprocess, 21.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 384)
# 726866
# iteration:  969
#
# 0: 384x384 22 Nucs, 990 Strias, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 384)
# 727878
# iteration:  970
#
# 0: 384x384 2 Nucs, 1350 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 729230
# iteration:  971
#
# 0: 384x384 3 Nucs, 1106 Strias, 20.8ms
# Speed: 1.0ms preprocess, 20.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 730339
# iteration:  972
#
# 0: 384x384 9 Nucs, 822 Strias, 20.6ms
# Speed: 4.0ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 731170
# iteration:  973
#
# 0: 384x384 31 Nucs, 322 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 731523
# iteration:  974
#
# 0: 384x384 28 Nucs, 14 Strias, 20.5ms
# Speed: 1.0ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 731549
# iteration:  975
#
# 0: 384x384 22 Nucs, 330 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 731901
# iteration:  976
#
# 0: 384x384 7 Nucs, 925 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 732833
# iteration:  977
#
# 0: 384x384 2 Nucs, 1088 Strias, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 733923
# iteration:  978
#
# 0: 384x384 1284 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 735207
# iteration:  979
#
# 0: 384x256 885 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 736092
# ERRRORORORORORORORO
# iteration:  980
#
# 0: 384x384 21 Nucs, 584 Strias, 23.4ms
# Speed: 1.6ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 736697
# ERRRORORORORORORORO
# iteration:  987
#
# 0: 384x384 5 Nucs, 1184 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 737886
# ERRRORORORORORORORO
# iteration:  988
#
# 0: 384x384 70 Nucs, 301 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 738257
# ERRRORORORORORORORO
# iteration:  989
#
# 0: 384x384 1029 Strias, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 739286
# ERRRORORORORORORORO
# iteration:  990
#
# 0: 384x384 7 Nucs, 1027 Strias, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 740320
# ERRRORORORORORORORO
# iteration:  991
#
# 0: 384x384 38 Nucs, 521 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 740879
# ERRRORORORORORORORO
# iteration:  992
#
# 0: 384x384 33 Nucs, 940 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 741852
# ERRRORORORORORORORO
# iteration:  993
#
# 0: 384x384 1004 Strias, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 742856
# ERRRORORORORORORORO
# iteration:  994
#
# 0: 384x384 1191 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 744047
# ERRRORORORORORORORO
# iteration:  995
#
# 0: 384x384 31 Nucs, 479 Strias, 21.2ms
# Speed: 2.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 744557
# ERRRORORORORORORORO
# iteration:  996
#
# 0: 384x384 29 Nucs, 701 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 745287
# ERRRORORORORORORORO
# iteration:  997
#
# 0: 384x384 24 Nucs, 829 Strias, 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 746140
# ERRRORORORORORORORO
# iteration:  998
#
# 0: 384x384 20 Nucs, 832 Strias, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 746992
# ERRRORORORORORORORO
# iteration:  999
#
# 0: 384x384 6 Nucs, 1090 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 748088
# ERRRORORORORORORORO
# iteration:  1000
#
# 0: 384x384 4 Nucs, 1099 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 749191
# ERRRORORORORORORORO
# iteration:  1001
#
# 0: 384x384 18 Nucs, 946 Strias, 22.4ms
# Speed: 0.5ms preprocess, 22.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 384)
# 750155
# ERRRORORORORORORORO
# iteration:  1002
#
# 0: 384x384 22 Nucs, 743 Strias, 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 750920
# ERRRORORORORORORORO
# iteration:  1003
#
# 0: 384x384 11 Nucs, 1141 Strias, 21.0ms
# Speed: 1.6ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 752072
# ERRRORORORORORORORO
# iteration:  1004
#
# 0: 384x384 4 Nucs, 1262 Strias, 21.0ms
# Speed: 6.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 753338
# ERRRORORORORORORORO
# iteration:  1005
#
# 0: 384x384 5 Nucs, 986 Strias, 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 754329
# ERRRORORORORORORORO
# iteration:  1006
#
# 0: 384x384 31 Nucs, 520 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 754880
# ERRRORORORORORORORO
# iteration:  1007
#
# 0: 384x384 17 Nucs, 181 Strias, 22.4ms
# Speed: 1.0ms preprocess, 22.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 384)
# 755075
# ERRRORORORORORORORO
# iteration:  1008
#
# 0: 384x384 29 Nucs, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 0
# ERRRORORORORORORORO
# iteration:  1009
#
# 0: 384x384 16 Nucs, 196 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 755277
# ERRRORORORORORORORO
# iteration:  1010
#
# 0: 384x384 11 Nucs, 289 Strias, 20.6ms
# Speed: 5.0ms preprocess, 20.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# 755567
# ERRRORORORORORORORO
# iteration:  1011
#
# 0: 384x384 8 Nucs, 390 Strias, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 755961
# ERRRORORORORORORORO
# iteration:  1012
#
# 0: 384x384 9 Nucs, 417 Strias, 21.0ms
# Speed: 5.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
# 756380
# ERRRORORORORORORORO
# iteration:  1013
#
# 0: 384x256 5 Nucs, 181 Strias, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 256)
# 756561
# ERRRORORORORORORORO
# iteration:  1014

# %%
big_array[i-start_y:i-start_y+tile.shape[0] , j-start_x:j - start_x+tile.shape[1]].shape
# Out:
# (249, 0)

# %%
cropped_array = big_array[0:image_resized.height - 384, 0:image_resized.width - 384]
Image.fromarray(cropped_array).show()

# %%
cropped_array.shape
# Out:
# (11385, 10233)

# %%
np.savetxt(r"R:\FIVE\EXP\FIV925\Additional Datasets\Human Lung Cancer\array_2x2b.csv", cropped_array, delimiter=",")#, fmt='%.2f')
