# %%
from PIL import Image
from ultralytics import YOLO
import json
import numpy as np
import matplotlib.path as mpltPath
import csv
import matplotlib.pyplot as plt
import sys
import matplotlib.colors as mcolors
import cv2
import statistics
import math
import os

# %%
model_path = r"S:\Phys\FIV942 Adipo\Datasets\02h9\YO 512 0320 Snow\map75=0607616 YOLOv8n-segml idx=5 ep=52 btch=32 rnd=4670342\weights\best.pt"
val_data = r"S:\Phys\FIV942 Adipo\Adipo2Viz 512"

files = os.listdir(val_data)

model = YOLO(model_path)
predictions = model.predict(val_data, show=False, max_det=1000)

def polygon_area(coords):
    """
    Calculate the area of a polygon given its vertices using numpy.
    :param coords: A numpy array of shape (n, 2), where n is the number of vertices.
    :return: The area of the polygon.
    """
    x = coords[:, 0]
    y = coords[:, 1]
    i = np.arange(len(x))
    # 'shoelace' formula
    # return 0.5*np.abs(np.dot(x, np.roll(y, -1)) - np.dot(y, np.roll(x, -1)))
    return np.abs(np.sum(x[i-1]*y[i]-x[i]*y[i-1])*0.5)

def find_parents(classes, image):
    class0_indices = np.where(classes == 0)[0]
    class1_indices = np.where(classes == 1)[0]
    
    class1_centers = image.boxes.xywh[class1_indices]
    class0_centers = image.boxes.xywh[class0_indices]
    
    class1_parents = []
    for class1_coord in class1_centers.numpy():
                # print("the class1 instance: ", class1_coord)
                
                droplet_x = class1_coord[0]
                droplet_y = class1_coord[1]
                # print("droplet x, y coords: ", droplet_x, droplet_y)
                min_distance_from_cells = math.inf
                parent_cell_index = 0
                for i, class0_coord in enumerate(class0_centers.numpy()):
                    # print("the class0 instance: ", class0_coord)
                    
                    cell_x = class0_coord[0]
                    cell_y = class0_coord[1]
                    # print("cell x, y coords: ", cell_x, cell_y)
                    point1 = np.array((droplet_x, droplet_y))
                    point2 = np.array((cell_x, cell_y))
                    dist = np.linalg.norm(point1 - point2)
                    # print("dist from class0 instance: ", dist)
                    if dist < min_distance_from_cells:
                        min_distance_from_cells = dist
                        parent_cell_index = i
                        
                # print("parent cell index: ", parent_cell_index)        
                class1_parents.append(class0_indices[parent_cell_index])
    return class1_parents

def find_mask_intensities(img_mask_coords, image_path):
    image_array = np.array(Image.open(image_path))
    pixel_intensity_data = []
    for mask_outline in range(len(img_mask_coords)):
        vertices = img_mask_coords[mask_outline]

        
        # Assuming image_array is a 2D numpy array for a grayscale image
        # For a color image, you need to decide how to handle the color channels

        # Create a mesh grid of coordinate values
        xx, yy = np.meshgrid(np.arange(image_array.shape[1]), np.arange(image_array.shape[0]))

        # Flatten the grid arrays
        x_flat = xx.flatten()
        y_flat = yy.flatten()

        # Create a list of (x, y) points from the flattened grid
        class1_points = np.vstack((x_flat, y_flat)).T

        # Create a path object from the vertices
        polygon_path = mpltPath.Path(vertices)

        # Use the path object to create a mask
        inside_polygon = polygon_path.contains_points(class1_points)

        # Reshape the mask back to the image shape
        mask = inside_polygon.reshape(xx.shape)

        # Apply the mask to select pixels within the polygon
        # selected_pixels = image_array[mask]

        # Sum the intensities of the selected pixels
        # sum_of_intensities = np.sum(selected_pixels)

        # print("Sum of pixel intensities in the polygonal region:", sum_of_intensities)
        # Initialize an array to hold the sum of intensities for each channel
        sum_of_intensities_per_channel = np.zeros(image_array.shape[2])

        # Iterate over each channel
        for i in range(image_array.shape[2]):
            # Apply the mask to the current channel and sum the intensities
            selected_pixels = image_array[:, :, i][mask]
            sum_of_intensities_per_channel[i] = np.sum(selected_pixels)

        # print("Sum of pixel intensities in the polygonal region for each channel:", sum_of_intensities_per_channel)
        pixel_intensity_data.append(sum_of_intensities_per_channel)
        
    return pixel_intensity_data

def find_box_intensities(img_data, image_path):
    img_box_centers = img_data.boxes.xywh.numpy()
    image_array = np.array(Image.open(image_path))
    box_intensity_data = []
    for box_instance in range(len(img_box_centers)):
        bbox_xywh = img_box_centers[box_instance]
        bbox_corners = [[bbox_xywh[0] - bbox_xywh[2], bbox_xywh[1] + bbox_xywh[3]],[bbox_xywh[0] + bbox_xywh[2], bbox_xywh[1] + bbox_xywh[3]]
                    , [bbox_xywh[0] + bbox_xywh[2], bbox_xywh[1] - bbox_xywh[3]], [bbox_xywh[0] - bbox_xywh[2], bbox_xywh[1] - bbox_xywh[3]]]
        vertices = bbox_corners

        
        # Assuming image_array is a 2D numpy array for a grayscale image
        # For a color image, you need to decide how to handle the color channels

        # Create a mesh grid of coordinate values
        xx, yy = np.meshgrid(np.arange(image_array.shape[1]), np.arange(image_array.shape[0]))

        # Flatten the grid arrays
        x_flat = xx.flatten()
        y_flat = yy.flatten()

        # Create a list of (x, y) points from the flattened grid
        class1_points = np.vstack((x_flat, y_flat)).T

        # Create a path object from the vertices
        polygon_path = mpltPath.Path(vertices)

        # Use the path object to create a mask
        inside_polygon = polygon_path.contains_points(class1_points)

        # Reshape the mask back to the image shape
        mask = inside_polygon.reshape(xx.shape)

        # Apply the mask to select pixels within the polygon
        # selected_pixels = image_array[mask]

        # Sum the intensities of the selected pixels
        # sum_of_intensities = np.sum(selected_pixels)

        # print("Sum of pixel intensities in the polygonal region:", sum_of_intensities)
        # Initialize an array to hold the sum of intensities for each channel
        sum_of_intensities_per_channel = np.zeros(image_array.shape[2])

        # Iterate over each channel
        for i in range(image_array.shape[2]):
            # Apply the mask to the current channel and sum the intensities
            selected_pixels = image_array[:, :, i][mask]
            sum_of_intensities_per_channel[i] = np.sum(selected_pixels)

        # print("Sum of pixel intensities in the polygonal region for each channel:", sum_of_intensities_per_channel)
        box_intensity_data.append(sum_of_intensities_per_channel)
        
    return box_intensity_data 

header = ["FilePath", "PolyID","cls","Vertices","Number of Vertices","PolyArea","Sum Inten WV0","SumInten WV1", "SumInten WV2","BBox x","BBox y","BBox w","BBox h",
          "BBox intensity WV0", "BBox intensity WV1","BBox intensity WV2","Conf","PolySum", "PolyAvg", "PolyStDDev", "BoxSum", "BoxAvg", "BoxStDDev", "Parents"]
data = []

for i, image_data in enumerate(predictions):
    print("image ", i)
    print("image name: ", os.listdir(val_data)[i])
    img_box_coords = image_data.boxes.xyxy
    image_path = val_data + "\\" + os.listdir(val_data)[i]
    image_info_toexport = []
    
    contains_masks = True
    if image_data.masks == None:
        contains_masks = False
    print("contains masks? ", contains_masks)
    
    classes = image_data.names
    print("classes: ", classes)
    
    polygon_areas = []
    pixel_intensity_data = []
    if contains_masks:
        polygon_areas = [polygon_area(mask) for mask in image_data.masks.xy]
        print("polygon areas: ", polygon_areas)
        pixel_intensity_data = find_mask_intensities(image_data.masks.xy, image_path)
        print("pixel intensities: ", pixel_intensity_data)
    
    box_intensity_data = find_box_intensities(image_data, image_path)
    print("box intensities: ", box_intensity_data)
    
    print("same number of boxes as polygons? ", len(box_intensity_data) == len(pixel_intensity_data))
        
    class1_parents = []
    if len(classes) == 2:
        class1_parents = find_parents(image_data.boxes.cls.numpy(), image_data)
        print("class1 parents: ", class1_parents)
        
    class1_counter = 0    
    for j in range(len(polygon_areas)):
        cls = predictions[i].boxes[j].cls.numpy().item(0)
        vertices = image_data.masks.xy[j]
        numVertices = len(vertices)
        polyArea = polygon_areas[j]
        bbox_data = predictions[i].boxes[j].xywh.numpy()
        conf = predictions[i].boxes.conf.numpy().item(j)
        polySum = sum([pixel_intensity_data[j][0],pixel_intensity_data[j][1],pixel_intensity_data[j][2]])
        polyAvg = polySum / 3
        polyStdDev = statistics.pstdev([pixel_intensity_data[j][0],pixel_intensity_data[j][1],pixel_intensity_data[j][2]])
        boxSum = sum([box_intensity_data[j][0],box_intensity_data[j][1],box_intensity_data[j][2]])
        boxAvg = boxSum / 3
        boxStdDev = statistics.pstdev([box_intensity_data[j][0],box_intensity_data[j][1],box_intensity_data[j][2]])
        polygon_data = [image_path,j,cls,vertices,numVertices,polyArea,pixel_intensity_data[j][0],pixel_intensity_data[j][1],pixel_intensity_data[j][2]
                        , bbox_data.item(0), bbox_data.item(1), bbox_data.item(2), bbox_data.item(3),box_intensity_data[j][0],box_intensity_data[j][1],box_intensity_data[j][2]
                        ,conf, polySum, polyAvg, polyStdDev, boxSum, boxAvg, boxStdDev]
        if np.where(image_data.boxes.cls.numpy() == 1)[0].__contains__(j):
            # print(j)
            polygon_data.append(class1_parents[class1_counter])
            print("class1 index before increment: ", class1_counter)
            class1_counter += 1
            print("class1 index after increment: ", class1_counter)
        data.append(polygon_data)
        
filename = 'polygon_image_data_test.csv'
with open(filename, 'w', newline="") as file:
    csvwriter = csv.writer(file)
    csvwriter.writerow(header)
    csvwriter.writerows(data)
# Out:
# image 1/10 S:\Phys\FIV942 Adipo\Adipo2Viz 512\001597.bmp: 512x512 64 Cells, 635 Droplets, 66.0ms
# image 2/10 S:\Phys\FIV942 Adipo\Adipo2Viz 512\001598.bmp: 512x512 25 Cells, 227 Droplets, 54.5ms
# image 3/10 S:\Phys\FIV942 Adipo\Adipo2Viz 512\001599.bmp: 512x512 16 Cells, 125 Droplets, 52.5ms
# image 4/10 S:\Phys\FIV942 Adipo\Adipo2Viz 512\FIV942P3-5_FIV942P3.A - 4_17_0_0.bmp: 512x512 14 Cells, 88 Droplets, 53.0ms
# image 5/10 S:\Phys\FIV942 Adipo\Adipo2Viz 512\FIV942P3-5_FIV942P3.D - 2_25_0_0.bmp: 512x512 42 Cells, 352 Droplets, 58.0ms
# image 6/10 S:\Phys\FIV942 Adipo\Adipo2Viz 512\FIV942P3-5_FIV942P3.D - 4_7_0_0.bmp: 512x512 5 Cells, 26 Droplets, 56.5ms
# image 7/10 S:\Phys\FIV942 Adipo\Adipo2Viz 512\kath0.bmp: 512x512 91 Cells, 835 Droplets, 53.1ms
# image 8/10 S:\Phys\FIV942 Adipo\Adipo2Viz 512\kath10.bmp: 512x512 26 Cells, 227 Droplets, 55.0ms
# image 9/10 S:\Phys\FIV942 Adipo\Adipo2Viz 512\kath20.bmp: 512x512 77 Cells, 618 Droplets, 56.0ms
# image 10/10 S:\Phys\FIV942 Adipo\Adipo2Viz 512\kath21.bmp: 512x512 38 Cells, 291 Droplets, 55.5ms
# Speed: 0.8ms preprocess, 56.0ms inference, 159.4ms postprocess per image at shape (1, 3, 512, 512)
# image  0
# image name:  001597.bmp
# contains masks?  True
# classes:  {0: 'Cell', 1: 'Droplet'}
# polygon areas:  [128.0, 43.5, 115.0, 43.0, 113.5, 59.0, 58.0, 37.5, 33.0, 81.0, 83.5, 133.0, 64.0, 29.5, 44.0, 102.5, 29.5, 105.5, 62.5, 25.0, 45.5, 37.0, 7.0, 96.5, 79.5, 28.5, 114.0, 93.5, 85.5, 19.0, 93.5, 89.0, 97.5, 30.5, 118.0, 54.5, 83.0, 29.5, 104.5, 73.0, 80.5, 76.5, 48.5, 102.0, 2.0, 47.0, 47.0, 7.0, 73.5, 22.0, 45.5, 79.0, 93.5, 36.0, 88.0, 66.5, 17.5, 29.5, 21.5, 45.5, 91.0, 0.0, 53.5, 61.0, 47.0, 76.0, 75.0, 63.5, 33.5, 72.0, 55.5, 41.0, 29.5, 70.5, 28.5, 66.0, 47.0, 25.0, 72.0, 111.5, 29.5, 25.0, 50.0, 48.0, 33.0, 29.5, 38.5, 32.5, 5.0, 45.5, 68.5, 77.5, 53.0, 100.0, 76.5, 110.5, 30.0, 99.0, 38.0, 1.0, 66.0, 76.0, 29.5, 49.5, 73.0, 80.5, 96.5, 7.0, 69.5, 42.0, 106.0, 0.0, 78.0, 50.5, 71.5, 7.0, 24.5, 7.0, 53.0, 9.0, 49.0, 69.5, 56.5, 83.0, 39.0, 32.0, 70.5, 75.5, 25.0, 41.5, 49.0, 119.5, 85.5, 54.5, 121.5, 7.0, 0.0, 7.0, 97.0, 75.5, 5.0, 32.5, 85.5, 85.0, 57.0, 52.0, 67.5, 45.0, 47.0, 23.5, 137.0, 29.0, 129.0, 36.0, 141.5, 114.0, 9.0, 101.0, 47.5, 32.5, 10.5, 52.5, 125.5, 32.5, 115.5, 17.5, 28.5, 80.5, 65.5, 30.5, 68.5, 0.0, 12.0, 14.0, 94.0, 98.5, 92.5, 57.0, 25.0, 10.5, 69.5, 99.5, 22.0, 69.5, 87.5, 28.5, 79.5, 49.0, 82.0, 70.5, 53.5, 59.5, 92.0, 85.5, 47.5, 110.0, 3.0, 105.5, 11.0, 47.0, 28.0, 99.0, 8.0, 0.0, 7.0, 62.5, 44.5, 72.5, 122.0, 1.5, 30.0, 10.0, 39.5, 32.5, 17.5, 7.0, 28.5, 47.0, 42.5, 41.5, 37.0, 54.0, 11.0, 0.0, 78.0, 2.0, 30.0, 36.5, 18.0, 49.0, 8.5, 64.5, 46.5, 117.5, 65.5, 53.5, 79.5, 53.5, 49.0, 47.0, 16.5, 61.5, 47.0, 31.5, 37.5, 20.5, 63.5, 35.0, 77.0, 31.5, 61.0, 28.5, 67.0, 17.0, 125.5, 41.0, 0.0, 25.0, 50.0, 14.5, 73.0, 34.5, 51.5, 42.0, 53.5, 52.5, 14.5, 47.0, 71.0, 0.0, 92.5, 22.5, 22.0, 36.0, 29.0, 60.0, 63.5, 116.0, 15.0, 41.0, 127.5, 68.5, 90.5, 81.0, 58.5, 0.0, 25.5, 0.0, 26.0, 22.0, 29.0, 75.5, 8.0, 7.0, 29.5, 46.0, 0.0, 67.0, 1.5, 5.5, 21.0, 17.0, 55.5, 21.0, 29.5, 49.5, 14.0, 7.0, 21.5, 24.5, 74.0, 40.0, 68.0, 29.5, 7.0, 35.0, 7.0, 9.0, 42.0, 131.5, 51.5, 56.5, 12.5, 12.0, 28.5, 7.0, 61.5, 10.0, 58.0, 64.5, 37.0, 35.5, 20.0, 20.0, 28.5, 0.0, 103.0, 0.0, 17.0, 26.0, 31.0, 0.0, 9.0, 60.0, 35.0, 66.5, 46.5, 53.0, 44.0, 56.0, 118.0, 2.5, 35.0, 21.5, 13.5, 45.5, 26.5, 39.0, 7.0, 52.5, 17.0, 53.5, 7.0, 0.0, 24.5, 54.5, 7.0, 1.0, 48.0, 50.0, 7.0, 19.5, 122.0, 21.0, 86.0, 7.0, 55.5, 7.0, 68.5, 63.5, 0.0, 16.5, 93.5, 48.0, 59.0, 101.0, 60.5, 46.0, 96.5, 51.0, 7.0, 34.5, 65.5, 43.5, 51.5, 29.5, 20.0, 64.0, 7.0, 0.0, 54.0, 59.0, 101.0, 29.5, 36.5, 7.0, 25.0, 49.0, 76.0, 31.5, 41.5, 42.0, 25.5, 27.0, 49.0, 27.0, 9.0, 56.5, 50.0, 11.0, 15.0, 31.0, 7.0, 38.5, 7.0, 45.5, 16.0, 0.0, 19.0, 57.5, 29.5, 37.0, 13.0, 0.0, 71.0, 48.0, 37.5, 39.0, 55.0, 52.5, 27.0, 102.5, 23.0, 31.0, 28.0, 80.0, 7.0, 0.0, 106.5, 9.0, 2.5, 3.0, 30.5, 57.5, 7.0, 49.5, 71.0, 5.5, 0.0, 7.0, 10.0, 14.0, 65.5, 50.5, 36.0, 22.0, 1.0, 0.0, 7.0, 20.5, 26.5, 38.5, 29.5, 7.0, 34.0, 37.5, 17.5, 9.0, 11.0, 7.0, 4.0, 27.0, 49.5, 0.0, 54.5, 6.0, 64.0, 56.0, 57.0, 79.0, 46.0, 32.5, 7.0, 15.0, 34.0, 108.5, 59.0, 37.0, 60.5, 27.0, 5.5, 28.5, 24.5, 40.0, 31.0, 2.0, 53.0, 2.0, 33.0, 35.0, 7.0, 34.0, 17.0, 1.0, 5.5, 7.0, 65.5, 28.0, 51.0, 21.5, 0.0, 13.5, 42.0, 7.0, 0.0, 7.0, 30.5, 102.5, 62.5, 36.5, 20.0, 28.5, 10.5, 10.0, 36.5, 34.0, 29.0, 33.5, 50.0, 3.5, 78.5, 1.0, 0.0, 48.5, 7.0, 54.0, 5.0, 0.0, 6.0, 51.5, 42.0, 11.0, 0.0, 11.5, 2.0, 0.5, 25.5, 32.5, 7.0, 22.0, 24.0, 18.0, 41.0, 30.5, 40.0, 28.0, 0.0, 9.0, 14.0, 67.5, 8.0, 34.5, 24.5, 7.5, 60.5, 7.0, 0.5, 20.5, 0.0, 23.0, 79.5, 4.0, 46.5, 8.5, 10.5, 44.0, 18.0, 48.5, 7.0, 1.5, 29.0, 1.0, 26.5, 22.0, 1.0, 2.0, 33.0, 53.0, 13.0, 27.5, 48.0, 0.5, 32.5, 14.0, 8.0, 7.5, 24.0, 1.5, 15.0, 22.0, 0.0, 32.5, 1.0, 2.0, 0.0, 38.0, 16.5, 0.0, 0.0, 0.0, 46.0, 1.0, 11.5, 50.5, 0.5, 70.5, 13.5, 0.0, 7.5, 16.5, 84.0, 118.5, 44.5, 23.0, 17.5, 9.0, 16.5, 48.0, 0.0, 65.0, 14.0, 42.0, 8.5, 25.0, 88.5, 4.5, 0.0, 20.0, 46.0, 42.0, 38.5, 0.0, 50.0, 11.0, 43.0, 7.0, 0.5, 49.5, 44.5, 61.5, 7.0, 1.0, 47.5, 0.5, 47.0, 0.0, 0.0, 1.0, 87.5, 21.0, 41.5, 28.5, 35.5, 9.0, 43.0, 71.0, 12.5, 33.5, 0.0, 40.0, 3.5, 12.0,  ...
# pixel intensities:  [array([      14422,          52,         211]), array([       5248,          15,          78]), array([      12870,          38,         171]), array([       5027,          17,          76]), array([      10925,          37,         159]), array([       5895,          18,          85]), array([       8228,          17,         121]), array([       2861,           7,          34]), array([       2834,          12,          38]), array([       9197,          29,         133]), array([       8457,          30,         121]), array([      11906,          54,         175]), array([       5435,          21,          77]), array([       2492,          12,          42]), array([       3815,           9,          54]), array([      11360,          36,         156]), array([       2674,           8,          35]), array([       9986,          39,         143]), array([       6897,          22,          92]), array([       1937,           8,          25]), array([       3999,          13,          62]), array([       4058,          12,          56]), array([        439,           0,           5]), array([      11338,          42,         167]), array([       8701,          24,         122]), array([       2829,           9,          46]), array([      13486,          47,         188]), array([       8137,          35,         111]), array([       8058,          36,         112]), array([        965,           8,          19]), array([      10082,          38,         141]), array([      11690,          34,         191]), array([       8166,          37,         104]), array([       2577,           9,          37]), array([      10103,          39,         125]), array([       4927,          21,          65]), array([       7494,          30,          94]), array([       2024,           8,          24]), array([      10150,          35,         144]), array([       6055,          23,          72]), array([       8800,          34,         145]), array([       7963,          22,          98]), array([       4857,          18,          66]), array([       9859,          35,         140]), array([          0,           0,           0]), array([       4926,          19,          70]), array([       4187,          16,          63]), array([        166,           1,           2]), array([       6469,          24,          89]), array([       2671,           5,          38]), array([       3075,          17,          44]), array([      10219,          33,         144]), array([      10290,          33,         160]), array([       3811,          12,          45]), array([      11868,          37,         177]), array([       8712,          17,         122]), array([       1463,           8,          20]), array([       2156,           5,          27]), array([       1262,           4,          17]), array([       4226,          13,          62]), array([      10455,          33,         143]), array([          0,           0,           0]), array([       5659,          20,          77]), array([       8377,          17,         121]), array([       4292,          18,          59]), array([      10473,          30,         156]), array([       8378,          23,         110]), array([       6681,          29,          93]), array([       3991,          13,          63]), array([       7334,          22,          97]), array([       7021,          21,          96]), array([       3989,          13,          53]), array([       2084,          10,          26]), array([       7698,          26,         108]), array([       2418,           7,          30]), array([       5700,          29,          85]), array([       3785,          18,          48]), array([       2417,           7,          37]), array([       8919,          29,         122]), array([      10885,          38,         148]), array([       2957,           9,          42]), array([       2487,           3,          30]), array([       7260,          11,         10 ...
# box intensities:  [array([      51646,         400,         805]), array([      21234,         163,         335]), array([      42013,         324,         618]), array([      29261,         148,         419]), array([      41405,         307,         628]), array([      26267,         179,         419]), array([      47771,         340,         706]), array([      24666,         182,         357]), array([      24743,         195,         376]), array([      53401,         280,         753]), array([      62924,         349,         930]), array([      46348,         379,         707]), array([      61669,         362,         901]), array([      21842,         152,         333]), array([      18478,         204,         304]), array([      48676,         379,         728]), array([      26027,         152,         362]), array([      31209,         388,         546]), array([      44051,         347,         656]), array([      21572,         162,         325]), array([      25521,         177,         423]), array([      25722,         146,         367]), array([       7471,          45,          99]), array([      55583,         334,         824]), array([      72735,         398,        1079]), array([      27782,         142,         409]), array([      69103,         420,        1017]), array([      39809,         325,         602]), array([      41788,         337,         615]), array([      17788,         103,         254]), array([      74633,         341,        1022]), array([      62657,         321,         887]), array([      57110,         361,         794]), array([      33201,         157,         474]), array([      48066,         319,         687]), array([      33652,         172,         445]), array([      42539,         315,         621]), array([      25729,         147,         345]), array([      46660,         380,         723]), array([      40542,         328,         592]), array([      68799,         337,        1048]), array([      58319,         338,         819]), array([      30157,         181,         429]), array([      46854,         312,         664]), array([ 1.3678e+05,        1173,        2169]), array([      26520,         156,         378]), array([      18785,         143,         290]), array([       8783,          88,         145]), array([      56122,         341,         770]), array([      37178,         216,         525]), array([      23224,         190,         346]), array([      55822,         349,         799]), array([      41448,         313,         641]), array([      29066,         168,         405]), array([      68273,         344,         963]), array([      53777,         378,         815]), array([      32089,         153,         439]), array([      31620,         176,         460]), array([      13434,         108,         205]), array([      28287,         161,         423]), array([      53264,         349,         780]), array([ 1.7503e+05,        1261,        2628]), array([      28109,         168,         400]), array([      60661,         369,         891]), array([      30644,         135,         424]), array([      68197,         343,         978]), array([      45402,         318,         709]), array([      47272,         337,         683]), array([      23850,         169,         358]), array([      64061,         322,         903]), array([      58355,         376,         835]), array([      27978,         191,         417]), array([      17907,         164,         273]), array([      56372,         339,         809]), array([      33612,         171,         464]), array([      54116,         312,         772]), array([      13962,         165,         226]), array([      10923,          67,         164]), array([      50483,         309,         731]), array([      40966,         275,         576]), array([      26594,         220,         420]), array([      17958,         124,         270]), array([      54320,         357,         816] ...
# same number of boxes as polygons?  True
# class1 parents:  [44, 202, 264, 228, 156, 161, 530, 88, 198, 61, 196, 530, 367, 228, 679, 202, 136, 684, 287, 635, 675, 140, 285, 209, 363, 111, 551, 356, 111, 161, 269, 111, 150, 635, 198, 140, 447, 416, 450, 336, 433, 136, 337, 256, 530, 548, 44, 198, 341, 442, 156, 447, 507, 678, 371, 467, 140, 481, 363, 171, 530, 171, 156, 467, 516, 88, 202, 156, 223, 209, 355, 341, 228, 467, 622, 228, 337, 447, 684, 99, 198, 675, 635, 480, 161, 230, 675, 285, 356, 433, 119, 203, 264, 44, 269, 363, 223, 136, 447, 481, 433, 136, 223, 140, 44, 433, 341, 466, 467, 264, 119, 356, 228, 287, 530, 287, 548, 468, 548, 196, 468, 480, 287, 450, 530, 99, 209, 467, 551, 341, 507, 524, 468, 225, 547, 223, 371, 367, 675, 480, 161, 367, 433, 119, 468, 684, 679, 202, 673, 150, 202, 136, 661, 507, 524, 264, 228, 269, 196, 547, 150, 442, 225, 198, 681, 161, 524, 367, 516, 287, 450, 416, 355, 530, 225, 480, 337, 256, 225, 119, 548, 264, 140, 467, 356, 209, 298, 136, 256, 228, 467, 551, 661, 450, 161, 367, 468, 99, 225, 356, 355, 355, 287, 230, 298, 543, 480, 136, 298, 341, 223, 516, 673, 298, 171, 467, 298, 547, 442, 161, 161, 230, 228, 136, 119, 225, 367, 230, 223, 298, 467, 337, 256, 416, 356, 140, 433, 99, 140, 551, 99, 228, 480, 298, 468, 44, 382, 336, 198, 355, 256, 203, 228, 136, 264, 285, 287, 111, 371, 336, 161, 119, 607, 468, 209, 433, 44, 298, 156, 202, 111, 416, 256, 61, 111, 44, 524, 61, 196, 228, 673, 543, 119, 223, 269, 150, 198, 356, 363, 269, 543, 228, 467, 140, 264, 285, 264, 524, 156, 524, 99, 363, 150, 367, 88, 433, 161, 88, 355, 298, 99, 678, 467, 198, 203, 356, 433, 416, 99, 156, 507, 433, 264, 202, 356, 367, 371, 371, 363, 524, 416, 298, 223, 622, 88, 203, 371, 371, 337, 171, 44, 230, 196, 367, 228, 433, 298, 264, 61, 150, 298, 88, 416, 356, 230, 367, 450, 356, 223, 264, 433, 356, 356, 607, 140, 171, 209, 161, 88, 150, 223, 228, 171, 356, 203, 287, 287, 156, 287, 136, 416, 433, 337, 367, 171, 447, 140, 99, 450, 156, 466, 150, 367, 442, 171, 363, 171, 337, 256, 171, 256, 161, 433, 209, 198, 367, 433, 635, 269, 285, 524, 547, 202, 382, 99, 416, 363, 341, 356, 196, 298, 507, 433, 119, 298, 61, 547, 382, 433, 433, 44, 99, 196, 88, 198, 355, 363, 256, 228, 433, 467, 111, 209, 111, 196, 450, 447, 363, 433, 264, 507, 355, 223, 209, 467, 61, 150, 196, 196, 416, 467, 264, 111, 198, 416, 367, 355, 287, 140, 228, 196, 140, 363, 119, 450, 551, 298, 136, 507, 467, 99, 367, 256, 140, 287, 156, 88, 468, 287, 433, 264, 196, 161, 287, 119, 363, 203, 171, 202, 223, 543, 119, 287, 228, 382, 551, 269, 468, 678, 356, 298, 209, 298, 228, 468, 356, 341, 171, 480, 203, 287, 466, 607, 298, 416, 382, 433, 363, 356, 547, 161, 61, 269, 136, 44, 99, 635, 156, 156, 363, 678, 140, 363, 223, 171, 524, 203, 61, 225, 99, 264, 203, 140, 416, 44, 119, 44, 228, 196, 336, 367, 119, 298, 367, 298, 196, 298, 198, 433, 524, 269, 356, 367, 136, 287, 223, 371, 61, 433, 382, 447, 681, 341, 99, 99, 99, 228, 287, 480, 119, 356, 196, 367, 161, 298, 136, 209, 367, 136, 198, 524, 363, 269, 382, 228, 524, 223, 367, 298, 285, 678, 468, 367, 203, 467, 136, 198, 196, 287, 675, 171, 119, 61, 678, 547, 140, 678, 416, 61, 156, 678, 228, 516, 524, 367]
# class1 index before increment:  0
# class1 index after increment:  1
# class1 index before increment:  1
# class1 index after increment:  2
# class1 index before increment:  2
# class1 index after increment:  3
# class1 index before increment:  3
# class1 index after increment:  4
# class1 index before increment:  4
# class1 index after increment:  5
# class1 index before increment:  5
# class1 index after increment:  6
# class1 index before increment:  6
# class1 index after increment:  7
# class1 index before increment:  7
# class1 index after increment:  8
# class1 index before increment:  8
# class1 index after increment:  9
# class1 index before increment:  9
# class1 index after increment:  10
# class1 index before increment:  10
# class1 index after increment:  11
# class1 index before increment:  11
# class1 index after increment:  12
# class1 index before increment:  12
# class1 index after increment:  13
# class1 index before increment:  13
# class1 index after increment:  14
# class1 index before increment:  14
# class1 index after increment:  15
# class1 index before increment:  15
# class1 index after increment:  16
# class1 index before increment:  16
# class1 index after increment:  17
# class1 index before increment:  17
# class1 index after increment:  18
# class1 index before increment:  18
# class1 index after increment:  19
# class1 index before increment:  19
# class1 index after increment:  20
# class1 index before increment:  20
# class1 index after increment:  21
# class1 index before increment:  21
# class1 index after increment:  22
# class1 index before increment:  22
# class1 index after increment:  23
# class1 index before increment:  23
# class1 index after increment:  24
# class1 index before increment:  24
# class1 index after increment:  25
# class1 index before increment:  25
# class1 index after increment:  26
# class1 index before increment:  26
# class1 index after increment:  27
# class1 index before increment:  27
# class1 index after increment:  28
# class1 index before increment:  28
# class1 index after increment:  29
# class1 index before increment:  29
# class1 index after increment:  30
# class1 index before increment:  30
# class1 index after increment:  31
# class1 index before increment:  31
# class1 index after increment:  32
# class1 index before increment:  32
# class1 index after increment:  33
# class1 index before increment:  33
# class1 index after increment:  34
# class1 index before increment:  34
# class1 index after increment:  35
# class1 index before increment:  35
# class1 index after increment:  36
# class1 index before increment:  36
# class1 index after increment:  37
# class1 index before increment:  37
# class1 index after increment:  38
# class1 index before increment:  38
# class1 index after increment:  39
# class1 index before increment:  39
# class1 index after increment:  40
# class1 index before increment:  40
# class1 index after increment:  41
# class1 index before increment:  41
# class1 index after increment:  42
# class1 index before increment:  42
# class1 index after increment:  43
# class1 index before increment:  43
# class1 index after increment:  44
# class1 index before increment:  44
# class1 index after increment:  45
# class1 index before increment:  45
# class1 index after increment:  46
# class1 index before increment:  46
# class1 index after increment:  47
# class1 index before increment:  47
# class1 index after increment:  48
# class1 index before increment:  48
# class1 index after increment:  49
# class1 index before increment:  49
# class1 index after increment:  50
# class1 index before increment:  50
# class1 index after increment:  51
# class1 index before increment:  51
# class1 index after increment:  52
# class1 index before increment:  52
# class1 index after increment:  53
# class1 index before increment:  53
# class1 index after increment:  54
# class1 index before increment:  54
# class1 index after increment:  55
# class1 index before increment:  55
# class1 index after increment:  56
# class1 index before increment:  56
# class1 index after increment:  57
# class1 index before increment:  57
# class1 index after increment:  58
# class1 index before increment:  58
# class1 index after increment:  59
# class1 index before increment:  59
# class1 index after increment:  60
# class1 index before increment:  60
# class1 index after increment:  61
# class1 index before increment:  61
# class1 index after increment:  62
# class1 index before increment:  62
# class1 index after increment:  63
# class1 index before increment:  63
# class1 index after increment:  64
# class1 index before increment:  64
# class1 index after increment:  65
# class1 index before increment:  65
# class1 index after increment:  66
# class1 index before increment:  66
# class1 index after increment:  67
# class1 index before increment:  67
# class1 index after increment:  68
# class1 index before increment:  68
# class1 index after increment:  69
# class1 index before increment:  69
# class1 index after increment:  70
# class1 index before increment:  70
# class1 index after increment:  71
# class1 index before increment:  71
# class1 index after increment:  72
# class1 index before increment:  72
# class1 index after increment:  73
# class1 index before increment:  73
# class1 index after increment:  74
# class1 index before increment:  74
# class1 index after increment:  75
# class1 index before increment:  75
# class1 index after increment:  76
# class1 index before increment:  76
# class1 index after increment:  77
# class1 index before increment:  77
# class1 index after increment:  78
# class1 index before increment:  78
# class1 index after increment:  79
# class1 index before increment:  79
# class1 index after increment:  80
# class1 index before increment:  80
# class1 index after increment:  81
# class1 index before increment:  81
# class1 index after increment:  82
# class1 index before increment:  82
# class1 index after increment:  83
# class1 index before increment:  83
# class1 index after increment:  84
# class1 index before increment:  84
# class1 index after increment:  85
# class1 index before increment:  85
# class1 index after increment:  86
# class1 index before increment:  86
# class1 index after increment:  87
# class1 index before increment:  87
# class1 index after increment:  88
# class1 index before increment:  88
# class1 index after increment:  89
# class1 index before increment:  89
# class1 index after increment:  90
# class1 index before increment:  90
# class1 index after increment:  91
# class1 index before increment:  91
# class1 index after increment:  92
# class1 index before increment:  92
# class1 index after increment:  93
# class1 index before increment:  93
# class1 index after increment:  94
# class1 index before increment:  94
# class1 index after increment:  95
# class1 index before increment:  95
# class1 index after increment:  96
# class1 index before increment:  96
# class1 index after increment:  97
# class1 index before increment:  97
# class1 index after increment:  98
# class1 index before increment:  98
# class1 index after increment:  99
# class1 index before increment:  99
# class1 index after increment:  100
# class1 index before increment:  100
# class1 index after increment:  101
# class1 index before increment:  101
# class1 index after increment:  102
# class1 index before increment:  102
# class1 index after increment:  103
# class1 index before increment:  103
# class1 index after increment:  104
# class1 index before increment:  104
# class1 index after increment:  105
# class1 index before increment:  105
# class1 index after increment:  106
# class1 index before increment:  106
# class1 index after increment:  107
# class1 index before increment:  107
# class1 index after increment:  108
# class1 index before increment:  108
# class1 index after increment:  109
# class1 index before increment:  109
# class1 index after increment:  110
# class1 index before increment:  110
# class1 index after increment:  111
# class1 index before increment:  111
# class1 index after increment:  112
# class1 index before increment:  112
# class1 index after increment:  113
# class1 index before increment:  113
# class1 index after increment:  114
# class1 index before increment:  114
# class1 index after increment:  115
# class1 index before increment:  115
# class1 index after increment:  116
# class1 index before increment:  116
# class1 index after increment:  117
# class1 index before increment:  117
# class1 index after increment:  118
# class1 index before increment:  118
# class1 index after increment:  119
# class1 index before increment:  119
# class1 index after increment:  120
# class1 index before increment:  120
# class1 index after increment:  121
# class1 index before increment:  121
# class1 index after increment:  122
# class1 index before increment:  122
# class1 index after increment:  123
# class1 index before increment:  123
# class1 index after increment:  124
# class1 index before increment:  124
# class1 index after increment:  125
# class1 index before increment:  125
# class1 index after increment:  126
# class1 index before increment:  126
# class1 index after increment:  127
# class1 index before increment:  127
# class1 index after increment:  128
# class1 index before increment:  128
# class1 index after increment:  129
# class1 index before increment:  129
# class1 index after increment:  130
# class1 index before increment:  130
# class1 index after increment:  131
# class1 index before increment:  131
# class1 index after increment:  132
# class1 index before increment:  132
# class1 index after increment:  133
# class1 index before increment:  133
# class1 index after increment:  134
# class1 index before increment:  134
# class1 index after increment:  135
# class1 index before increment:  135
# class1 index after increment:  136
# class1 index before increment:  136
# class1 index after increment:  137
# class1 index before increment:  137
# class1 index after increment:  138
# class1 index before increment:  138
# class1 index after increment:  139
# class1 index before increment:  139
# class1 index after increment:  140
# class1 index before increment:  140
# class1 index after increment:  141
# class1 index before increment:  141
# class1 index after increment:  142
# class1 index before increment:  142
# class1 index after increment:  143
# class1 index before increment:  143
# class1 index after increment:  144
# class1 index before increment:  144
# class1 index after increment:  145
# class1 index before increment:  145
# class1 index after increment:  146
# class1 index before increment:  146
# class1 index after increment:  147
# class1 index before increment:  147
# class1 index after increment:  148
# class1 index before increment:  148
# class1 index after increment:  149
# class1 index before increment:  149
# class1 index after increment:  150
# class1 index before increment:  150
# class1 index after increment:  151
# class1 index before increment:  151
# class1 index after increment:  152
# class1 index before increment:  152
# class1 index after increment:  153
# class1 index before increment:  153
# class1 index after increment:  154
# class1 index before increment:  154
# class1 index after increment:  155
# class1 index before increment:  155
# class1 index after increment:  156
# class1 index before increment:  156
# class1 index after increment:  157
# class1 index before increment:  157
# class1 index after increment:  158
# class1 index before increment:  158
# class1 index after increment:  159
# class1 index before increment:  159
# class1 index after increment:  160
# class1 index before increment:  160
# class1 index after increment:  161
# class1 index before increment:  161
# class1 index after increment:  162
# class1 index before increment:  162
# class1 index after increment:  163
# class1 index before increment:  163
# class1 index after increment:  164
# class1 index before increment:  164
# class1 index after increment:  165
# class1 index before increment:  165
# class1 index after increment:  166
# class1 index before increment:  166
# class1 index after increment:  167
# class1 index before increment:  167
# class1 index after increment:  168
# class1 index before increment:  168
# class1 index after increment:  169
# class1 index before increment:  169
# class1 index after increment:  170
# class1 index before increment:  170
# class1 index after increment:  171
# class1 index before increment:  171
# class1 index after increment:  172
# class1 index before increment:  172
# class1 index after increment:  173
# class1 index before increment:  173
# class1 index after increment:  174
# class1 index before increment:  174
# class1 index after increment:  175
# class1 index before increment:  175
# class1 index after increment:  176
# class1 index before increment:  176
# class1 index after increment:  177
# class1 index before increment:  177
# class1 index after increment:  178
# class1 index before increment:  178
# class1 index after increment:  179
# class1 index before increment:  179
# class1 index after increment:  180
# class1 index before increment:  180
# class1 index after increment:  181
# class1 index before increment:  181
# class1 index after increment:  182
# class1 index before increment:  182
# class1 index after increment:  183
# class1 index before increment:  183
# class1 index after increment:  184
# class1 index before increment:  184
# class1 index after increment:  185
# class1 index before increment:  185
# class1 index after increment:  186
# class1 index before increment:  186
# class1 index after increment:  187
# class1 index before increment:  187
# class1 index after increment:  188
# class1 index before increment:  188
# class1 index after increment:  189
# class1 index before increment:  189
# class1 index after increment:  190
# class1 index before increment:  190
# class1 index after increment:  191
# class1 index before increment:  191
# class1 index after increment:  192
# class1 index before increment:  192
# class1 index after increment:  193
# class1 index before increment:  193
# class1 index after increment:  194
# class1 index before increment:  194
# class1 index after increment:  195
# class1 index before increment:  195
# class1 index after increment:  196
# class1 index before increment:  196
# class1 index after increment:  197
# class1 index before increment:  197
# class1 index after increment:  198
# class1 index before increment:  198
# class1 index after increment:  199
# class1 index before increment:  199
# class1 index after increment:  200
# class1 index before increment:  200
# class1 index after increment:  201
# class1 index before increment:  201
# class1 index after increment:  202
# class1 index before increment:  202
# class1 index after increment:  203
# class1 index before increment:  203
# class1 index after increment:  204
# class1 index before increment:  204
# class1 index after increment:  205
# class1 index before increment:  205
# class1 index after increment:  206
# class1 index before increment:  206
# class1 index after increment:  207
# class1 index before increment:  207
# class1 index after increment:  208
# class1 index before increment:  208
# class1 index after increment:  209
# class1 index before increment:  209
# class1 index after increment:  210
# class1 index before increment:  210
# class1 index after increment:  211
# class1 index before increment:  211
# class1 index after increment:  212
# class1 index before increment:  212
# class1 index after increment:  213
# class1 index before increment:  213
# class1 index after increment:  214
# class1 index before increment:  214
# class1 index after increment:  215
# class1 index before increment:  215
# class1 index after increment:  216
# class1 index before increment:  216
# class1 index after increment:  217
# class1 index before increment:  217
# class1 index after increment:  218
# class1 index before increment:  218
# class1 index after increment:  219
# class1 index before increment:  219
# class1 index after increment:  220
# class1 index before increment:  220
# class1 index after increment:  221
# class1 index before increment:  221
# class1 index after increment:  222
# class1 index before increment:  222
# class1 index after increment:  223
# class1 index before increment:  223
# class1 index after increment:  224
# class1 index before increment:  224
# class1 index after increment:  225
# class1 index before increment:  225
# class1 index after increment:  226
# class1 index before increment:  226
# class1 index after increment:  227
# class1 index before increment:  227
# class1 index after increment:  228
# class1 index before increment:  228
# class1 index after increment:  229
# class1 index before increment:  229
# class1 index after increment:  230
# class1 index before increment:  230
# class1 index after increment:  231
# class1 index before increment:  231
# class1 index after increment:  232
# class1 index before increment:  232
# class1 index after increment:  233
# class1 index before increment:  233
# class1 index after increment:  234
# class1 index before increment:  234
# class1 index after increment:  235
# class1 index before increment:  235
# class1 index after increment:  236
# class1 index before increment:  236
# class1 index after increment:  237
# class1 index before increment:  237
# class1 index after increment:  238
# class1 index before increment:  238
# class1 index after increment:  239
# class1 index before increment:  239
# class1 index after increment:  240
# class1 index before increment:  240
# class1 index after increment:  241
# class1 index before increment:  241
# class1 index after increment:  242
# class1 index before increment:  242
# class1 index after increment:  243
# class1 index before increment:  243
# class1 index after increment:  244
# class1 index before increment:  244
# class1 index after increment:  245
# class1 index before increment:  245
# class1 index after increment:  246
# class1 index before increment:  246
# class1 index after increment:  247
# class1 index before increment:  247
# class1 index after increment:  248
# class1 index before increment:  248
# class1 index after increment:  249
# class1 index before increment:  249
# class1 index after increment:  250
# class1 index before increment:  250
# class1 index after increment:  251
# class1 index before increment:  251
# class1 index after increment:  252
# class1 index before increment:  252
# class1 index after increment:  253
# class1 index before increment:  253
# class1 index after increment:  254
# class1 index before increment:  254
# class1 index after increment:  255
# class1 index before increment:  255
# class1 index after increment:  256
# class1 index before increment:  256
# class1 index after increment:  257
# class1 index before increment:  257
# class1 index after increment:  258
# class1 index before increment:  258
# class1 index after increment:  259
# class1 index before increment:  259
# class1 index after increment:  260
# class1 index before increment:  260
# class1 index after increment:  261
# class1 index before increment:  261
# class1 index after increment:  262
# class1 index before increment:  262
# class1 index after increment:  263
# class1 index before increment:  263
# class1 index after increment:  264
# class1 index before increment:  264
# class1 index after increment:  265
# class1 index before increment:  265
# class1 index after increment:  266
# class1 index before increment:  266
# class1 index after increment:  267
# class1 index before increment:  267
# class1 index after increment:  268
# class1 index before increment:  268
# class1 index after increment:  269
# class1 index before increment:  269
# class1 index after increment:  270
# class1 index before increment:  270
# class1 index after increment:  271
# class1 index before increment:  271
# class1 index after increment:  272
# class1 index before increment:  272
# class1 index after increment:  273
# class1 index before increment:  273
# class1 index after increment:  274
# class1 index before increment:  274
# class1 index after increment:  275
# class1 index before increment:  275
# class1 index after increment:  276
# class1 index before increment:  276
# class1 index after increment:  277
# class1 index before increment:  277
# class1 index after increment:  278
# class1 index before increment:  278
# class1 index after increment:  279
# class1 index before increment:  279
# class1 index after increment:  280
# class1 index before increment:  280
# class1 index after increment:  281
# class1 index before increment:  281
# class1 index after increment:  282
# class1 index before increment:  282
# class1 index after increment:  283
# class1 index before increment:  283
# class1 index after increment:  284
# class1 index before increment:  284
# class1 index after increment:  285
# class1 index before increment:  285
# class1 index after increment:  286
# class1 index before increment:  286
# class1 index after increment:  287
# class1 index before increment:  287
# class1 index after increment:  288
# class1 index before increment:  288
# class1 index after increment:  289
# class1 index before increment:  289
# class1 index after increment:  290
# class1 index before increment:  290
# class1 index after increment:  291
# class1 index before increment:  291
# class1 index after increment:  292
# class1 index before increment:  292
# class1 index after increment:  293
# class1 index before increment:  293
# class1 index after increment:  294
# class1 index before increment:  294
# class1 index after increment:  295
# class1 index before increment:  295
# class1 index after increment:  296
# class1 index before increment:  296
# class1 index after increment:  297
# class1 index before increment:  297
# class1 index after increment:  298
# class1 index before increment:  298
# class1 index after increment:  299
# class1 index before increment:  299
# class1 index after increment:  300
# class1 index before increment:  300
# class1 index after increment:  301
# class1 index before increment:  301
# class1 index after increment:  302
# class1 index before increment:  302
# class1 index after increment:  303
# class1 index before increment:  303
# class1 index after increment:  304
# class1 index before increment:  304
# class1 index after increment:  305
# class1 index before increment:  305
# class1 index after increment:  306
# class1 index before increment:  306
# class1 index after increment:  307
# class1 index before increment:  307
# class1 index after increment:  308
# class1 index before increment:  308
# class1 index after increment:  309
# class1 index before increment:  309
# class1 index after increment:  310
# class1 index before increment:  310
# class1 index after increment:  311
# class1 index before increment:  311
# class1 index after increment:  312
# class1 index before increment:  312
# class1 index after increment:  313
# class1 index before increment:  313
# class1 index after increment:  314
# class1 index before increment:  314
# class1 index after increment:  315
# class1 index before increment:  315
# class1 index after increment:  316
# class1 index before increment:  316
# class1 index after increment:  317
# class1 index before increment:  317
# class1 index after increment:  318
# class1 index before increment:  318
# class1 index after increment:  319
# class1 index before increment:  319
# class1 index after increment:  320
# class1 index before increment:  320
# class1 index after increment:  321
# class1 index before increment:  321
# class1 index after increment:  322
# class1 index before increment:  322
# class1 index after increment:  323
# class1 index before increment:  323
# class1 index after increment:  324
# class1 index before increment:  324
# class1 index after increment:  325
# class1 index before increment:  325
# class1 index after increment:  326
# class1 index before increment:  326
# class1 index after increment:  327
# class1 index before increment:  327
# class1 index after increment:  328
# class1 index before increment:  328
# class1 index after increment:  329
# class1 index before increment:  329
# class1 index after increment:  330
# class1 index before increment:  330
# class1 index after increment:  331
# class1 index before increment:  331
# class1 index after increment:  332
# class1 index before increment:  332
# class1 index after increment:  333
# class1 index before increment:  333
# class1 index after increment:  334
# class1 index before increment:  334
# class1 index after increment:  335
# class1 index before increment:  335
# class1 index after increment:  336
# class1 index before increment:  336
# class1 index after increment:  337
# class1 index before increment:  337
# class1 index after increment:  338
# class1 index before increment:  338
# class1 index after increment:  339
# class1 index before increment:  339
# class1 index after increment:  340
# class1 index before increment:  340
# class1 index after increment:  341
# class1 index before increment:  341
# class1 index after increment:  342
# class1 index before increment:  342
# class1 index after increment:  343
# class1 index before increment:  343
# class1 index after increment:  344
# class1 index before increment:  344
# class1 index after increment:  345
# class1 index before increment:  345
# class1 index after increment:  346
# class1 index before increment:  346
# class1 index after increment:  347
# class1 index before increment:  347
# class1 index after increment:  348
# class1 index before increment:  348
# class1 index after increment:  349
# class1 index before increment:  349
# class1 index after increment:  350
# class1 index before increment:  350
# class1 index after increment:  351
# class1 index before increment:  351
# class1 index after increment:  352
# class1 index before increment:  352
# class1 index after increment:  353
# class1 index before increment:  353
# class1 index after increment:  354
# class1 index before increment:  354
# class1 index after increment:  355
# class1 index before increment:  355
# class1 index after increment:  356
# class1 index before increment:  356
# class1 index after increment:  357
# class1 index before increment:  357
# class1 index after increment:  358
# class1 index before increment:  358
# class1 index after increment:  359
# class1 index before increment:  359
# class1 index after increment:  360
# class1 index before increment:  360
# class1 index after increment:  361
# class1 index before increment:  361
# class1 index after increment:  362
# class1 index before increment:  362
# class1 index after increment:  363
# class1 index before increment:  363
# class1 index after increment:  364
# class1 index before increment:  364
# class1 index after increment:  365
# class1 index before increment:  365
# class1 index after increment:  366
# class1 index before increment:  366
# class1 index after increment:  367
# class1 index before increment:  367
# class1 index after increment:  368
# class1 index before increment:  368
# class1 index after increment:  369
# class1 index before increment:  369
# class1 index after increment:  370
# class1 index before increment:  370
# class1 index after increment:  371
# class1 index before increment:  371
# class1 index after increment:  372
# class1 index before increment:  372
# class1 index after increment:  373
# class1 index before increment:  373
# class1 index after increment:  374
# class1 index before increment:  374
# class1 index after increment:  375
# class1 index before increment:  375
# class1 index after increment:  376
# class1 index before increment:  376
# class1 index after increment:  377
# class1 index before increment:  377
# class1 index after increment:  378
# class1 index before increment:  378
# class1 index after increment:  379
# class1 index before increment:  379
# class1 index after increment:  380
# class1 index before increment:  380
# class1 index after increment:  381
# class1 index before increment:  381
# class1 index after increment:  382
# class1 index before increment:  382
# class1 index after increment:  383
# class1 index before increment:  383
# class1 index after increment:  384
# class1 index before increment:  384
# class1 index after increment:  385
# class1 index before increment:  385
# class1 index after increment:  386
# class1 index before increment:  386
# class1 index after increment:  387
# class1 index before increment:  387
# class1 index after increment:  388
# class1 index before increment:  388
# class1 index after increment:  389
# class1 index before increment:  389
# class1 index after increment:  390
# class1 index before increment:  390
# class1 index after increment:  391
# class1 index before increment:  391
# class1 index after increment:  392
# class1 index before increment:  392
# class1 index after increment:  393
# class1 index before increment:  393
# class1 index after increment:  394
# class1 index before increment:  394
# class1 index after increment:  395
# class1 index before increment:  395
# class1 index after increment:  396
# class1 index before increment:  396
# class1 index after increment:  397
# class1 index before increment:  397
# class1 index after increment:  398
# class1 index before increment:  398
# class1 index after increment:  399
# class1 index before increment:  399
# class1 index after increment:  400
# class1 index before increment:  400
# class1 index after increment:  401
# class1 index before increment:  401
# class1 index after increment:  402
# class1 index before increment:  402
# class1 index after increment:  403
# class1 index before increment:  403
# class1 index after increment:  404
# class1 index before increment:  404
# class1 index after increment:  405
# class1 index before increment:  405
# class1 index after increment:  406
# class1 index before increment:  406
# class1 index after increment:  407
# class1 index before increment:  407
# class1 index after increment:  408
# class1 index before increment:  408
# class1 index after increment:  409
# class1 index before increment:  409
# class1 index after increment:  410
# class1 index before increment:  410
# class1 index after increment:  411
# class1 index before increment:  411
# class1 index after increment:  412
# class1 index before increment:  412
# class1 index after increment:  413
# class1 index before increment:  413
# class1 index after increment:  414
# class1 index before increment:  414
# class1 index after increment:  415
# class1 index before increment:  415
# class1 index after increment:  416
# class1 index before increment:  416
# class1 index after increment:  417
# class1 index before increment:  417
# class1 index after increment:  418
# class1 index before increment:  418
# class1 index after increment:  419
# class1 index before increment:  419
# class1 index after increment:  420
# class1 index before increment:  420
# class1 index after increment:  421
# class1 index before increment:  421
# class1 index after increment:  422
# class1 index before increment:  422
# class1 index after increment:  423
# class1 index before increment:  423
# class1 index after increment:  424
# class1 index before increment:  424
# class1 index after increment:  425
# class1 index before increment:  425
# class1 index after increment:  426
# class1 index before increment:  426
# class1 index after increment:  427
# class1 index before increment:  427
# class1 index after increment:  428
# class1 index before increment:  428
# class1 index after increment:  429
# class1 index before increment:  429
# class1 index after increment:  430
# class1 index before increment:  430
# class1 index after increment:  431
# class1 index before increment:  431
# class1 index after increment:  432
# class1 index before increment:  432
# class1 index after increment:  433
# class1 index before increment:  433
# class1 index after increment:  434
# class1 index before increment:  434
# class1 index after increment:  435
# class1 index before increment:  435
# class1 index after increment:  436
# class1 index before increment:  436
# class1 index after increment:  437
# class1 index before increment:  437
# class1 index after increment:  438
# class1 index before increment:  438
# class1 index after increment:  439
# class1 index before increment:  439
# class1 index after increment:  440
# class1 index before increment:  440
# class1 index after increment:  441
# class1 index before increment:  441
# class1 index after increment:  442
# class1 index before increment:  442
# class1 index after increment:  443
# class1 index before increment:  443
# class1 index after increment:  444
# class1 index before increment:  444
# class1 index after increment:  445
# class1 index before increment:  445
# class1 index after increment:  446
# class1 index before increment:  446
# class1 index after increment:  447
# class1 index before increment:  447
# ...
# class1 index before increment:  65
# class1 index after increment:  66
# class1 index before increment:  66
# class1 index after increment:  67
# class1 index before increment:  67
# class1 index after increment:  68
# class1 index before increment:  68
# class1 index after increment:  69
# class1 index before increment:  69
# class1 index after increment:  70
# class1 index before increment:  70
# class1 index after increment:  71
# class1 index before increment:  71
# class1 index after increment:  72
# class1 index before increment:  72
# class1 index after increment:  73
# class1 index before increment:  73
# class1 index after increment:  74
# class1 index before increment:  74
# class1 index after increment:  75
# class1 index before increment:  75
# class1 index after increment:  76
# class1 index before increment:  76
# class1 index after increment:  77
# class1 index before increment:  77
# class1 index after increment:  78
# class1 index before increment:  78
# class1 index after increment:  79
# class1 index before increment:  79
# class1 index after increment:  80
# class1 index before increment:  80
# class1 index after increment:  81
# class1 index before increment:  81
# class1 index after increment:  82
# class1 index before increment:  82
# class1 index after increment:  83
# class1 index before increment:  83
# class1 index after increment:  84
# class1 index before increment:  84
# class1 index after increment:  85
# class1 index before increment:  85
# class1 index after increment:  86
# class1 index before increment:  86
# class1 index after increment:  87
# class1 index before increment:  87
# class1 index after increment:  88
# class1 index before increment:  88
# class1 index after increment:  89
# class1 index before increment:  89
# class1 index after increment:  90
# class1 index before increment:  90
# class1 index after increment:  91
# class1 index before increment:  91
# class1 index after increment:  92
# class1 index before increment:  92
# class1 index after increment:  93
# class1 index before increment:  93
# class1 index after increment:  94
# class1 index before increment:  94
# class1 index after increment:  95
# class1 index before increment:  95
# class1 index after increment:  96
# class1 index before increment:  96
# class1 index after increment:  97
# class1 index before increment:  97
# class1 index after increment:  98
# class1 index before increment:  98
# class1 index after increment:  99
# class1 index before increment:  99
# class1 index after increment:  100
# class1 index before increment:  100
# class1 index after increment:  101
# class1 index before increment:  101
# class1 index after increment:  102
# class1 index before increment:  102
# class1 index after increment:  103
# class1 index before increment:  103
# class1 index after increment:  104
# class1 index before increment:  104
# class1 index after increment:  105
# class1 index before increment:  105
# class1 index after increment:  106
# class1 index before increment:  106
# class1 index after increment:  107
# class1 index before increment:  107
# class1 index after increment:  108
# class1 index before increment:  108
# class1 index after increment:  109
# class1 index before increment:  109
# class1 index after increment:  110
# class1 index before increment:  110
# class1 index after increment:  111
# class1 index before increment:  111
# class1 index after increment:  112
# class1 index before increment:  112
# class1 index after increment:  113
# class1 index before increment:  113
# class1 index after increment:  114
# class1 index before increment:  114
# class1 index after increment:  115
# class1 index before increment:  115
# class1 index after increment:  116
# class1 index before increment:  116
# class1 index after increment:  117
# class1 index before increment:  117
# class1 index after increment:  118
# class1 index before increment:  118
# class1 index after increment:  119
# class1 index before increment:  119
# class1 index after increment:  120
# class1 index before increment:  120
# class1 index after increment:  121
# class1 index before increment:  121
# class1 index after increment:  122
# class1 index before increment:  122
# class1 index after increment:  123
# class1 index before increment:  123
# class1 index after increment:  124
# class1 index before increment:  124
# class1 index after increment:  125
# class1 index before increment:  125
# class1 index after increment:  126
# class1 index before increment:  126
# class1 index after increment:  127
# class1 index before increment:  127
# class1 index after increment:  128
# class1 index before increment:  128
# class1 index after increment:  129
# class1 index before increment:  129
# class1 index after increment:  130
# class1 index before increment:  130
# class1 index after increment:  131
# class1 index before increment:  131
# class1 index after increment:  132
# class1 index before increment:  132
# class1 index after increment:  133
# class1 index before increment:  133
# class1 index after increment:  134
# class1 index before increment:  134
# class1 index after increment:  135
# class1 index before increment:  135
# class1 index after increment:  136
# class1 index before increment:  136
# class1 index after increment:  137
# class1 index before increment:  137
# class1 index after increment:  138
# class1 index before increment:  138
# class1 index after increment:  139
# class1 index before increment:  139
# class1 index after increment:  140
# class1 index before increment:  140
# class1 index after increment:  141
# class1 index before increment:  141
# class1 index after increment:  142
# class1 index before increment:  142
# class1 index after increment:  143
# class1 index before increment:  143
# class1 index after increment:  144
# class1 index before increment:  144
# class1 index after increment:  145
# class1 index before increment:  145
# class1 index after increment:  146
# class1 index before increment:  146
# class1 index after increment:  147
# class1 index before increment:  147
# class1 index after increment:  148
# class1 index before increment:  148
# class1 index after increment:  149
# class1 index before increment:  149
# class1 index after increment:  150
# class1 index before increment:  150
# class1 index after increment:  151
# class1 index before increment:  151
# class1 index after increment:  152
# class1 index before increment:  152
# class1 index after increment:  153
# class1 index before increment:  153
# class1 index after increment:  154
# class1 index before increment:  154
# class1 index after increment:  155
# class1 index before increment:  155
# class1 index after increment:  156
# class1 index before increment:  156
# class1 index after increment:  157
# class1 index before increment:  157
# class1 index after increment:  158
# class1 index before increment:  158
# class1 index after increment:  159
# class1 index before increment:  159
# class1 index after increment:  160
# class1 index before increment:  160
# class1 index after increment:  161
# class1 index before increment:  161
# class1 index after increment:  162
# class1 index before increment:  162
# class1 index after increment:  163
# class1 index before increment:  163
# class1 index after increment:  164
# class1 index before increment:  164
# class1 index after increment:  165
# class1 index before increment:  165
# class1 index after increment:  166
# class1 index before increment:  166
# class1 index after increment:  167
# class1 index before increment:  167
# class1 index after increment:  168
# class1 index before increment:  168
# class1 index after increment:  169
# class1 index before increment:  169
# class1 index after increment:  170
# class1 index before increment:  170
# class1 index after increment:  171
# class1 index before increment:  171
# class1 index after increment:  172
# class1 index before increment:  172
# class1 index after increment:  173
# class1 index before increment:  173
# class1 index after increment:  174
# class1 index before increment:  174
# class1 index after increment:  175
# class1 index before increment:  175
# class1 index after increment:  176
# class1 index before increment:  176
# class1 index after increment:  177
# class1 index before increment:  177
# class1 index after increment:  178
# class1 index before increment:  178
# class1 index after increment:  179
# class1 index before increment:  179
# class1 index after increment:  180
# class1 index before increment:  180
# class1 index after increment:  181
# class1 index before increment:  181
# class1 index after increment:  182
# class1 index before increment:  182
# class1 index after increment:  183
# class1 index before increment:  183
# class1 index after increment:  184
# class1 index before increment:  184
# class1 index after increment:  185
# class1 index before increment:  185
# class1 index after increment:  186
# class1 index before increment:  186
# class1 index after increment:  187
# class1 index before increment:  187
# class1 index after increment:  188
# class1 index before increment:  188
# class1 index after increment:  189
# class1 index before increment:  189
# class1 index after increment:  190
# class1 index before increment:  190
# class1 index after increment:  191
# class1 index before increment:  191
# class1 index after increment:  192
# class1 index before increment:  192
# class1 index after increment:  193
# class1 index before increment:  193
# class1 index after increment:  194
# class1 index before increment:  194
# class1 index after increment:  195
# class1 index before increment:  195
# class1 index after increment:  196
# class1 index before increment:  196
# class1 index after increment:  197
# class1 index before increment:  197
# class1 index after increment:  198
# class1 index before increment:  198
# class1 index after increment:  199
# class1 index before increment:  199
# class1 index after increment:  200
# class1 index before increment:  200
# class1 index after increment:  201
# class1 index before increment:  201
# class1 index after increment:  202
# class1 index before increment:  202
# class1 index after increment:  203
# class1 index before increment:  203
# class1 index after increment:  204
# class1 index before increment:  204
# class1 index after increment:  205
# class1 index before increment:  205
# class1 index after increment:  206
# class1 index before increment:  206
# class1 index after increment:  207
# class1 index before increment:  207
# class1 index after increment:  208
# class1 index before increment:  208
# class1 index after increment:  209
# class1 index before increment:  209
# class1 index after increment:  210
# class1 index before increment:  210
# class1 index after increment:  211
# class1 index before increment:  211
# class1 index after increment:  212
# class1 index before increment:  212
# class1 index after increment:  213
# class1 index before increment:  213
# class1 index after increment:  214
# class1 index before increment:  214
# class1 index after increment:  215
# class1 index before increment:  215
# class1 index after increment:  216
# class1 index before increment:  216
# class1 index after increment:  217
# class1 index before increment:  217
# class1 index after increment:  218
# class1 index before increment:  218
# class1 index after increment:  219
# class1 index before increment:  219
# class1 index after increment:  220
# class1 index before increment:  220
# class1 index after increment:  221
# class1 index before increment:  221
# class1 index after increment:  222
# class1 index before increment:  222
# class1 index after increment:  223
# class1 index before increment:  223
# class1 index after increment:  224
# class1 index before increment:  224
# class1 index after increment:  225
# class1 index before increment:  225
# class1 index after increment:  226
# class1 index before increment:  226
# class1 index after increment:  227
# class1 index before increment:  227
# class1 index after increment:  228
# class1 index before increment:  228
# class1 index after increment:  229
# class1 index before increment:  229
# class1 index after increment:  230
# class1 index before increment:  230
# class1 index after increment:  231
# class1 index before increment:  231
# class1 index after increment:  232
# class1 index before increment:  232
# class1 index after increment:  233
# class1 index before increment:  233
# class1 index after increment:  234
# class1 index before increment:  234
# class1 index after increment:  235
# class1 index before increment:  235
# class1 index after increment:  236
# class1 index before increment:  236
# class1 index after increment:  237
# class1 index before increment:  237
# class1 index after increment:  238
# class1 index before increment:  238
# class1 index after increment:  239
# class1 index before increment:  239
# class1 index after increment:  240
# class1 index before increment:  240
# class1 index after increment:  241
# class1 index before increment:  241
# class1 index after increment:  242
# class1 index before increment:  242
# class1 index after increment:  243
# class1 index before increment:  243
# class1 index after increment:  244
# class1 index before increment:  244
# class1 index after increment:  245
# class1 index before increment:  245
# class1 index after increment:  246
# class1 index before increment:  246
# class1 index after increment:  247
# class1 index before increment:  247
# class1 index after increment:  248
# class1 index before increment:  248
# class1 index after increment:  249
# class1 index before increment:  249
# class1 index after increment:  250
# class1 index before increment:  250
# class1 index after increment:  251
# class1 index before increment:  251
# class1 index after increment:  252
# class1 index before increment:  252
# class1 index after increment:  253
# class1 index before increment:  253
# class1 index after increment:  254
# class1 index before increment:  254
# class1 index after increment:  255
# class1 index before increment:  255
# class1 index after increment:  256
# class1 index before increment:  256
# class1 index after increment:  257
# class1 index before increment:  257
# class1 index after increment:  258
# class1 index before increment:  258
# class1 index after increment:  259
# class1 index before increment:  259
# class1 index after increment:  260
# class1 index before increment:  260
# class1 index after increment:  261
# class1 index before increment:  261
# class1 index after increment:  262
# class1 index before increment:  262
# class1 index after increment:  263
# class1 index before increment:  263
# class1 index after increment:  264
# class1 index before increment:  264
# class1 index after increment:  265
# class1 index before increment:  265
# class1 index after increment:  266
# class1 index before increment:  266
# class1 index after increment:  267
# class1 index before increment:  267
# class1 index after increment:  268
# class1 index before increment:  268
# class1 index after increment:  269
# class1 index before increment:  269
# class1 index after increment:  270
# class1 index before increment:  270
# class1 index after increment:  271
# class1 index before increment:  271
# class1 index after increment:  272
# class1 index before increment:  272
# class1 index after increment:  273
# class1 index before increment:  273
# class1 index after increment:  274
# class1 index before increment:  274
# class1 index after increment:  275
# class1 index before increment:  275
# class1 index after increment:  276
# class1 index before increment:  276
# class1 index after increment:  277
# class1 index before increment:  277
# class1 index after increment:  278
# class1 index before increment:  278
# class1 index after increment:  279
# class1 index before increment:  279
# class1 index after increment:  280
# class1 index before increment:  280
# class1 index after increment:  281
# class1 index before increment:  281
# class1 index after increment:  282
# class1 index before increment:  282
# class1 index after increment:  283
# class1 index before increment:  283
# class1 index after increment:  284
# class1 index before increment:  284
# class1 index after increment:  285
# class1 index before increment:  285
# class1 index after increment:  286
# class1 index before increment:  286
# class1 index after increment:  287
# class1 index before increment:  287
# class1 index after increment:  288
# class1 index before increment:  288
# class1 index after increment:  289
# class1 index before increment:  289
# class1 index after increment:  290
# class1 index before increment:  290
# class1 index after increment:  291

# %%
data
# Out:
# [['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   0,
#   1.0,
#   array([[        214,          21],
#          [        213,          22],
#          [        213,          24],
#          [        212,          25],
#          [        212,          27],
#          [        213,          28],
#          [        213,          30],
#          [        214,          31],
#          [        215,          31],
#          [        216,          32],
#          [        219,          32],
#          [        220,          31],
#          [        222,          31],
#          [        223,          30],
#          [        224,          30],
#          [        224,          29],
#          [        225,          28],
#          [        226,          28],
#          [        226,          27],
#          [        227,          26],
#          [        227,          25],
#          [        226,          24],
#          [        226,          23],
#          [        225,          22],
#          [        224,          22],
#          [        223,          21]], dtype=float32),
#   26,
#   128.0,
#   14422.0,
#   52.0,
#   211.0,
#   218.82334899902344,
#   26.01698112487793,
#   14.969329833984375,
#   15.905941009521484,
#   51646.0,
#   400.0,
#   805.0,
#   0.8997946977615356,
#   14685.0,
#   4895.0,
#   6736.91902875491,
#   52851.0,
#   17617.0,
#   24062.70471081753,
#   44],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   1,
#   1.0,
#   array([[        169,         160],
#          [        168,         161],
#          [        168,         164],
#          [        169,         165],
#          [        169,         166],
#          [        170,         166],
#          [        171,         167],
#          [        174,         167],
#          [        175,         166],
#          [        175,         161],
#          [        174,         160]], dtype=float32),
#   11,
#   43.5,
#   5248.0,
#   15.0,
#   78.0,
#   171.99139404296875,
#   162.446533203125,
#   9.7705078125,
#   9.71893310546875,
#   21234.0,
#   163.0,
#   335.0,
#   0.8935440182685852,
#   5341.0,
#   1780.3333333333333,
#   2452.145500486371,
#   21732.0,
#   7244.0,
#   9892.673079944909,
#   202],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   2,
#   1.0,
#   array([[        341,          56],
#          [        340,          57],
#          [        340,          62],
#          [        345,          67],
#          [        350,          67],
#          [        351,          66],
#          [        351,          65],
#          [        352,          64],
#          [        352,          63],
#          [        353,          62],
#          [        353,          61],
#          [        352,          60],
#          [        352,          59],
#          [        351,          58],
#          [        351,          57],
#          [        350,          56]], dtype=float32),
#   16,
#   115.0,
#   12870.0,
#   38.0,
#   171.0,
#   346.7025146484375,
#   61.26337432861328,
#   14.6484375,
#   14.3553466796875,
#   42013.0,
#   324.0,
#   618.0,
#   0.8924652934074402,
#   13079.0,
#   4359.666666666667,
#   6017.959362515576,
#   42955.0,
#   14318.333333333334,
#   19583.454416646946,
#   264],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   3,
#   1.0,
#   array([[        277,         100],
#          [        276,         101],
#          [        276,         106],
#          [        277,         107],
#          [        281,         107],
#          [        282,         106],
#          [        282,         105],
#          [        283,         104],
#          [        283,         102],
#          [        281,         100]], dtype=float32),
#   10,
#   43.0,
#   5027.0,
#   17.0,
#   76.0,
#   278.5601806640625,
#   103.76465606689453,
#   10.0189208984375,
#   9.8580322265625,
#   29261.0,
#   148.0,
#   419.0,
#   0.8896960616111755,
#   5120.0,
#   1706.6666666666667,
#   2347.9537663439814,
#   29828.0,
#   9942.666666666666,
#   13660.572519318346,
#   228],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   4,
#   1.0,
#   array([[        241,         100],
#          [        240,         101],
#          [        239,         101],
#          [        237,         103],
#          [        237,         104],
#          [        236,         105],
#          [        236,         109],
#          [        238,         111],
#          [        245,         111],
#          [        247,         109],
#          [        247,         108],
#          [        248,         107],
#          [        248,         106],
#          [        249,         105],
#          [        248,         104],
#          [        248,         102],
#          [        246,         100]], dtype=float32),
#   17,
#   113.5,
#   10925.0,
#   37.0,
#   159.0,
#   242.2902374267578,
#   104.12351989746094,
#   13.872833251953125,
#   13.7342529296875,
#   41405.0,
#   307.0,
#   628.0,
#   0.8883717060089111,
#   11121.0,
#   3707.0,
#   5104.139757752198,
#   42340.0,
#   14113.333333333334,
#   19298.567517363103,
#   156],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   5,
#   1.0,
#   array([[        458,         464],
#          [        456,         466],
#          [        456,         470],
#          [        457,         471],
#          [        462,         471],
#          [        463,         470],
#          [        463,         469],
#          [        465,         467],
#          [        466,         467],
#          [        467,         466],
#          [        467,         465],
#          [        466,         464]], dtype=float32),
#   12,
#   59.0,
#   5895.0,
#   18.0,
#   85.0,
#   460.3892822265625,
#   466.58697509765625,
#   10.3095703125,
#   10.368408203125,
#   26267.0,
#   179.0,
#   419.0,
#   0.8872039318084717,
#   5998.0,
#   1999.3333333333333,
#   2754.7881144573635,
#   26865.0,
#   8955.0,
#   12241.824700591003,
#   161],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   6,
#   1.0,
#   array([[        197,         161],
#          [        197,         163],
#          [        196,         164],
#          [        196,         167],
#          [        197,         168],
#          [        197,         170],
#          [        198,         171],
#          [        199,         171],
#          [        200,         170],
#          [        202,         170],
#          [        202,         169],
#          [        203,         168],
#          [        203,         162],
#          [        202,         161]], dtype=float32),
#   14,
#   58.0,
#   8228.0,
#   17.0,
#   121.0,
#   199.5673370361328,
#   165.77854919433594,
#   14.528839111328125,
#   14.577301025390625,
#   47771.0,
#   340.0,
#   706.0,
#   0.8825250267982483,
#   8366.0,
#   2788.6666666666665,
#   3846.4238224904734,
#   48817.0,
#   16272.333333333334,
#   22273.421984259377,
#   530],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   7,
#   1.0,
#   array([[         93,         132],
#          [         92,         133],
#          [         92,         138],
#          [         93,         139],
#          [         94,         139],
#          [         95,         138],
#          [         96,         138],
#          [         98,         136],
#          [         98,         135],
#          [         99,         134],
#          [         99,         133],
#          [         98,         132]], dtype=float32),
#   12,
#   37.5,
#   2861.0,
#   7.0,
#   34.0,
#   94.60340881347656,
#   133.8846435546875,
#   9.744140625,
#   10.1182861328125,
#   24666.0,
#   182.0,
#   357.0,
#   0.8807087540626526,
#   2902.0,
#   967.3333333333334,
#   1339.069909385698,
#   25205.0,
#   8401.666666666666,
#   11500.842297656096,
#   88],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   8,
#   1.0,
#   array([[        329,         316],
#          [        328,         317],
#          [        328,         322],
#          [        329,         323],
#          [        330,         323],
#          [        331,         322],
#          [        332,         322],
#          [        333,         321],
#          [        333,         320],
#          [        334,         319],
#          [        334,         317],
#          [        333,         317],
#          [        332,         316]], dtype=float32),
#   13,
#   33.0,
#   2834.0,
#   12.0,
#   38.0,
#   329.99920654296875,
#   317.93609619140625,
#   10.2686767578125,
#   10.1649169921875,
#   24743.0,
#   195.0,
#   376.0,
#   0.8724005818367004,
#   2884.0,
#   961.3333333333334,
#   1324.217840420861,
#   25314.0,
#   8438.0,
#   11529.612858490378,
#   198],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   9,
#   1.0,
#   array([[        497,         432],
#          [        496,         433],
#          [        496,         436],
#          [        497,         437],
#          [        497,         439],
#          [        498,         440],
#          [        499,         440],
#          [        500,         441],
#          [        501,         441],
#          [        502,         440],
#          [        503,         440],
#          [        504,         439],
#          [        506,         439],
#          [        507,         438],
#          [        507,         433],
#          [        506,         432]], dtype=float32),
#   16,
#   81.0,
#   9197.0,
#   29.0,
#   133.0,
#   500.71673583984375,
#   435.3188171386719,
#   14.228759765625,
#   14.141357421875,
#   53401.0,
#   280.0,
#   753.0,
#   0.8722173571586609,
#   9359.0,
#   3119.6666666666665,
#   4297.533349363201,
#   54434.0,
#   18144.666666666668,
#   24930.74022611888,
#   61],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   10,
#   1.0,
#   array([[         70,         173],
#          [         69,         174],
#          [         70,         175],
#          [         70,         182],
#          [         71,         183],
#          [         76,         183],
#          [         77,         182],
#          [         78,         182],
#          [         78,         181],
#          [         79,         180],
#          [         79,         176],
#          [         78,         175],
#          [         78,         174],
#          [         77,         173]], dtype=float32),
#   14,
#   83.5,
#   8457.0,
#   30.0,
#   121.0,
#   72.57039642333984,
#   177.25460815429688,
#   14.528732299804688,
#   14.49951171875,
#   62924.0,
#   349.0,
#   930.0,
#   0.8699461221694946,
#   8608.0,
#   2869.3333333333335,
#   3951.251644169927,
#   64203.0,
#   21401.0,
#   29362.152929692784,
#   196],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   11,
#   1.0,
#   array([[        209,         192],
#          [        204,         197],
#          [        204,         202],
#          [        205,         203],
#          [        214,         203],
#          [        215,         202],
#          [        215,         201],
#          [        217,         199],
#          [        218,         199],
#          [        219,         198],
#          [        219,         195],
#          [        218,         194],
#          [        218,         193],
#          [        217,         193],
#          [        216,         192]], dtype=float32),
#   15,
#   133.0,
#   11906.0,
#   54.0,
#   175.0,
#   210.391845703125,
#   196.48910522460938,
#   15.33966064453125,
#   15.429656982421875,
#   46348.0,
#   379.0,
#   707.0,
#   0.8697961568832397,
#   12135.0,
#   4045.0,
#   5558.785898617311,
#   47434.0,
#   15811.333333333334,
#   21593.099273198884,
#   530],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   12,
#   1.0,
#   array([[        122,         389],
#          [        118,         393],
#          [        118,         394],
#          [        119,         395],
#          [        119,         396],
#          [        120,         397],
#          [        120,         398],
#          [        121,         399],
#          [        122,         399],
#          [        123,         398],
#          [        124,         398],
#          [        127,         395],
#          [        127,         391],
#          [        126,         390],
#          [        126,         389]], dtype=float32),
#   15,
#   64.0,
#   5435.0,
#   21.0,
#   77.0,
#   120.7237777709961,
#   392.2489929199219,
#   14.532745361328125,
#   15.24114990234375,
#   61669.0,
#   362.0,
#   901.0,
#   0.8676310181617737,
#   5533.0,
#   1844.3333333333333,
#   2539.0876751743376,
#   62932.0,
#   20977.333333333332,
#   28774.194831866665,
#   367],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   13,
#   1.0,
#   array([[        297,         100],
#          [        296,         101],
#          [        296,         105],
#          [        297,         106],
#          [        298,         106],
#          [        301,         103],
#          [        302,         103],
#          [        303,         102],
#          [        303,         101],
#          [        302,         100]], dtype=float32),
#   10,
#   29.5,
#   2492.0,
#   12.0,
#   42.0,
#   297.73577880859375,
#   101.31017303466797,
#   9.55035400390625,
#   9.601394653320312,
#   21842.0,
#   152.0,
#   333.0,
#   0.8675845265388489,
#   2546.0,
#   848.6666666666666,
#   1162.0766851728083,
#   22327.0,
#   7442.333333333333,
#   10182.370069007618,
#   228],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   14,
#   1.0,
#   array([[         25,          16],
#          [         24,          17],
#          [         24,          21],
#          [         26,          23],
#          [         29,          23],
#          [         31,          21],
#          [         31,          17],
#          [         30,          16]], dtype=float32),
#   8,
#   44.0,
#   3815.0,
#   9.0,
#   54.0,
#   27.033071517944336,
#   17.81707000732422,
#   11.474346160888672,
#   10.875899314880371,
#   18478.0,
#   204.0,
#   304.0,
#   0.8670193552970886,
#   3878.0,
#   1292.6666666666667,
#   1783.653616098771,
#   18986.0,
#   6328.666666666667,
#   8590.97298848558,
#   679],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   15,
#   1.0,
#   array([[        147,         173],
#          [        146,         174],
#          [        145,         174],
#          [        145,         175],
#          [        144,         176],
#          [        144,         182],
#          [        145,         183],
#          [        146,         183],
#          [        147,         184],
#          [        148,         184],
#          [        150,         186],
#          [        150,         185],
#          [        151,         184],
#          [        152,         184],
#          [        153,         183],
#          [        154,         183],
#          [        155,         182],
#          [        155,         177],
#          [        154,         176],
#          [        153,         176],
#          [        150,         173]], dtype=float32),
#   21,
#   102.5,
#   11360.0,
#   36.0,
#   156.0,
#   150.12261962890625,
#   178.26040649414062,
#   15.2410888671875,
#   14.868896484375,
#   48676.0,
#   379.0,
#   728.0,
#   0.8658686876296997,
#   11552.0,
#   3850.6666666666665,
#   5310.126510315508,
#   49783.0,
#   16594.333333333332,
#   22685.611480015745,
#   202],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   16,
#   1.0,
#   array([[        213,         436],
#          [        212,         437],
#          [        212,         441],
#          [        213,         442],
#          [        214,         442],
#          [        217,         439],
#          [        218,         439],
#          [        219,         438],
#          [        219,         437],
#          [        218,         436]], dtype=float32),
#   10,
#   29.5,
#   2674.0,
#   8.0,
#   35.0,
#   213.60531616210938,
#   438.06683349609375,
#   9.965789794921875,
#   9.8072509765625,
#   26027.0,
#   152.0,
#   362.0,
#   0.8655762672424316,
#   2717.0,
#   905.6666666666666,
#   1250.4490748882536,
#   26541.0,
#   8847.0,
#   12148.39701359813,
#   136],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   17,
#   1.0,
#   array([[         89,         216],
#          [         88,         217],
#          [         88,         225],
#          [         90,         227],
#          [         94,         227],
#          [         99,         222],
#          [         99,         217],
#          [         98,         216]], dtype=float32),
#   8,
#   105.5,
#   9986.0,
#   39.0,
#   143.0,
#   93.16557312011719,
#   219.48910522460938,
#   14.2833251953125,
#   14.54296875,
#   31209.0,
#   388.0,
#   546.0,
#   0.8644342422485352,
#   10168.0,
#   3389.3333333333335,
#   4664.740959819979,
#   32143.0,
#   10714.333333333334,
#   14492.061328725997,
#   684],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   18,
#   1.0,
#   array([[        233,         152],
#          [        232,         153],
#          [        232,         158],
#          [        233,         159],
#          [        233,         160],
#          [        234,         160],
#          [        235,         159],
#          [        238,         159],
#          [        239,         158],
#          [        240,         158],
#          [        241,         157],
#          [        241,         156],
#          [        242,         155],
#          [        242,         153],
#          [        241,         153],
#          [        240,         152]], dtype=float32),
#   16,
#   62.5,
#   6897.0,
#   22.0,
#   92.0,
#   238.13668823242188,
#   156.22982788085938,
#   13.893463134765625,
#   14.099090576171875,
#   44051.0,
#   347.0,
#   656.0,
#   0.8643081188201904,
#   7011.0,
#   2337.0,
#   3224.5335579997713,
#   45054.0,
#   15018.0,
#   20529.818752244257,
#   287],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   19,
#   1.0,
#   array([[         21,         304],
#          [         20,         305],
#          [         20,         310],
#          [         21,         311],
#          [         22,         311],
#          [         23,         310],
#          [         23,         309],
#          [         24,         308],
#          [         24,         307],
#          [         25,         306],
#          [         25,         305],
#          [         24,         305],
#          [         23,         304]], dtype=float32),
#   13,
#   25.0,
#   1937.0,
#   8.0,
#   25.0,
#   21.468399047851562,
#   305.7937927246094,
#   9.828788757324219,
#   9.73895263671875,
#   21572.0,
#   162.0,
#   325.0,
#   0.8638774752616882,
#   1970.0,
#   656.6666666666666,
#   905.3589834363434,
#   22059.0,
#   7353.0,
#   10054.571530734995,
#   635],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   20,
#   1.0,
#   array([[        457,         148],
#          [        456,         149],
#          [        456,         153],
#          [        458,         155],
#          [        460,         155],
#          [        461,         154],
#          [        462,         154],
#          [        463,         153],
#          [        463,         152],
#          [        464,         151],
#          [        464,         149],
#          [        463,         149],
#          [        462,         148]], dtype=float32),
#   13,
#   45.5,
#   3999.0,
#   13.0,
#   62.0,
#   460.06927490234375,
#   149.33511352539062,
#   10.369140625,
#   9.77618408203125,
#   25521.0,
#   177.0,
#   423.0,
#   0.8622424006462097,
#   4074.0,
#   1358.0,
#   1867.5761474881463,
#   26121.0,
#   8707.0,
#   11889.717574442213,
#   675],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   21,
#   1.0,
#   array([[        281,         300],
#          [        280,         301],
#          [        280,         303],
#          [        281,         304],
#          [        281,         306],
#          [        286,         306],
#          [        286,         305],
#          [        287,         304],
#          [        287,         301],
#          [        286,         300]], dtype=float32),
#   10,
#   37.0,
#   4058.0,
#   12.0,
#   56.0,
#   283.4119873046875,
#   301.81744384765625,
#   9.345703125,
#   9.3111572265625,
#   25722.0,
#   146.0,
#   367.0,
#   0.8611660599708557,
#   4126.0,
#   1375.3333333333333,
#   1897.0168393793685,
#   26235.0,
#   8745.0,
#   12004.890864421328,
#   140],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   22,
#   1.0,
#   array([[        149,         236],
#          [        148,         237],
#          [        148,         238],
#          [        149,         239],
#          [        150,         239],
#          [        151,         238],
#          [        151,         237],
#          [        150,         236]], dtype=float32),
#   8,
#   7.0,
#   439.0,
#   0.0,
#   5.0,
#   148.92637634277344,
#   236.688720703125,
#   6.05389404296875,
#   6.2845458984375,
#   7471.0,
#   45.0,
#   99.0,
#   0.8607599139213562,
#   444.0,
#   148.0,
#   205.77819774375192,
#   7615.0,
#   2538.3333333333335,
#   3487.991717625233,
#   285],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   23,
#   1.0,
#   array([[        137,          24],
#          [        136,          25],
#          [        136,          33],
#          [        138,          35],
#          [        139,          34],
#          [        140,          34],
#          [        141,          33],
#          [        142,          33],
#          [        143,          32],
#          [        145,          32],
#          [        147,          30],
#          [        147,          25],
#          [        146,          24]], dtype=float32),
#   13,
#   96.5,
#   11338.0,
#   42.0,
#   167.0,
#   142.61968994140625,
#   29.542659759521484,
#   14.16741943359375,
#   14.33404541015625,
#   55583.0,
#   334.0,
#   824.0,
#   0.860195517539978,
#   11547.0,
#   3849.0,
#   5295.768562415343,
#   56741.0,
#   18913.666666666668,
#   25929.90590461566,
#   209],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   24,
#   1.0,
#   array([[        425,          56],
#          [        423,          58],
#          [        423,          62],
#          [        424,          63],
#          [        424,          65],
#          [        425,          66],
#          [        426,          66],
#          [        427,          67],
#          [        430,          67],
#          [        431,          66],
#          [        431,          63],
#          [        432,          62],
#          [        432,          61],
#          [        431,          60],
#          [        431,          57],
#          [        430,          56]], dtype=float32),
#   16,
#   79.5,
#   8701.0,
#   24.0,
#   122.0,
#   425.19354248046875,
#   61.95969009399414,
#   16.0653076171875,
#   16.023826599121094,
#   72735.0,
#   398.0,
#   1079.0,
#   0.8592661619186401,
#   8847.0,
#   2949.0,
#   4067.474974313507,
#   74212.0,
#   24737.333333333332,
#   33940.61425817486,
#   363],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   25,
#   1.0,
#   array([[        269,          40],
#          [        268,          41],
#          [        268,          46],
#          [        269,          47],
#          [        270,          47],
#          [        271,          46],
#          [        271,          45],
#          [        274,          42],
#          [        274,          41],
#          [        273,          41],
#          [        272,          40]], dtype=float32),
#   11,
#   28.5,
#   2829.0,
#   9.0,
#   46.0,
#   269.3537292480469,
#   42.58988571166992,
#   9.45001220703125,
#   9.824234008789062,
#   27782.0,
#   142.0,
#   409.0,
#   0.8588206768035889,
#   2884.0,
#   961.3333333333334,
#   1320.7261470704498,
#   28333.0,
#   9444.333333333334,
#   12967.146597802033,
#   111],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   26,
#   1.0,
#   array([[         41,         192],
#          [         40,         193],
#          [         40,         200],
#          [         41,         201],
#          [         41,         202],
#          [         42,         203],
#          [         49,         203],
#          [         50,         202],
#          [         50,         201],
#          [         51,         200],
#          [         51,         193],
#          [         50,         192]], dtype=float32),
#   12,
#   114.0,
#   13486.0,
#   47.0,
#   188.0,
#   45.02317428588867,
#   198.37591552734375,
#   15.327522277832031,
#   16.26300048828125,
#   69103.0,
#   420.0,
#   1017.0,
#   0.8575880527496338,
#   13721.0,
#   4573.666666666667,
#   6302.234224639879,
#   70540.0,
#   23513.333333333332,
#   32237.683770533033,
#   551],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   27,
#   1.0,
#   array([[         82,         440],
#          [         80,         442],
#          [         80,         449],
#          [         82,         451],
#          [         86,         451],
#          [         91,         446],
#          [         91,         444],
#          [         88,         441],
#          [         85,         441],
#          [         84,         440]], dtype=float32),
#   10,
#   93.5,
#   8137.0,
#   35.0,
#   111.0,
#   86.75373840332031,
#   444.59521484375,
#   13.849884033203125,
#   13.6689453125,
#   39809.0,
#   325.0,
#   602.0,
#   0.8573772311210632,
#   8283.0,
#   2761.0,
#   3801.5326733656607,
#   40736.0,
#   13578.666666666666,
#   18547.991307835888,
#   356],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   28,
#   1.0,
#   array([[        297,          44],
#          [        296,          45],
#          [        296,          50],
#          [        297,          51],
#          [        297,          54],
#          [        298,          54],
#          [        299,          55],
#          [        302,          55],
#          [        303,          54],
#          [        303,          53],
#          [        305,          51],
#          [        306,          51],
#          [        307,          50],
#          [        307,          49],
#          [        306,          48],
#          [        305,          48],
#          [        304,          47],
#          [        304,          46],
#          [        302,          44]], dtype=float32),
#   19,
#   85.5,
#   8058.0,
#   36.0,
#   112.0,
#   299.12774658203125,
#   49.737098693847656,
#   14.1944580078125,
#   13.276458740234375,
#   41788.0,
#   337.0,
#   615.0,
#   0.8559734225273132,
#   8206.0,
#   2735.3333333333335,
#   3763.8215803739804,
#   42740.0,
#   14246.666666666666,
#   19474.994263299683,
#   111],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   29,
#   1.0,
#   array([[        445,         440],
#          [        444,         441],
#          [        444,         446],
#          [        445,         447],
#          [        446,         447],
#          [        447,         446],
#          [        447,         441],
#          [        446,         440]], dtype=float32),
#   8,
#   19.0,
#   965.0,
#   8.0,
#   19.0,
#   444.25177001953125,
#   443.583740234375,
#   7.689697265625,
#   7.50439453125,
#   17788.0,
#   103.0,
#   254.0,
#   0.8555803894996643,
#   992.0,
#   330.6666666666667,
#   448.5638812427451,
#   18145.0,
#   6048.333333333333,
#   8301.426798381643,
#   161],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   30,
#   1.0,
#   array([[        108,         245],
#          [        107,         246],
#          [        106,         246],
#          [        105,         247],
#          [        105,         254],
#          [        106,         255],
#          [        106,         256],
#          [        112,         256],
#          [        113,         255],
#          [        114,         255],
#          [        115,         254],
#          [        115,         249],
#          [        112,         246],
#          [        111,         246],
#          [        110,         245]], dtype=float32),
#   15,
#   93.5,
#   10082.0,
#   38.0,
#   141.0,
#   108.79907989501953,
#   250.6351318359375,
#   14.071502685546875,
#   13.82135009765625,
#   74633.0,
#   341.0,
#   1022.0,
#   0.854913592338562,
#   10261.0,
#   3420.3333333333335,
#   4710.697353423965,
#   75996.0,
#   25332.0,
#   34862.179994945815,
#   269],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   31,
#   1.0,
#   array([[        276,          41],
#          [        274,          43],
#          [        274,          44],
#          [        273,          45],
#          [        273,          48],
#          [        272,          49],
#          [        274,          51],
#          [        278,          51],
#          [        279,          50],
#          [        280,          50],
#          [        284,          46],
#          [        284,          44],
#          [        283,          43],
#          [        283,          41]], dtype=float32),
#   14,
#   89.0,
#   11690.0,
#   34.0,
#   191.0,
#   278.3315124511719,
#   44.72195816040039,
#   14.60125732421875,
#   14.244728088378906,
#   62657.0,
#   321.0,
#   887.0,
#   0.8534824848175049,
#   11915.0,
#   3971.6666666666665,
#   5458.062191738831,
#   63865.0,
#   21288.333333333332,
#   29252.977345144813,
#   111],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   32,
#   1.0,
#   array([[        349,         270],
#          [        348,         271],
#          [        346,         271],
#          [        345,         272],
#          [        345,         273],
#          [        344,         274],
#          [        344,         278],
#          [        349,         283],
#          [        355,         277],
#          [        355,         274],
#          [        354,         273],
#          [        354,         272],
#          [        353,         271],
#          [        351,         271],
#          [        350,         270]], dtype=float32),
#   15,
#   97.5,
#   8166.0,
#   37.0,
#   104.0,
#   348.11163330078125,
#   274.14605712890625,
#   15.0531005859375,
#   15.243408203125,
#   57110.0,
#   361.0,
#   794.0,
#   0.8531592488288879,
#   8307.0,
#   2769.0,
#   3816.3533204705595,
#   58265.0,
#   19421.666666666668,
#   26650.26234183988,
#   150],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   33,
#   1.0,
#   array([[         35,         312],
#          [         34,         313],
#          [         33,         313],
#          [         33,         314],
#          [         37,         318],
#          [         39,         318],
#          [         40,         317],
#          [         40,         313],
#          [         39,         313],
#          [         38,         312]], dtype=float32),
#   10,
#   30.5,
#   2577.0,
#   9.0,
#   37.0,
#   36.58684158325195,
#   314.306884765625,
#   9.584014892578125,
#   9.25225830078125,
#   33201.0,
#   157.0,
#   474.0,
#   0.8531264662742615,
#   2623.0,
#   874.3333333333334,
#   1204.021409924074,
#   33832.0,
#   11277.333333333334,
#   15502.913539790583,
#   635],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   34,
#   1.0,
#   array([[        358,         308],
#          [        357,         309],
#          [        356,         309],
#          [        355,         310],
#          [        355,         311],
#          [        353,         313],
#          [        353,         315],
#          [        354,         316],
#          [        354,         319],
#          [        355,         320],
#          [        355,         321],
#          [        356,         321],
#          [        357,         322],
#          [        358,         322],
#          [        358,         321],
#          [        359,         320],
#          [        360,         320],
#          [        361,         319],
#          [        362,         319],
#          [        363,         318],
#          [        363,         317],
#          [        366,         314],
#          [        366,         312],
#          [        365,         312],
#          [        363,         310],
#          [        363,         309],
#          [        362,         308]], dtype=float32),
#   27,
#   118.0,
#   10103.0,
#   39.0,
#   125.0,
#   357.8750915527344,
#   314.5265808105469,
#   14.6939697265625,
#   14.04388427734375,
#   48066.0,
#   319.0,
#   687.0,
#   0.8527424931526184,
#   10267.0,
#   3422.3333333333335,
#   4724.075171101982,
#   49072.0,
#   16357.333333333334,
#   22421.91654510282,
#   198],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   35,
#   1.0,
#   array([[        286,         329],
#          [        285,         330],
#          [        285,         331],
#          [        284,         332],
#          [        284,         337],
#          [        285,         338],
#          [        289,         338],
#          [        290,         337],
#          [        290,         336],
#          [        291,         335],
#          [        291,         331],
#          [        289,         329]], dtype=float32),
#   12,
#   54.5,
#   4927.0,
#   21.0,
#   65.0,
#   287.57794189453125,
#   333.12066650390625,
#   10.3895263671875,
#   11.009033203125,
#   33652.0,
#   172.0,
#   445.0,
#   0.85076504945755,
#   5013.0,
#   1671.0,
#   2302.4097521220388,
#   34269.0,
#   11423.0,
#   15718.67176322478,
#   140],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   36,
#   1.0,
#   array([[          9,         424],
#          [          8,         425],
#          [          8,         431],
#          [          9,         432],
#          [          9,         433],
#          [         10,         434],
#          [         11,         433],
#          [         14,         433],
#          [         17,         430],
#          [         18,         430],
#          [         18,         428],
#          [         19,         427],
#          [         19,         426],
#          [         17,         424]], dtype=float32),
#   14,
#   83.0,
#   7494.0,
#   30.0,
#   94.0,
#   11.969061851501465,
#   427.57403564453125,
#   14.076547622680664,
#   14.03802490234375,
#   42539.0,
#   315.0,
#   621.0,
#   0.8506702184677124,
#   7618.0,
#   2539.3333333333335,
#   3503.5758241481735,
#   43475.0,
#   14491.666666666666,
#   19832.85303620121,
#   447],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   37,
#   1.0,
#   array([[        261,         212],
#          [        260,         213],
#          [        260,         217],
#          [        261,         218],
#          [        262,         218],
#          [        265,         215],
#          [        266,         215],
#          [        267,         214],
#          [        267,         213],
#          [        266,         212]], dtype=float32),
#   10,
#   29.5,
#   2024.0,
#   8.0,
#   24.0,
#   261.552978515625,
#   214.0933074951172,
#   10.408447265625,
#   10.13299560546875,
#   25729.0,
#   147.0,
#   345.0,
#   0.8493729829788208,
#   2056.0,
#   685.3333333333334,
#   946.6028147480276,
#   26221.0,
#   8740.333333333334,
#   12013.073360117116,
#   416],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   38,
#   1.0,
#   array([[         25,         220],
#          [         20,         225],
#          [         20,         229],
#          [         21,         230],
#          [         21,         231],
#          [         29,         231],
#          [         31,         229],
#          [         31,         221],
#          [         30,         220]], dtype=float32),
#   9,
#   104.5,
#   10150.0,
#   35.0,
#   144.0,
#   24.46676254272461,
#   225.26611328125,
#   15.380409240722656,
#   14.762939453125,
#   46660.0,
#   380.0,
#   723.0,
#   0.8482741117477417,
#   10329.0,
#   3443.0,
#   4742.773942184749,
#   47763.0,
#   15921.0,
#   21736.206400075123,
#   450],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   39,
#   1.0,
#   array([[          9,         376],
#          [          9,         377],
#          [          8,         378],
#          [          8,         382],
#          [          9,         383],
#          [         18,         383],
#          [         19,         382],
#          [         19,         378],
#          [         18,         377],
#          [         18,         376]], dtype=float32),
#   10,
#   73.0,
#   6055.0,
#   23.0,
#   72.0,
#   13.100621223449707,
#   377.1759033203125,
#   14.829183578491211,
#   15.1644287109375,
#   40542.0,
#   328.0,
#   592.0,
#   0.8476032614707947,
#   6150.0,
#   2050.0,
#   2832.033309596952,
#   41462.0,
#   13820.666666666666,
#   18895.143385419324,
#   336],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   40,
#   1.0,
#   array([[        172,         334],
#          [        171,         335],
#          [        169,         335],
#          [        169,         336],
#          [        168,         337],
#          [        168,         342],
#          [        169,         343],
#          [        175,         343],
#          [        178,         340],
#          [        178,         339],
#          [        179,         338],
#          [        179,         337],
#          [        178,         336],
#          [        178,         335],
#          [        177,         335],
#          [        176,         334]], dtype=float32),
#   16,
#   80.5,
#   8800.0,
#   34.0,
#   145.0,
#   172.63059997558594,
#   336.03741455078125,
#   14.40570068359375,
#   14.5108642578125,
#   68799.0,
#   337.0,
#   1048.0,
#   0.8472830653190613,
#   8979.0,
#   2993.0,
#   4106.419121326999,
#   70184.0,
#   23394.666666666668,
#   32107.02409477126,
#   433],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   41,
#   1.0,
#   array([[        177,         448],
#          [        176,         449],
#          [        176,         458],
#          [        177,         459],
#          [        178,         459],
#          [        179,         458],
#          [        181,         458],
#          [        184,         455],
#          [        184,         454],
#          [        185,         453],
#          [        185,         450],
#          [        184,         450],
#          [        183,         449],
#          [        181,         449],
#          [        180,         448]], dtype=float32),
#   15,
#   76.5,
#   7963.0,
#   22.0,
#   98.0,
#   182.26718139648438,
#   452.86962890625,
#   14.0225830078125,
#   14.10205078125,
#   58319.0,
#   338.0,
#   819.0,
#   0.8469753265380859,
#   8083.0,
#   2694.3333333333335,
#   3725.6391248870154,
#   59476.0,
#   19825.333333333332,
#   27219.841051866722,
#   136],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   42,
#   1.0,
#   array([[        386,         416],
#          [        384,         418],
#          [        384,         422],
#          [        385,         423],
#          [        390,         423],
#          [        391,         422],
#          [        391,         421],
#          [        392,         420],
#          [        392,         418],
#          [        390,         416]], dtype=float32),
#   10,
#   48.5,
#   4857.0,
#   18.0,
#   66.0,
#   388.2043762207031,
#   419.12774658203125,
#   10.8021240234375,
#   10.28350830078125,
#   30157.0,
#   181.0,
#   429.0,
#   0.8466959595680237,
#   4941.0,
#   1647.0,
#   2269.8973545074678,
#   30767.0,
#   10255.666666666666,
#   14072.731962518468,
#   337],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   43,
#   1.0,
#   array([[        445,          16],
#          [        444,          17],
#          [        444,          23],
#          [        445,          24],
#          [        445,          25],
#          [        447,          27],
#          [        454,          27],
#          [        455,          26],
#          [        455,          21],
#          [        450,          16]], dtype=float32),
#   10,
#   102.0,
#   9859.0,
#   35.0,
#   140.0,
#   447.59027099609375,
#   22.830223083496094,
#   14.43341064453125,
#   13.961920738220215,
#   46854.0,
#   312.0,
#   664.0,
#   0.8465988636016846,
#   10034.0,
#   3344.6666666666665,
#   4606.528724418083,
#   47830.0,
#   15943.333333333334,
#   21857.614406781806,
#   256],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   44,
#   0.0,
#   array([[        205,          28],
#          [        205,          30],
#          [        206,          30],
#          [        206,          28]], dtype=float32),
#   4,
#   2.0,
#   0.0,
#   0.0,
#   0.0,
#   206.8426513671875,
#   20.50403594970703,
#   28.11181640625,
#   29.235824584960938,
#   136779.0,
#   1173.0,
#   2169.0,
#   0.8465140461921692,
#   0.0,
#   0.0,
#   0.0,
#   140121.0,
#   46707.0,
#   63691.81994573557],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   45,
#   1.0,
#   array([[        209,         180],
#          [        208,         181],
#          [        208,         186],
#          [        209,         187],
#          [        214,         187],
#          [        215,         186],
#          [        215,         181],
#          [        214,         180]], dtype=float32),
#   8,
#   47.0,
#   4926.0,
#   19.0,
#   70.0,
#   211.38099670410156,
#   182.81851196289062,
#   10.226348876953125,
#   9.57684326171875,
#   26520.0,
#   156.0,
#   378.0,
#   0.845042884349823,
#   5015.0,
#   1671.6666666666667,
#   2301.2553578910406,
#   27054.0,
#   9018.0,
#   12376.114737671109,
#   530],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   46,
#   1.0,
#   array([[        477,         244],
#          [        476,         245],
#          [        476,         250],
#          [        477,         251],
#          [        482,         251],
#          [        483,         250],
#          [        483,         245],
#          [        482,         244]], dtype=float32),
#   8,
#   47.0,
#   4187.0,
#   16.0,
#   63.0,
#   477.9755859375,
#   247.47091674804688,
#   9.664794921875,
#   9.0421142578125,
#   18785.0,
#   143.0,
#   290.0,
#   0.8446318507194519,
#   4266.0,
#   1422.0,
#   1955.244400750624,
#   19218.0,
#   6406.0,
#   8753.480564895315,
#   548],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   47,
#   1.0,
#   array([[        221,          12],
#          [        220,          13],
#          [        220,          14],
#          [        221,          15],
#          [        222,          15],
#          [        223,          14],
#          [        223,          13],
#          [        222,          12]], dtype=float32),
#   8,
#   7.0,
#   166.0,
#   1.0,
#   2.0,
#   219.7248992919922,
#   12.33124828338623,
#   6.479766845703125,
#   6.745384216308594,
#   8783.0,
#   88.0,
#   145.0,
#   0.8443772792816162,
#   169.0,
#   56.333333333333336,
#   77.54711829304526,
#   9016.0,
#   3005.3333333333335,
#   4085.493551035854,
#   44],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   48,
#   1.0,
#   array([[        346,         317],
#          [        345,         318],
#          [        345,         324],
#          [        344,         325],
#          [        346,         327],
#          [        350,         327],
#          [        351,         326],
#          [        351,         325],
#          [        355,         321],
#          [        353,         319],
#          [        352,         319],
#          [        350,         317]], dtype=float32),
#   12,
#   73.5,
#   6469.0,
#   24.0,
#   89.0,
#   347.83154296875,
#   319.7240905761719,
#   15.025634765625,
#   14.96826171875,
#   56122.0,
#   341.0,
#   770.0,
#   0.8420261740684509,
#   6582.0,
#   2194.0,
#   3022.9979600831134,
#   57233.0,
#   19077.666666666668,
#   26194.884797524028,
#   198],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   49,
#   1.0,
#   array([[        149,         392],
#          [        148,         393],
#          [        148,         397],
#          [        150,         399],
#          [        152,         397],
#          [        152,         393],
#          [        151,         393],
#          [        150,         392]], dtype=float32),
#   8,
#   22.0,
#   2671.0,
#   5.0,
#   38.0,
#   151.4045867919922,
#   393.8060302734375,
#   11.666839599609375,
#   11.417236328125,
#   37178.0,
#   216.0,
#   525.0,
#   0.841680109500885,
#   2714.0,
#   904.6666666666666,
#   1249.0589346472896,
#   37919.0,
#   12639.666666666666,
#   17351.68046296637,
#   341],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   50,
#   1.0,
#   array([[        485,         168],
#          [        484,         169],
#          [        484,         174],
#          [        485,         175],
#          [        489,         175],
#          [        491,         173],
#          [        491,         169],
#          [        490,         168]], dtype=float32),
#   8,
#   45.5,
#   3075.0,
#   17.0,
#   44.0,
#   486.436767578125,
#   169.3192596435547,
#   10.91583251953125,
#   10.4361572265625,
#   23224.0,
#   190.0,
#   346.0,
#   0.8414232134819031,
#   3136.0,
#   1045.3333333333333,
#   1435.2333917829842,
#   23760.0,
#   7920.0,
#   10821.749581283057,
#   442],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   51,
#   1.0,
#   array([[        241,          64],
#          [        240,          65],
#          [        240,          69],
#          [        241,          70],
#          [        241,          71],
#          [        243,          71],
#          [        244,          72],
#          [        249,          72],
#          [        250,          71],
#          [        250,          70],
#          [        251,          69],
#          [        251,          65],
#          [        250,          64]], dtype=float32),
#   13,
#   79.0,
#   10219.0,
#   33.0,
#   144.0,
#   247.224365234375,
#   69.23596954345703,
#   14.91473388671875,
#   14.705581665039062,
#   55822.0,
#   349.0,
#   799.0,
#   0.8411029577255249,
#   10396.0,
#   3465.3333333333335,
#   4775.778493839744,
#   56970.0,
#   18990.0,
#   26044.804894642617,
#   156],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   52,
#   1.0,
#   array([[         29,         428],
#          [         26,         431],
#          [         26,         432],
#          [         25,         433],
#          [         25,         436],
#          [         26,         437],
#          [         26,         438],
#          [         27,         438],
#          [         29,         440],
#          [         30,         440],
#          [         31,         439],
#          [         32,         439],
#          [         33,         438],
#          [         34,         438],
#          [         34,         436],
#          [         35,         435],
#          [         35,         429],
#          [         34,         428]], dtype=float32),
#   18,
#   93.5,
#   10290.0,
#   33.0,
#   160.0,
#   29.59821319580078,
#   433.1637268066406,
#   13.268455505371094,
#   14.33563232421875,
#   41448.0,
#   313.0,
#   641.0,
#   0.8404492735862732,
#   10483.0,
#   3494.3333333333335,
#   4805.541685272211,
#   42402.0,
#   14134.0,
#   19314.37880612956,
#   447],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   53,
#   1.0,
#   array([[        437,         256],
#          [        436,         257],
#          [        436,         261],
#          [        438,         263],
#          [        439,         262],
#          [        441,         262],
#          [        442,         261],
#          [        442,         259],
#          [        443,         258],
#          [        441,         256]], dtype=float32),
#   10,
#   36.0,
#   3811.0,
#   12.0,
#   45.0,
#   438.5079650878906,
#   259.04315185546875,
#   9.78448486328125,
#   10.802749633789062,
#   29066.0,
#   168.0,
#   405.0,
#   0.8402203321456909,
#   3868.0,
#   1289.3333333333333,
#   1783.1384940292464,
#   29639.0,
#   9879.666666666666,
#   13567.131417100996,
#   507],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   54,
#   1.0,
#   array([[         58,         304],
#          [         56,         306],
#          [         57,         307],
#          [         57,         308],
#          [         60,         311],
#          [         60,         312],
#          [         62,         314],
#          [         65,         314],
#          [         67,         312],
#          [         67,         310],
#          [         68,         309],
#          [         68,         307],
#          [         69,         306],
#          [         68,         305],
#          [         67,         305],
#          [         66,         304]], dtype=float32),
#   16,
#   88.0,
#   11868.0,
#   37.0,
#   177.0,
#   61.88005828857422,
#   309.3731384277344,
#   14.493011474609375,
#   15.35614013671875,
#   68273.0,
#   344.0,
#   963.0,
#   0.8387088179588318,
#   12082.0,
#   4027.3333333333335,
#   5544.483163970791,
#   69580.0,
#   23193.333333333332,
#   31877.139670233206,
#   678],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   55,
#   1.0,
#   array([[        421,         160],
#          [        420,         161],
#          [        420,         168],
#          [        421,         169],
#          [        421,         170],
#          [        423,         170],
#          [        423,         169],
#          [        429,         163],
#          [        430,         163],
#          [        430,         161],
#          [        429,         160]], dtype=float32),
#   11,
#   66.5,
#   8712.0,
#   17.0,
#   122.0,
#   425.00726318359375,
#   164.87899780273438,
#   15.5789794921875,
#   15.3099365234375,
#   53777.0,
#   378.0,
#   815.0,
#   0.8385048508644104,
#   8851.0,
#   2950.3333333333335,
#   4074.3390738730727,
#   54970.0,
#   18323.333333333332,
#   25070.162907771908,
#   371],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   56,
#   1.0,
#   array([[        373,         260],
#          [        372,         261],
#          [        372,         262],
#          [        373,         263],
#          [        373,         265],
#          [        375,         265],
#          [        377,         263],
#          [        377,         261],
#          [        375,         261],
#          [        374,         260]], dtype=float32),
#   10,
#   17.5,
#   1463.0,
#   8.0,
#   20.0,
#   373.18719482421875,
#   261.93853759765625,
#   10.1148681640625,
#   9.8603515625,
#   32089.0,
#   153.0,
#   439.0,
#   0.8382303714752197,
#   1491.0,
#   497.0,
#   683.0827182706353,
#   32681.0,
#   10893.666666666666,
#   14987.818727961125,
#   467],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001597.bmp',
#   57,
#   1.0,
#   array([[        297,         328],
#          [        296,         329],
#          [        296,         334],
#          [        297,         335],
#          [        298,         335],
#          [        299,         334],
#          [        299,         333],
#          [        302,         330],
#          [        302,         329],
#          [        301,         328]], dtype=float32),
#   10,
#   29.5,
#   2156.0,
#   5.0,
#   27.0,
#   297.4749755859375,
#   329.25225830078125,
# ...
#          [        363,         467],
#          [        363,         465],
#          [        362,         464]], dtype=float32),
#   14,
#   107.5,
#   12042.0,
#   30.0,
#   155.0,
#   358.2630310058594,
#   470.552001953125,
#   14.60797119140625,
#   14.6832275390625,
#   57114.0,
#   357.0,
#   718.0,
#   0.7849882245063782,
#   12227.0,
#   4075.6666666666665,
#   5633.279467198086,
#   58189.0,
#   19396.333333333332,
#   26670.825063270084,
#   60],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   30,
#   1.0,
#   array([[        185,         196],
#          [        184,         197],
#          [        184,         198],
#          [        185,         199],
#          [        185,         200],
#          [        186,         201],
#          [        187,         201],
#          [        188,         202],
#          [        190,         202],
#          [        190,         201],
#          [        191,         200],
#          [        191,         199],
#          [        192,         198],
#          [        190,         196]], dtype=float32),
#   14,
#   34.0,
#   4093.0,
#   12.0,
#   58.0,
#   188.30767822265625,
#   198.15948486328125,
#   10.201934814453125,
#   10.082550048828125,
#   31157.0,
#   173.0,
#   393.0,
#   0.7816663980484009,
#   4163.0,
#   1387.6666666666667,
#   1913.0517214359074,
#   31723.0,
#   10574.333333333334,
#   14554.420298391213,
#   49],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   31,
#   1.0,
#   array([[        281,         420],
#          [        280,         421],
#          [        280,         422],
#          [        281,         423],
#          [        282,         423],
#          [        283,         422],
#          [        283,         421],
#          [        282,         420]], dtype=float32),
#   8,
#   7.0,
#   680.0,
#   2.0,
#   10.0,
#   282.5794677734375,
#   421.017333984375,
#   5.9007568359375,
#   5.7135009765625,
#   7742.0,
#   50.0,
#   85.0,
#   0.7802075147628784,
#   692.0,
#   230.66666666666666,
#   317.74343248742196,
#   7877.0,
#   2625.6666666666665,
#   3617.8222117118407,
#   95],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   32,
#   1.0,
#   array([[        476,         388],
#          [        475,         389],
#          [        473,         389],
#          [        473,         391],
#          [        474,         392],
#          [        474,         393],
#          [        475,         394],
#          [        475,         399],
#          [        477,         401],
#          [        478,         401],
#          [        479,         400],
#          [        481,         400],
#          [        483,         398],
#          [        483,         393],
#          [        478,         388]], dtype=float32),
#   15,
#   89.5,
#   9047.0,
#   31.0,
#   125.0,
#   476.12255859375,
#   395.2678527832031,
#   14.9630126953125,
#   15.11676025390625,
#   56589.0,
#   370.0,
#   732.0,
#   0.7796210050582886,
#   9203.0,
#   3067.6666666666665,
#   4228.201298687448,
#   57691.0,
#   19230.333333333332,
#   26416.97992243289,
#   94],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   33,
#   1.0,
#   array([[        195,         224],
#          [        194,         225],
#          [        193,         225],
#          [        193,         230],
#          [        195,         230],
#          [        196,         231],
#          [        198,         231],
#          [        199,         230],
#          [        199,         227],
#          [        200,         226],
#          [        198,         224]], dtype=float32),
#   11,
#   38.0,
#   4024.0,
#   12.0,
#   54.0,
#   196.13070678710938,
#   226.21334838867188,
#   10.370819091796875,
#   10.44012451171875,
#   42214.0,
#   171.0,
#   568.0,
#   0.7773197293281555,
#   4090.0,
#   1363.3333333333333,
#   1881.4535751794558,
#   42953.0,
#   14317.666666666666,
#   19726.35229556871,
#   49],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   34,
#   1.0,
#   array([[        197,         208],
#          [        196,         209],
#          [        196,         210],
#          [        197,         211],
#          [        198,         211],
#          [        199,         210],
#          [        199,         209],
#          [        198,         208]], dtype=float32),
#   8,
#   7.0,
#   165.0,
#   2.0,
#   3.0,
#   195.3152313232422,
#   210.37774658203125,
#   6.33441162109375,
#   6.18359375,
#   10774.0,
#   65.0,
#   130.0,
#   0.7753239870071411,
#   170.0,
#   56.666666666666664,
#   76.60432247740478,
#   10969.0,
#   3656.3333333333335,
#   5033.020321393065,
#   49],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   35,
#   1.0,
#   array([[        157,         140],
#          [        156,         141],
#          [        156,         143],
#          [        157,         144],
#          [        157,         147],
#          [        158,         148],
#          [        159,         148],
#          [        160,         147],
#          [        163,         147],
#          [        164,         146],
#          [        165,         146],
#          [        166,         145],
#          [        167,         145],
#          [        167,         143],
#          [        168,         142],
#          [        167,         141],
#          [        165,         141],
#          [        164,         140]], dtype=float32),
#   18,
#   68.5,
#   9144.0,
#   21.0,
#   136.0,
#   163.72360229492188,
#   145.13247680664062,
#   15.9356689453125,
#   15.97979736328125,
#   101029.0,
#   416.0,
#   1345.0,
#   0.7716616988182068,
#   9301.0,
#   3100.3333333333335,
#   4273.775562141226,
#   102790.0,
#   34263.333333333336,
#   47211.97901898297,
#   37],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   36,
#   1.0,
#   array([[        265,         169],
#          [        265,         171],
#          [        266,         172],
#          [        266,         173],
#          [        267,         173],
#          [        269,         175],
#          [        269,         178],
#          [        268,         179],
#          [        268,         182],
#          [        270,         182],
#          [        271,         183],
#          [        274,         183],
#          [        275,         182],
#          [        275,         181],
#          [        277,         179],
#          [        278,         179],
#          [        279,         178],
#          [        279,         177],
#          [        277,         175],
#          [        276,         175],
#          [        275,         174],
#          [        274,         174],
#          [        273,         173],
#          [        271,         173],
#          [        270,         172],
#          [        270,         170],
#          [        269,         169]], dtype=float32),
#   27,
#   96.5,
#   8492.0,
#   38.0,
#   108.0,
#   270.6906433105469,
#   175.27365112304688,
#   15.1202392578125,
#   16.1605224609375,
#   68131.0,
#   380.0,
#   872.0,
#   0.7712964415550232,
#   8638.0,
#   2879.3333333333335,
#   3968.8575462243816,
#   69383.0,
#   23127.666666666668,
#   31822.796067529256,
#   62],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   37,
#   0.0,
#   array([], shape=(0, 2), dtype=float32),
#   0,
#   0.0,
#   0.0,
#   0.0,
#   0.0,
#   166.4546356201172,
#   155.52069091796875,
#   27.671875,
#   26.577392578125,
#   200519.0,
#   1241.0,
#   2580.0,
#   0.7711287140846252,
#   0.0,
#   0.0,
#   0.0,
#   204340.0,
#   68113.33333333333,
#   93626.5405902028],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   38,
#   1.0,
#   array([[         20,           0],
#          [         20,          13],
#          [         22,          15],
#          [         27,          15],
#          [         28,          14],
#          [         29,          14],
#          [         30,          13],
#          [         30,          12],
#          [         31,          11],
#          [         31,           5],
#          [         29,           3],
#          [         28,           3],
#          [         27,           2],
#          [         27,           0]], dtype=float32),
#   14,
#   143.0,
#   15477.0,
#   50.0,
#   220.0,
#   25.774669647216797,
#   7.280016899108887,
#   15.515357971191406,
#   14.560033798217773,
#   40014.0,
#   278.0,
#   516.0,
#   0.7702663540840149,
#   15747.0,
#   5249.0,
#   7232.621147735215,
#   40808.0,
#   13602.666666666666,
#   18675.88565206183,
#   129],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   39,
#   1.0,
#   array([[        481,         424],
#          [        480,         425],
#          [        480,         430],
#          [        481,         431],
#          [        482,         431],
#          [        483,         430],
#          [        483,         429],
#          [        486,         426],
#          [        486,         425],
#          [        485,         424]], dtype=float32),
#   10,
#   29.5,
#   2171.0,
#   13.0,
#   35.0,
#   480.8897705078125,
#   426.0774230957031,
#   9.2344970703125,
#   9.2066650390625,
#   21464.0,
#   162.0,
#   278.0,
#   0.7698602080345154,
#   2219.0,
#   739.6666666666666,
#   1012.1453562716288,
#   21904.0,
#   7301.333333333333,
#   10014.629609836913,
#   94],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   40,
#   1.0,
#   array([[        189,         444],
#          [        188,         445],
#          [        187,         445],
#          [        185,         447],
#          [        185,         453],
#          [        186,         454],
#          [        188,         454],
#          [        189,         455],
#          [        193,         451],
#          [        194,         451],
#          [        195,         450],
#          [        195,         446],
#          [        193,         444]], dtype=float32),
#   13,
#   82.0,
#   6637.0,
#   29.0,
#   81.0,
#   187.76666259765625,
#   447.64324951171875,
#   14.04791259765625,
#   14.574951171875,
#   65335.0,
#   360.0,
#   820.0,
#   0.769170343875885,
#   6747.0,
#   2249.0,
#   3102.8571779356307,
#   66515.0,
#   22171.666666666668,
#   30521.663435810453,
#   22],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   41,
#   1.0,
#   array([[        469,         388],
#          [        468,         389],
#          [        468,         395],
#          [        469,         396],
#          [        469,         397],
#          [        470,         397],
#          [        477,         390],
#          [        477,         389],
#          [        475,         389],
#          [        474,         388]], dtype=float32),
#   10,
#   52.0,
#   6921.0,
#   17.0,
#   102.0,
#   471.0052490234375,
#   392.8830261230469,
#   13.5545654296875,
#   12.63653564453125,
#   43218.0,
#   286.0,
#   571.0,
#   0.7671352028846741,
#   7040.0,
#   2346.6666666666665,
#   3234.728255802779,
#   44075.0,
#   14691.666666666666,
#   20171.499305262914,
#   94],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   42,
#   1.0,
#   array([[        206,         208],
#          [        205,         209],
#          [        204,         209],
#          [        204,         210],
#          [        202,         212],
#          [        202,         214],
#          [        205,         217],
#          [        205,         218],
#          [        208,         221],
#          [        208,         222],
#          [        210,         222],
#          [        214,         218],
#          [        214,         215],
#          [        215,         214],
#          [        211,         210],
#          [        211,         209],
#          [        210,         208]], dtype=float32),
#   17,
#   115.5,
#   11164.0,
#   33.0,
#   141.0,
#   206.01895141601562,
#   215.2467041015625,
#   15.40850830078125,
#   15.5562744140625,
#   74950.0,
#   387.0,
#   966.0,
#   0.7626219987869263,
#   11338.0,
#   3779.3333333333335,
#   5221.934018052018,
#   76303.0,
#   25434.333333333332,
#   35013.661565483584,
#   49],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   43,
#   1.0,
#   array([[        379,         220],
#          [        378,         221],
#          [        377,         221],
#          [        377,         222],
#          [        376,         223],
#          [        376,         229],
#          [        378,         231],
#          [        382,         231],
#          [        383,         230],
#          [        383,         229],
#          [        385,         227],
#          [        386,         227],
#          [        387,         226],
#          [        387,         221],
#          [        386,         220]], dtype=float32),
#   15,
#   99.5,
#   9421.0,
#   32.0,
#   132.0,
#   380.4389953613281,
#   223.30181884765625,
#   13.6568603515625,
#   13.5399169921875,
#   45494.0,
#   308.0,
#   585.0,
#   0.7622886896133423,
#   9585.0,
#   3195.0,
#   4402.636104275104,
#   46387.0,
#   15462.333333333334,
#   21235.896250348265,
#   108],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   44,
#   1.0,
#   array([[        169,         429],
#          [        168,         430],
#          [        168,         431],
#          [        169,         432],
#          [        170,         431],
#          [        170,         430]], dtype=float32),
#   6,
#   4.0,
#   561.0,
#   1.0,
#   8.0,
#   170.3863525390625,
#   435.57965087890625,
#   17.74951171875,
#   17.952880859375,
#   130952.0,
#   542.0,
#   1700.0,
#   0.7584463953971863,
#   570.0,
#   190.0,
#   262.3521806020805,
#   133194.0,
#   44398.0,
#   61204.746155833374,
#   22],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   45,
#   1.0,
#   array([[        249,           8],
#          [        248,           9],
#          [        248,          14],
#          [        249,          15],
#          [        249,          16],
#          [        250,          17],
#          [        254,          13],
#          [        255,          13],
#          [        255,          12],
#          [        256,          11],
#          [        256,          10],
#          [        255,           9],
#          [        252,           9],
#          [        251,           8]], dtype=float32),
#   14,
#   46.0,
#   5482.0,
#   18.0,
#   73.0,
#   252.66448974609375,
#   12.73952865600586,
#   13.8917236328125,
#   13.977676391601562,
#   58682.0,
#   306.0,
#   734.0,
#   0.7532393336296082,
#   5573.0,
#   1857.6666666666667,
#   2562.8890382188265,
#   59722.0,
#   19907.333333333332,
#   27418.38649924941,
#   116],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   46,
#   1.0,
#   array([[        186,         221],
#          [        185,         222],
#          [        185,         223],
#          [        184,         224],
#          [        184,         230],
#          [        185,         231],
#          [        190,         231],
#          [        191,         230],
#          [        191,         225],
#          [        190,         224],
#          [        190,         222],
#          [        188,         222],
#          [        187,         221]], dtype=float32),
#   13,
#   60.0,
#   6376.0,
#   25.0,
#   95.0,
#   187.28704833984375,
#   225.4459686279297,
#   11.8973388671875,
#   11.932891845703125,
#   51644.0,
#   228.0,
#   687.0,
#   0.7508038878440857,
#   6496.0,
#   2165.3333333333335,
#   2977.528094838998,
#   52559.0,
#   17519.666666666668,
#   24130.27509628148,
#   49],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   47,
#   1.0,
#   array([[        349,         212],
#          [        348,         213],
#          [        348,         218],
#          [        350,         220],
#          [        352,         220],
#          [        353,         219],
#          [        354,         219],
#          [        354,         218],
#          [        355,         217],
#          [        355,         213],
#          [        354,         212]], dtype=float32),
#   11,
#   49.0,
#   5786.0,
#   13.0,
#   73.0,
#   351.591796875,
#   216.97718811035156,
#   12.893798828125,
#   13.2686767578125,
#   61521.0,
#   278.0,
#   764.0,
#   0.7487408518791199,
#   5872.0,
#   1957.3333333333333,
#   2707.3869731204336,
#   62563.0,
#   20854.333333333332,
#   28756.360251062528,
#   108],
#  ['S:\\Phys\\FIV942 Adipo\\Adipo2Viz 512\\001599.bmp',
#   48,
#   1.0,
#   array([[        254,         164],
#          [        253,         165],
#          [        253,         166],
#          [        254,         167],
#          [        255,         166],
#          [        257,         166],
#          [        257,         165],
#          [        255,         165]], dtype=float32),
#   8,
#   6.0,
#   195.0,
#   3.0,
#   3.0,
#   252.65728759765625,
#   163.669677734375,
#   7.11279296875,
#   7.141754150390625,
#   17507.0,
#   88.0,
#   222.0,
#   0.7411998510360718,
#   201.0,
#   67.0,
#   90.50966799187809,
#   17817.0,
#   5939.0,
#   8179.99417277706,
#   62],
#  ...]
