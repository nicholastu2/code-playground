# %%
# Imports
from PIL import Image
from ultralytics import YOLO
import json
import numpy as np
import matplotlib.path as mpltPath
import csv
import matplotlib.pyplot as plt
import sys
import matplotlib.colors as mcolors
import cv2
import statistics

model_path = r"S:\Phys\FIV942 Adipo\Datasets\02h9\YO 512 0320 Snow\map75=0607616 YOLOv8n-segml idx=5 ep=52 btch=32 rnd=4670342\weights\best.pt"
val_data = r"S:\Phys\FIV942 Adipo\FIV942P3 Chops 512"

adipo_seg = YOLO(model_path)

predictions = adipo_seg.predict(val_data, show=False, max_det = 1000)

img1_data = predictions[0]
img1_mask_coords = img1_data.masks.xy
img1_classes = img1_data.boxes.cls.numpy()

class0_indices = np.where(img1_classes == 0)[0]

class1_indices = np.where(img1_classes == 1)[0]

img1_box_coords = img1_data.boxes.xyxy
img1_class0_bbox_coords = img1_box_coords[class0_indices]
img1_class1_bbox_coords = img1_box_coords[class1_indices]

def polygon_area(coords):
    """
    Calculate the area of a polygon given its vertices using numpy.
    :param coords: A numpy array of shape (n, 2), where n is the number of vertices.
    :return: The area of the polygon.
    """
    x = coords[:, 0]
    y = coords[:, 1]
    i=np.arange(len(x))
    # 'shoelace' formula
    # return 0.5*np.abs(np.dot(x, np.roll(y, -1)) - np.dot(y, np.roll(x, -1)))
    return np.abs(np.sum(x[i-1]*y[i]-x[i]*y[i-1])*0.5)

# Example list of numpy arrays as provided
polygons = img1_mask_coords

# Calculate the area for each polygon and store the results in a new list
areas = [polygon_area(polygon) for polygon in polygons]

class1_parents = []

for class1_coord in img1_class1_bbox_coords.numpy():
    class1_instance_parents = []
    class0_id = 0
    print("the class1 instance: ", class1_coord)
    for class0_coord in img1_class0_bbox_coords.numpy():
        print("the class0 instance: ", class0_coord)
        if class1_coord[0] > class0_coord[2] or class1_coord[2] < class0_coord[0] or class1_coord[1] > class0_coord[3] or class1_coord[3] < class0_coord[1]:
            print("it wasn't a parent")
            class0_id += 1
            print("class0_id is now: ", class0_id)
            continue
        elif (class1_coord[0] > class0_coord[0] and class1_coord[0] < class0_coord[2] and class1_coord[1] > class0_coord[1] and class1_coord[1] < class0_coord[3]) or (class1_coord[2] < class0_coord[2] and class1_coord[2] > class0_coord[0] and class1_coord[3] > class0_coord[1] and class1_coord[3] < class0_coord[3]):
            class1_instance_parents.append(class0_indices[class0_id])
            print("it was an instance, we added ", class0_indices[class0_id])
            class0_id += 1
            print("now class0_id is: ", class0_id)
            
    class1_parents.append(class1_instance_parents)
    
image_path = r"S:\Phys\FIV942 Adipo\Adipo2Viz 512\001597.bmp"
image = Image.open(image_path)
image_array = np.array(image)

pixel_intensity_data = []
for mask_outline in range(len(img1_mask_coords)):
    vertices = img1_mask_coords[mask_outline]

    
    # Assuming image_array is a 2D numpy array for a grayscale image
    # For a color image, you need to decide how to handle the color channels

    # Create a mesh grid of coordinate values
    xx, yy = np.meshgrid(np.arange(image_array.shape[1]), np.arange(image_array.shape[0]))

    # Flatten the grid arrays
    x_flat = xx.flatten()
    y_flat = yy.flatten()

    # Create a list of (x, y) points from the flattened grid
    class1_points = np.vstack((x_flat, y_flat)).T

    # Create a path object from the vertices
    polygon_path = mpltPath.Path(vertices)

    # Use the path object to create a mask
    inside_polygon = polygon_path.contains_points(class1_points)

    # Reshape the mask back to the image shape
    mask = inside_polygon.reshape(xx.shape)

    # Apply the mask to select pixels within the polygon
    # selected_pixels = image_array[mask]

    # Sum the intensities of the selected pixels
    # sum_of_intensities = np.sum(selected_pixels)

    # print("Sum of pixel intensities in the polygonal region:", sum_of_intensities)
    # Initialize an array to hold the sum of intensities for each channel
    sum_of_intensities_per_channel = np.zeros(image_array.shape[2])

    # Iterate over each channel
    for i in range(image_array.shape[2]):
        # Apply the mask to the current channel and sum the intensities
        selected_pixels = image_array[:, :, i][mask]
        sum_of_intensities_per_channel[i] = np.sum(selected_pixels)

    print("Sum of pixel intensities in the polygonal region for each channel:", sum_of_intensities_per_channel)
    pixel_intensity_data.append(sum_of_intensities_per_channel)
    
img1_box_centers = img1_data.boxes.xywh.numpy()

box_intensity_data = []
for box_instance in range(len(img1_box_centers)):
    bbox_xywh = img1_data.boxes.xywh.numpy()[box_instance]
    bbox_corners = [[bbox_xywh[0] - bbox_xywh[2], bbox_xywh[1] + bbox_xywh[3]],[bbox_xywh[0] + bbox_xywh[2], bbox_xywh[1] + bbox_xywh[3]]
                , [bbox_xywh[0] + bbox_xywh[2], bbox_xywh[1] - bbox_xywh[3]], [bbox_xywh[0] - bbox_xywh[2], bbox_xywh[1] - bbox_xywh[3]]]
    vertices = bbox_corners

    
    # Assuming image_array is a 2D numpy array for a grayscale image
    # For a color image, you need to decide how to handle the color channels

    # Create a mesh grid of coordinate values
    xx, yy = np.meshgrid(np.arange(image_array.shape[1]), np.arange(image_array.shape[0]))

    # Flatten the grid arrays
    x_flat = xx.flatten()
    y_flat = yy.flatten()

    # Create a list of (x, y) points from the flattened grid
    class1_points = np.vstack((x_flat, y_flat)).T

    # Create a path object from the vertices
    polygon_path = mpltPath.Path(vertices)

    # Use the path object to create a mask
    inside_polygon = polygon_path.contains_points(class1_points)

    # Reshape the mask back to the image shape
    mask = inside_polygon.reshape(xx.shape)

    # Apply the mask to select pixels within the polygon
    # selected_pixels = image_array[mask]

    # Sum the intensities of the selected pixels
    # sum_of_intensities = np.sum(selected_pixels)

    # print("Sum of pixel intensities in the polygonal region:", sum_of_intensities)
    # Initialize an array to hold the sum of intensities for each channel
    sum_of_intensities_per_channel = np.zeros(image_array.shape[2])

    # Iterate over each channel
    for i in range(image_array.shape[2]):
        # Apply the mask to the current channel and sum the intensities
        selected_pixels = image_array[:, :, i][mask]
        sum_of_intensities_per_channel[i] = np.sum(selected_pixels)

    print("Sum of pixel intensities in the polygonal region for each channel:", sum_of_intensities_per_channel)
    box_intensity_data.append(sum_of_intensities_per_channel)
    
    # need to add confidence score
header = ["FilePath", "PolyID","cls","Vertices","Number of Vertices","PolyArea","Sum Inten WV0","SumInten WV1", "SumInten WV2","BBox x","BBox y","BBox w","BBox h",
          "BBox intensity WV0", "BBox intensity WV1","BBox intensity WV2","Conf","PolySum", "PolyAvg", "PolyStDDev", "BoxSum", "BoxAvg", "BoxStDDev", "Parents"]
data = []

class1_counter = 0
for i in range(len(img1_classes)):
    # excluding nonexistent masks
    # if img1_mask_coords[i].size == 0:
    #     if img1_classes[i] == 1.0:
    #         class1_counter += 1
    #         print("the class of this mask is 1.0, class1 counter is now ", class1_counter)
    #     continue
    # else:
    cls = predictions[0].boxes[i].cls.numpy().item(0)
    vertices = polygons[i]
    numVertices = len(vertices)
    polyArea = areas[i]
    bbox_data = predictions[0].boxes[i].xywh.numpy()
    conf = predictions[0].boxes.conf.numpy().item(i)
    polySum = sum([pixel_intensity_data[i][0],pixel_intensity_data[i][1],pixel_intensity_data[i][2]])
    polyAvg = polySum / 3
    polyStdDev = statistics.pstdev([pixel_intensity_data[i][0],pixel_intensity_data[i][1],pixel_intensity_data[i][2]])
    boxSum = sum([box_intensity_data[i][0],box_intensity_data[i][1],box_intensity_data[i][2]])
    boxAvg = boxSum / 3
    boxStdDev = statistics.pstdev([box_intensity_data[i][0],box_intensity_data[i][1],box_intensity_data[i][2]])
    polygon_data = [image_path,i,cls,vertices,numVertices,polyArea,pixel_intensity_data[i][0],pixel_intensity_data[i][1],pixel_intensity_data[i][2]
                    , bbox_data.item(0), bbox_data.item(1), bbox_data.item(2), bbox_data.item(3),box_intensity_data[i][0],box_intensity_data[i][1],box_intensity_data[i][2]
                    ,conf, polySum, polyAvg, polyStdDev, boxSum, boxAvg, boxStdDev]
    if class1_indices.__contains__(i):
        # print(i)
        polygon_data.append(class1_parents[class1_counter])
        print("class1 index before increment: ", class1_counter)
        class1_counter += 1
        print("class1 index after increment: ", class1_counter)
    data.append(polygon_data)
    

filename = 'polygon_image_data_test.csv'
with open(filename, 'w', newline="") as file:
    csvwriter = csv.writer(file)
    csvwriter.writerow(header)
    csvwriter.writerows(data)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_0_0_0.bmp: 512x512 (no detections), 79.5ms
# image 2/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_10_0_0.bmp: 512x512 7 Cells, 58 Droplets, 56.6ms
# image 3/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_11_0_0.bmp: 512x512 2 Cells, 9 Droplets, 61.1ms
# image 4/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_12_0_0.bmp: 512x512 19 Cells, 121 Droplets, 56.6ms
# image 5/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_13_0_0.bmp: 512x512 18 Cells, 141 Droplets, 57.0ms
# image 6/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_14_0_0.bmp: 512x512 24 Cells, 79 Droplets, 58.5ms
# image 7/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_15_0_0.bmp: 512x512 4 Cells, 29 Droplets, 55.6ms
# image 8/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_16_0_0.bmp: 512x512 15 Cells, 80 Droplets, 57.3ms
# image 9/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_17_0_0.bmp: 512x512 7 Cells, 55 Droplets, 57.5ms
# image 10/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_18_0_0.bmp: 512x512 12 Cells, 205 Droplets, 56.4ms
# image 11/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_19_0_0.bmp: 512x512 6 Cells, 36 Droplets, 53.5ms
# image 12/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_1_0_0.bmp: 512x512 (no detections), 55.5ms
# image 13/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_20_0_0.bmp: 512x512 3 Droplets, 54.0ms
# image 14/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_21_0_0.bmp: 512x512 7 Cells, 17 Droplets, 56.0ms
# image 15/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_22_0_0.bmp: 512x512 5 Cells, 35 Droplets, 55.1ms
# image 16/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_23_0_0.bmp: 512x512 4 Cells, 29 Droplets, 58.0ms
# image 17/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_24_0_0.bmp: 512x512 10 Cells, 45 Droplets, 57.0ms
# image 18/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_25_0_0.bmp: 512x512 1 Cell, 8 Droplets, 56.6ms
# image 19/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_26_0_0.bmp: 512x512 6 Cells, 17 Droplets, 57.5ms
# image 20/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_27_0_0.bmp: 512x512 1 Cell, 4 Droplets, 52.0ms
# image 21/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_28_0_0.bmp: 512x512 2 Droplets, 57.7ms
# image 22/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_29_0_0.bmp: 512x512 4 Cells, 34 Droplets, 58.0ms
# image 23/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_2_0_0.bmp: 512x512 1 Cell, 14 Droplets, 57.6ms
# image 24/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_30_0_0.bmp: 512x512 4 Cells, 26 Droplets, 57.0ms
# image 25/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_31_0_0.bmp: 512x512 5 Cells, 23 Droplets, 60.0ms
# image 26/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_32_0_0.bmp: 512x512 4 Cells, 15 Droplets, 58.0ms
# image 27/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_33_0_0.bmp: 512x512 (no detections), 56.0ms
# image 28/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_34_0_0.bmp: 512x512 3 Cells, 7 Droplets, 57.1ms
# image 29/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_3_0_0.bmp: 512x512 6 Cells, 34 Droplets, 57.7ms
# image 30/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_4_0_0.bmp: 512x512 17 Cells, 118 Droplets, 60.9ms
# image 31/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_5_0_0.bmp: 512x512 17 Cells, 84 Droplets, 59.0ms
# image 32/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_6_0_0.bmp: 512x512 1 Cell, 2 Droplets, 56.0ms
# image 33/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_7_0_0.bmp: 512x512 3 Cells, 28 Droplets, 55.5ms
# image 34/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_8_0_0.bmp: 512x512 5 Cells, 57 Droplets, 57.5ms
# image 35/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 10_9_0_0.bmp: 512x512 3 Cells, 30 Droplets, 53.0ms
# image 36/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_0_0_0.bmp: 512x512 (no detections), 57.0ms
# image 37/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_10_0_0.bmp: 512x512 5 Cells, 23 Droplets, 54.4ms
# image 38/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_11_0_0.bmp: 512x512 5 Cells, 33 Droplets, 57.5ms
# image 39/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_12_0_0.bmp: 512x512 5 Cells, 27 Droplets, 59.5ms
# image 40/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_13_0_0.bmp: 512x512 2 Cells, 15 Droplets, 55.0ms
# image 41/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_14_0_0.bmp: 512x512 (no detections), 56.4ms
# image 42/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_15_0_0.bmp: 512x512 1 Cell, 3 Droplets, 57.6ms
# image 43/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_16_0_0.bmp: 512x512 6 Cells, 66 Droplets, 57.5ms
# image 44/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_17_0_0.bmp: 512x512 4 Cells, 35 Droplets, 58.6ms
# image 45/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_18_0_0.bmp: 512x512 2 Droplets, 55.1ms
# image 46/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_19_0_0.bmp: 512x512 2 Cells, 10 Droplets, 55.3ms
# image 47/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_1_0_0.bmp: 512x512 1 Cell, 6 Droplets, 57.7ms
# image 48/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_20_0_0.bmp: 512x512 (no detections), 57.5ms
# image 49/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_21_0_0.bmp: 512x512 1 Cell, 7 Droplets, 56.6ms
# image 50/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_22_0_0.bmp: 512x512 10 Cells, 91 Droplets, 53.7ms
# image 51/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_23_0_0.bmp: 512x512 4 Cells, 24 Droplets, 54.1ms
# image 52/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_24_0_0.bmp: 512x512 4 Cells, 8 Droplets, 58.5ms
# image 53/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_25_0_0.bmp: 512x512 7 Cells, 30 Droplets, 57.6ms
# image 54/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_26_0_0.bmp: 512x512 1 Cell, 4 Droplets, 53.5ms
# image 55/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_27_0_0.bmp: 512x512 1 Cell, 8 Droplets, 56.6ms
# image 56/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_28_0_0.bmp: 512x512 4 Cells, 36 Droplets, 58.6ms
# image 57/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_29_0_0.bmp: 512x512 (no detections), 55.5ms
# image 58/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_2_0_0.bmp: 512x512 1 Droplet, 55.5ms
# image 59/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_30_0_0.bmp: 512x512 (no detections), 55.5ms
# image 60/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_31_0_0.bmp: 512x512 5 Cells, 29 Droplets, 56.5ms
# image 61/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_32_0_0.bmp: 512x512 (no detections), 56.6ms
# image 62/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_33_0_0.bmp: 512x512 1 Droplet, 54.0ms
# image 63/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_34_0_0.bmp: 512x512 2 Cells, 18 Droplets, 57.0ms
# image 64/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_3_0_0.bmp: 512x512 1 Cell, 9 Droplets, 59.0ms
# image 65/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_4_0_0.bmp: 512x512 5 Cells, 91 Droplets, 53.6ms
# image 66/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_5_0_0.bmp: 512x512 3 Droplets, 57.9ms
# image 67/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_6_0_0.bmp: 512x512 (no detections), 59.0ms
# image 68/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_7_0_0.bmp: 512x512 3 Cells, 2 Droplets, 52.0ms
# image 69/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_8_0_0.bmp: 512x512 (no detections), 57.0ms
# image 70/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 11_9_0_0.bmp: 512x512 2 Cells, 6 Droplets, 55.5ms
# image 71/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_0_0_0.bmp: 512x512 9 Cells, 53 Droplets, 53.5ms
# image 72/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_10_0_0.bmp: 512x512 53 Cells, 947 Droplets, 54.5ms
# image 73/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_11_0_0.bmp: 512x512 57 Cells, 858 Droplets, 52.0ms
# image 74/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_12_0_0.bmp: 512x512 (no detections), 54.2ms
# image 75/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_13_0_0.bmp: 512x512 (no detections), 56.0ms
# image 76/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_14_0_0.bmp: 512x512 2 Cells, 7 Droplets, 50.0ms
# image 77/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_15_0_0.bmp: 512x512 12 Cells, 72 Droplets, 53.0ms
# image 78/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_16_0_0.bmp: 512x512 21 Cells, 167 Droplets, 56.0ms
# image 79/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_17_0_0.bmp: 512x512 41 Cells, 230 Droplets, 55.1ms
# image 80/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_18_0_0.bmp: 512x512 (no detections), 56.5ms
# image 81/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_19_0_0.bmp: 512x512 1 Cell, 5 Droplets, 47.5ms
# image 82/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_1_0_0.bmp: 512x512 4 Cells, 55 Droplets, 58.5ms
# image 83/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_20_0_0.bmp: 512x512 4 Cells, 12 Droplets, 56.5ms
# image 84/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_21_0_0.bmp: 512x512 7 Cells, 15 Droplets, 55.5ms
# image 85/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_22_0_0.bmp: 512x512 30 Cells, 143 Droplets, 55.5ms
# image 86/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_23_0_0.bmp: 512x512 44 Cells, 422 Droplets, 56.6ms
# image 87/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_24_0_0.bmp: 512x512 (no detections), 62.4ms
# image 88/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_25_0_0.bmp: 512x512 1 Cell, 1 Droplet, 59.4ms
# image 89/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_26_0_0.bmp: 512x512 1 Droplet, 57.5ms
# image 90/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_27_0_0.bmp: 512x512 12 Cells, 67 Droplets, 57.5ms
# image 91/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_28_0_0.bmp: 512x512 6 Cells, 37 Droplets, 55.7ms
# image 92/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_29_0_0.bmp: 512x512 4 Cells, 38 Droplets, 58.1ms
# image 93/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_2_0_0.bmp: 512x512 3 Cells, 10 Droplets, 53.1ms
# image 94/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_30_0_0.bmp: 512x512 5 Cells, 32 Droplets, 56.2ms
# image 95/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_31_0_0.bmp: 512x512 3 Cells, 18 Droplets, 57.1ms
# image 96/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_32_0_0.bmp: 512x512 6 Cells, 47 Droplets, 55.5ms
# image 97/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_33_0_0.bmp: 512x512 8 Cells, 34 Droplets, 49.5ms
# image 98/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_34_0_0.bmp: 512x512 4 Cells, 30 Droplets, 56.9ms
# image 99/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_3_0_0.bmp: 512x512 (no detections), 55.5ms
# image 100/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_4_0_0.bmp: 512x512 15 Cells, 99 Droplets, 56.5ms
# image 101/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_5_0_0.bmp: 512x512 29 Cells, 226 Droplets, 56.0ms
# image 102/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_6_0_0.bmp: 512x512 3 Cells, 45 Droplets, 59.0ms
# image 103/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_7_0_0.bmp: 512x512 2 Cells, 14 Droplets, 54.0ms
# image 104/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_8_0_0.bmp: 512x512 5 Droplets, 55.0ms
# image 105/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 12_9_0_0.bmp: 512x512 37 Cells, 239 Droplets, 53.5ms
# image 106/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_0_0_0.bmp: 512x512 1 Droplet, 60.9ms
# image 107/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_10_0_0.bmp: 512x512 (no detections), 56.6ms
# image 108/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_11_0_0.bmp: 512x512 (no detections), 53.5ms
# image 109/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_12_0_0.bmp: 512x512 (no detections), 54.5ms
# image 110/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_13_0_0.bmp: 512x512 (no detections), 57.5ms
# image 111/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_14_0_0.bmp: 512x512 (no detections), 58.6ms
# image 112/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_15_0_0.bmp: 512x512 (no detections), 56.0ms
# image 113/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_16_0_0.bmp: 512x512 (no detections), 57.0ms
# image 114/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_17_0_0.bmp: 512x512 (no detections), 56.5ms
# image 115/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_18_0_0.bmp: 512x512 (no detections), 56.5ms
# image 116/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_19_0_0.bmp: 512x512 (no detections), 49.6ms
# image 117/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_1_0_0.bmp: 512x512 (no detections), 56.8ms
# image 118/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_20_0_0.bmp: 512x512 (no detections), 55.0ms
# image 119/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_21_0_0.bmp: 512x512 (no detections), 55.0ms
# image 120/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_22_0_0.bmp: 512x512 (no detections), 56.1ms
# image 121/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_23_0_0.bmp: 512x512 (no detections), 54.5ms
# image 122/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_24_0_0.bmp: 512x512 (no detections), 55.6ms
# image 123/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_25_0_0.bmp: 512x512 (no detections), 54.6ms
# image 124/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_26_0_0.bmp: 512x512 (no detections), 57.1ms
# image 125/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_27_0_0.bmp: 512x512 (no detections), 55.0ms
# image 126/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_28_0_0.bmp: 512x512 (no detections), 52.5ms
# image 127/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_29_0_0.bmp: 512x512 (no detections), 53.1ms
# image 128/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_2_0_0.bmp: 512x512 (no detections), 53.0ms
# image 129/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_30_0_0.bmp: 512x512 (no detections), 57.0ms
# image 130/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_31_0_0.bmp: 512x512 (no detections), 55.1ms
# image 131/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_32_0_0.bmp: 512x512 (no detections), 55.1ms
# image 132/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_33_0_0.bmp: 512x512 (no detections), 59.9ms
# image 133/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_34_0_0.bmp: 512x512 (no detections), 60.3ms
# image 134/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_3_0_0.bmp: 512x512 (no detections), 59.1ms
# image 135/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_4_0_0.bmp: 512x512 (no detections), 55.5ms
# image 136/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_5_0_0.bmp: 512x512 (no detections), 52.6ms
# image 137/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_6_0_0.bmp: 512x512 (no detections), 58.0ms
# image 138/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_7_0_0.bmp: 512x512 (no detections), 54.0ms
# image 139/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_8_0_0.bmp: 512x512 (no detections), 52.0ms
# image 140/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 2_9_0_0.bmp: 512x512 (no detections), 58.5ms
# image 141/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_0_0_0.bmp: 512x512 (no detections), 57.5ms
# image 142/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_10_0_0.bmp: 512x512 1 Cell, 6 Droplets, 53.0ms
# image 143/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_11_0_0.bmp: 512x512 1 Cell, 4 Droplets, 57.0ms
# image 144/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_12_0_0.bmp: 512x512 (no detections), 59.0ms
# image 145/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_13_0_0.bmp: 512x512 (no detections), 52.2ms
# image 146/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_14_0_0.bmp: 512x512 2 Cells, 13 Droplets, 51.5ms
# image 147/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_15_0_0.bmp: 512x512 3 Cells, 13 Droplets, 55.5ms
# image 148/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_16_0_0.bmp: 512x512 4 Cells, 30 Droplets, 55.7ms
# image 149/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_17_0_0.bmp: 512x512 2 Cells, 20 Droplets, 56.5ms
# image 150/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_18_0_0.bmp: 512x512 1 Cell, 4 Droplets, 57.5ms
# image 151/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_19_0_0.bmp: 512x512 (no detections), 58.0ms
# image 152/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_1_0_0.bmp: 512x512 (no detections), 53.8ms
# image 153/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_20_0_0.bmp: 512x512 2 Cells, 8 Droplets, 51.5ms
# image 154/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_21_0_0.bmp: 512x512 1 Cell, 9 Droplets, 54.0ms
# image 155/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_22_0_0.bmp: 512x512 2 Cells, 7 Droplets, 52.0ms
# image 156/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_23_0_0.bmp: 512x512 (no detections), 54.8ms
# image 157/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_24_0_0.bmp: 512x512 (no detections), 58.6ms
# image 158/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_25_0_0.bmp: 512x512 2 Cells, 7 Droplets, 55.0ms
# image 159/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_26_0_0.bmp: 512x512 10 Cells, 38 Droplets, 56.6ms
# image 160/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_27_0_0.bmp: 512x512 11 Cells, 66 Droplets, 60.0ms
# image 161/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_28_0_0.bmp: 512x512 6 Cells, 70 Droplets, 59.4ms
# image 162/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_29_0_0.bmp: 512x512 6 Cells, 36 Droplets, 58.1ms
# image 163/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_2_0_0.bmp: 512x512 1 Cell, 3 Droplets, 54.5ms
# image 164/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_30_0_0.bmp: 512x512 (no detections), 56.0ms
# image 165/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_31_0_0.bmp: 512x512 1 Droplet, 59.3ms
# image 166/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_32_0_0.bmp: 512x512 3 Cells, 22 Droplets, 56.6ms
# image 167/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_33_0_0.bmp: 512x512 13 Cells, 95 Droplets, 58.5ms
# image 168/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_34_0_0.bmp: 512x512 3 Cells, 20 Droplets, 55.5ms
# image 169/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_3_0_0.bmp: 512x512 (no detections), 57.5ms
# image 170/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_4_0_0.bmp: 512x512 (no detections), 60.1ms
# image 171/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_5_0_0.bmp: 512x512 7 Cells, 46 Droplets, 53.0ms
# image 172/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_6_0_0.bmp: 512x512 (no detections), 58.3ms
# image 173/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_7_0_0.bmp: 512x512 (no detections), 59.5ms
# image 174/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_8_0_0.bmp: 512x512 3 Cells, 17 Droplets, 55.1ms
# image 175/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 3_9_0_0.bmp: 512x512 3 Cells, 19 Droplets, 55.5ms
# image 176/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_0_0_0.bmp: 512x512 (no detections), 56.0ms
# image 177/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_10_0_0.bmp: 512x512 14 Cells, 96 Droplets, 56.0ms
# image 178/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_11_0_0.bmp: 512x512 12 Cells, 82 Droplets, 58.0ms
# image 179/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_12_0_0.bmp: 512x512 2 Droplets, 52.0ms
# image 180/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_13_0_0.bmp: 512x512 (no detections), 53.0ms
# image 181/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_14_0_0.bmp: 512x512 (no detections), 46.5ms
# image 182/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_15_0_0.bmp: 512x512 (no detections), 54.0ms
# image 183/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_16_0_0.bmp: 512x512 7 Cells, 49 Droplets, 53.0ms
# image 184/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_17_0_0.bmp: 512x512 14 Cells, 88 Droplets, 58.6ms
# image 185/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_18_0_0.bmp: 512x512 (no detections), 58.0ms
# image 186/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_19_0_0.bmp: 512x512 (no detections), 63.6ms
# image 187/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_1_0_0.bmp: 512x512 1 Droplet, 59.2ms
# image 188/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_20_0_0.bmp: 512x512 (no detections), 55.3ms
# image 189/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_21_0_0.bmp: 512x512 (no detections), 56.1ms
# image 190/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_22_0_0.bmp: 512x512 8 Cells, 29 Droplets, 61.0ms
# image 191/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_23_0_0.bmp: 512x512 58 Cells, 246 Droplets, 57.0ms
# image 192/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_24_0_0.bmp: 512x512 (no detections), 59.0ms
# image 193/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_25_0_0.bmp: 512x512 (no detections), 52.5ms
# image 194/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_26_0_0.bmp: 512x512 (no detections), 54.5ms
# image 195/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_27_0_0.bmp: 512x512 (no detections), 55.1ms
# image 196/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_28_0_0.bmp: 512x512 (no detections), 52.5ms
# image 197/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_29_0_0.bmp: 512x512 24 Cells, 114 Droplets, 56.7ms
# image 198/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_2_0_0.bmp: 512x512 (no detections), 62.2ms
# image 199/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_30_0_0.bmp: 512x512 (no detections), 59.5ms
# image 200/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_31_0_0.bmp: 512x512 1 Droplet, 54.7ms
# image 201/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_32_0_0.bmp: 512x512 (no detections), 55.0ms
# image 202/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_33_0_0.bmp: 512x512 (no detections), 57.2ms
# image 203/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_34_0_0.bmp: 512x512 (no detections), 51.5ms
# image 204/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_3_0_0.bmp: 512x512 (no detections), 55.0ms
# image 205/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_4_0_0.bmp: 512x512 19 Cells, 159 Droplets, 57.1ms
# image 206/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_5_0_0.bmp: 512x512 13 Cells, 119 Droplets, 63.5ms
# image 207/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_6_0_0.bmp: 512x512 1 Cell, 1 Droplet, 63.0ms
# image 208/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_7_0_0.bmp: 512x512 (no detections), 67.0ms
# image 209/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_8_0_0.bmp: 512x512 (no detections), 53.5ms
# image 210/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 4_9_0_0.bmp: 512x512 (no detections), 52.1ms
# image 211/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_0_0_0.bmp: 512x512 10 Cells, 103 Droplets, 62.0ms
# image 212/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_10_0_0.bmp: 512x512 15 Cells, 62 Droplets, 57.0ms
# image 213/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_11_0_0.bmp: 512x512 22 Cells, 152 Droplets, 55.9ms
# image 214/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_12_0_0.bmp: 512x512 26 Cells, 149 Droplets, 50.6ms
# image 215/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_13_0_0.bmp: 512x512 84 Cells, 662 Droplets, 59.3ms
# image 216/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_14_0_0.bmp: 512x512 87 Cells, 798 Droplets, 73.7ms
# image 217/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_15_0_0.bmp: 512x512 33 Cells, 228 Droplets, 64.5ms
# image 218/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_16_0_0.bmp: 512x512 50 Cells, 386 Droplets, 63.1ms
# image 219/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_17_0_0.bmp: 512x512 57 Cells, 421 Droplets, 59.1ms
# image 220/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_18_0_0.bmp: 512x512 2 Cells, 19 Droplets, 67.1ms
# image 221/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_19_0_0.bmp: 512x512 37 Cells, 463 Droplets, 61.6ms
# image 222/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_1_0_0.bmp: 512x512 27 Cells, 237 Droplets, 69.1ms
# image 223/3325 S:\Phys\FIV942 Adipo\FIV942P3 Chops 512\FIV942P3-5_FIV942P3.A - 5_20_0_0.bmp: 512x512 17 Cells, 136 Droplets, 59.5ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 19
#      15 val_data = r"S:\Phys\FIV942 Adipo\FIV942P3 Chops 512"
#      17 adipo_seg = YOLO(model_path)
# ---> 19 predictions = adipo_seg.predict(val_data, show=False, max_det = 1000)
#      21 img1_data = predictions[0]
#      22 img1_mask_coords = img1_data.masks.xy
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\ultralytics\engine\model.py:439, in Model.predict(self, source, stream, predictor, **kwargs)
#     437 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     438     self.predictor.set_prompts(prompts)
# --> 439 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\utils\_contextlib.py:56, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      53         else:
#      54             # Pass the last request to the generator and get its response
#      55             with ctx_factory():
# ---> 56                 response = gen.send(request)
#      58 # We let the exceptions raised above by the generator's `.throw` or
#      59 # `.send` methods bubble up to our caller, except for StopIteration
#      60 except StopIteration as e:
#      61     # The generator informed us that it is done: take whatever its
#      62     # returned value (if any) was and indicate that we're done too
#      63     # by returning it (see docs for python's return-statement).
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\ultralytics\engine\predictor.py:248, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     246 # Inference
#     247 with profilers[1]:
# --> 248     preds = self.inference(im, *args, **kwargs)
#     249     if self.args.embed:
#     250         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\ultralytics\engine\predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\ultralytics\nn\autobackend.py:425, in AutoBackend.forward(self, im, augment, visualize, embed)
#     423 # PyTorch
#     424 if self.pt or self.nn_module:
# --> 425     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     427 # TorchScript
#     428 elif self.jit:
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\ultralytics\nn\tasks.py:89, in BaseModel.forward(self, x, *args, **kwargs)
#      87 if isinstance(x, dict):  # for cases of training and validating while training.
#      88     return self.loss(x, *args, **kwargs)
# ---> 89 return self.predict(x, *args, **kwargs)
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\ultralytics\nn\tasks.py:107, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     105 if augment:
#     106     return self._predict_augment(x)
# --> 107 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\ultralytics\nn\tasks.py:128, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     126 if profile:
#     127     self._profile_one_layer(m, x, dt)
# --> 128 x = m(x)  # run
#     129 y.append(x if m.i in self.save else None)  # save output
#     130 if visualize:
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\ultralytics\nn\modules\block.py:232, in C2f.forward(self, x)
#     230 y = list(self.cv1(x).chunk(2, 1))
#     231 y.extend(m(y[-1]) for m in self.m)
# --> 232 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\ultralytics\nn\modules\conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\nn\modules\conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\FIVE\anaconda3\envs\myenv4\lib\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
